# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "NYISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"
with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)

YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "NY"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/New_York_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    # "mid", 
    "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    # "midnight": {
    #     "profile": "timed_charging",
    #     "description": "Midnight timed charging",
    # },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    # "arrive": {
    #     "profile": "min_delay",
    #     "description": "Immediate arrival charging",
    # },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "NY_Z_J": 0.40,      # NYC - highest demand, most valuable storage
    "NY_Z_K": 0.20,      # Long Island - high demand, constrained transmission
    "NY_Z_F": 0.10,      # Capital region
    "NY_Z_C&E": 0.10,    # Central
    "NY_Z_G-I": 0.10,    # Hudson Valley - transmission relief
    "NY_Z_A": 0.05,      # Western NY
    "NY_Z_B": 0.025,     # Genesee
    "NY_Z_D": 0.025,     # North
}

STATE_TO_REGIONS = {
    "NY": [
        "NY_Z_A",
        "NY_Z_B",
        "NY_Z_C&E",
        "NY_Z_D",
        "NY_Z_F",
        "NY_Z_G-I",
        "NY_Z_J",
        "NY_Z_K"
    ],
}

RETIREMENT_POLICIES = {
    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },
}

ASSET_CONSTRAINT_POLICIES = {

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 690,
        },
    },
    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (fast)
# # Charging scenarios: 1 (flex)
# # Total combinations: 1
# # Total runs: 15 (= 15 scenarios × 1 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: FAST
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: FAST adoption + Flexible load leveling
# Results Directory: Output/NYISO/scenario_results_2030_fast_NYISO_flex
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 5.945620536804199
# Variables Built: 4.004281282424927
# Constraints Built: 35.325812339782715
# Objective Built: 2.3422791957855225
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 5.8861167430877686
# Variables Built: 4.03026556968689
# Constraints Built: 35.396814823150635
# Objective Built: 2.3549931049346924
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 5.9354376792907715
# Variables Built: 4.0575480461120605
# Constraints Built: 35.648234367370605
# Objective Built: 2.353466510772705
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.262084484100342
# Variables Built: 4.5512003898620605
# Constraints Built: 37.359567642211914
# Objective Built: 4.928992509841919
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.242852687835693
# Variables Built: 4.537660360336304
# Constraints Built: 37.51996612548828
# Objective Built: 4.954364061355591
# Problem Solved: 2508.002536058426
# Solution Graph Built: 58.2713565826416
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.4159560203552246
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 4 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 31,456,964 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      10,241.47      15,989.86          336,540.11          1,435.85       155
# solar                                8,460.55       6,488.61      14,949.16           80,759.09            609.80        64
# battery                                690.00           0.00         690.00          106,267.74              0.00         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               2,100.00           0.00       2,100.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,877.07           0.00     -33,877.07                0.00              0.00        24
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              5,228,838.46
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 4
# ====================================================================================================
#
# Total Objective: $4,408,728,145.91
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,435,853,939.74
#   solar                          $ 609,804,682.11
#   TOTAL                          $2,045,658,621.86
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $ 666,820,486.19
#   nuclear                        $ 612,286,602.99
#   steam                          $ 170,986,970.56
#   natural gas turbine            $ 107,940,595.46
#   oil                            $  86,628,339.79
#   waste                          $  24,627,440.48
#   biomass                        $  14,353,846.77
#   large_hydro                    $   6,927,556.39
#   non-fossil                     $     774,090.46
#   small_hydro                    $     236,994.65
#   TOTAL                          $1,691,582,923.74
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 222,961,264.01
#   NY_Z_F:NY_Z_G-I                $ 135,673,262.92
#   NY_Z_C&E:NY_Z_G-I              $ 112,448,893.84
#   NY_Z_C&E:NY_Z_F                $  89,229,131.48
#   NY_Z_G-I:NY_Z_K                $  44,644,362.49
#   NY_Z_D:NY_Z_C&E                $  24,262,718.58
#   NY_Z_K:NY_Z_J                  $   9,516,105.69
#   NY_Z_B:NY_Z_A                  $   6,109,330.94
#   NY_Z_A:NY_Z_B                  $   5,669,070.66
#   NY_Z_C&E:NY_Z_B                $   5,657,964.58
#   NY_Z_B:NY_Z_C&E                $   5,554,119.93
#   NY_Z_J:NY_Z_K                  $   3,930,300.10
#   NY_Z_K:NY_Z_G-I                $   2,517,131.08
#   NY_Z_C&E:NY_Z_D                $     730,947.71
#   TOTAL                          $ 668,904,604.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $4,406,146,149.60
# Model Objective                $4,408,728,145.91
# Other Gap                      $   2,581,996.31
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 196.84 MWh
# NY_Z_B -> NY_Z_A via line_81: 212.13 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 192.85 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 196.46 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 25.38 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 3,098.23 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,904.48 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 842.46 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 4,710.88 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 7,741.71 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 1,550.15 MWh
# NY_Z_J -> NY_Z_K via line_99: 136.47 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 87.40 MWh
# NY_Z_K -> NY_Z_J via line_102: 330.42 MWh
#
# Total transmission across all lines: 23,225.85 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# ================================================================================
#
# Parameters Built: 6.3972673416137695
# Variables Built: 3.0967323780059814
# Constraints Built: 53.67259883880615
# Objective Built: 6.840882062911987
#   Scenario   4 ✓
#
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               28,020.57      10,907.10           0.00      10,907.10         9
# nuclear                                  27,473.40       3,346.70           0.00       3,346.70         2
# steam                                     6,007.15      10,910.56           0.00      10,910.56         6
# large_hydro                               5,420.23       3,374.40           0.00       3,374.40         3
# small_hydro                               4,385.70       1,186.40           0.00       1,186.40         6
# waste                                     3,550.79         473.20           0.00         473.20         8
# natural gas turbine                       3,436.39       2,545.92           0.00       2,545.92         8
# oil                                       2,806.61       1,699.11           0.00       1,699.11         5
# battery                                   1,380.58         690.00           0.00         690.00         8
# biomass                                     270.70          54.90           0.00          54.90         1
# non-fossil                                  111.59          20.20           0.00          20.20         2
# pump hydro                                    0.67           0.10           0.00           0.10         2
# import                                        0.00       2,100.00           0.00       2,100.00         3
# solar                                   -28,924.79       8,460.55       6,488.61      14,949.16        64
# wind                                    -61,516.49       5,748.39      10,241.47      15,989.86       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   5,228,838.46
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 78.19 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_A:
#   Installed Capacity: 26.06 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 26.06 MW
#   Max Shift Down: -13.01 MW
#   Total Shifting: 68,165.77 MWh
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 59.47 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_B:
#   Installed Capacity: 19.82 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 19.82 MW
#   Max Shift Down: -9.89 MW
#   Total Shifting: 67,921.47 MWh
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 116.77 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_C&E:
#   Installed Capacity: 38.92 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 38.92 MW
#   Max Shift Down: -19.43 MW
#   Total Shifting: 140,735.21 MWh
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 13.04 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_D:
#   Installed Capacity: 4.35 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 4.35 MW
#   Max Shift Down: -2.17 MW
#   Total Shifting: 13,448.13 MWh
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 74.58 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_F:
#   Installed Capacity: 24.86 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 24.86 MW
#   Max Shift Down: -12.41 MW
#   Total Shifting: 89,249.38 MWh
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 117.80 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_G-I:
#   Installed Capacity: 39.27 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 39.27 MW
#   Max Shift Down: -19.60 MW
#   Total Shifting: 140,412.25 MWh
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 143.40 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_J:
#   Installed Capacity: 47.80 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 47.80 MW
#   Max Shift Down: -23.86 MW
#   Total Shifting: 166,048.00 MWh
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 132.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_K:
#   Installed Capacity: 44.26 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 44.26 MW
#   Max Shift Down: -22.09 MW
#   Total Shifting: 140,078.90 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_s04_fast_m0_d360/s04_s04_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_s04_fast_m0_d360/s04_s04_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_s04_fast_m0_d360/s04_s04_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_s04_fast_m0_d360/s04_s04_ev_summary.csv
# Finished scenario 4: s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360/s04_V1G_rps60_v1g25_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 4,408,728,145.91
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
# Added detail-equivalent aggregate V2G store to NY_Z_A: max_power=351.13 MW, max_energy=351.13 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_B: max_power=267.05 MW, max_energy=267.05 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_C&E: max_power=524.40 MW, max_energy=524.40 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_D: max_power=58.55 MW, max_energy=58.55 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_F: max_power=334.94 MW, max_energy=334.94 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_G-I: max_power=529.05 MW, max_energy=529.05 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_J: max_power=643.98 MW, max_energy=643.98 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_K: max_power=596.29 MW, max_energy=596.29 MWh, window_hours=24
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 7.069854736328125
# Variables Built: 3.292863368988037
# Constraints Built: 59.74593162536621
# Objective Built: 6.964643955230713
# Problem Solved: 2672.44846200943
# Solution Graph Built: 57.980170011520386
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.4475619792938232
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 70.0%
# ============================================================================================================================================
#
# Gas Generation: 22,812,082 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      14,563.58      20,311.98          336,540.11          2,169.53       155
# solar                                8,460.55      11,973.70      20,434.25           80,759.09          1,123.98        64
# battery                                690.00       3,787.66       4,477.66          106,267.74            396.99         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               2,100.00           0.00       2,100.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,877.07           0.00     -33,877.07                0.00              0.00        24
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             12,916,325.40
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
# Total Objective: $6,093,678,480.49
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $2,169,532,545.59
#   solar                          $1,123,979,654.34
#   battery                        $ 396,992,519.30
#   TOTAL                          $3,690,504,719.24
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $ 612,216,596.65
#   natural gas combined cycle     $ 483,298,319.00
#   natural gas turbine            $  82,197,096.46
#   steam                          $  68,608,296.30
#   oil                            $  64,592,122.73
#   waste                          $  21,929,893.97
#   biomass                        $   9,491,218.03
#   large_hydro                    $   2,892,592.83
#   non-fossil                     $     442,820.20
#   small_hydro                    $     214,405.73
#   TOTAL                          $1,345,883,361.90
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 347,818,715.57
#   NY_Z_C&E:NY_Z_G-I              $ 314,692,198.27
#   NY_Z_F:NY_Z_G-I                $ 163,652,418.77
#   NY_Z_G-I:NY_Z_K                $  80,056,541.10
#   NY_Z_C&E:NY_Z_F                $  48,870,330.03
#   NY_Z_D:NY_Z_C&E                $  28,342,627.28
#   NY_Z_K:NY_Z_J                  $  24,252,579.15
#   NY_Z_B:NY_Z_C&E                $   6,443,534.02
#   NY_Z_A:NY_Z_B                  $   6,333,361.68
#   NY_Z_C&E:NY_Z_B                $   6,209,767.26
#   NY_Z_J:NY_Z_K                  $   5,741,417.62
#   NY_Z_B:NY_Z_A                  $   5,021,651.82
#   NY_Z_K:NY_Z_G-I                $   2,448,022.00
#   NY_Z_C&E:NY_Z_D                $     556,281.02
#   NY_Z_F:NY_Z_C&E                $       8,872.18
#   TOTAL                          $1,040,448,317.77
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $6,076,836,398.91
# Model Objective                $6,093,678,480.49
# Other Gap                      $  16,842,081.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 219.91 MWh
# NY_Z_B -> NY_Z_A via line_81: 174.36 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 223.73 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 215.62 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 19.32 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 1,696.89 MWh
# ...
#   Shiftable: False
#
# ev_load_v2g_NY_Z_B:
#   Installed Capacity: 19.82 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 116.77 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_C&E:
#   Installed Capacity: 38.92 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 13.04 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_D:
#   Installed Capacity: 4.35 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 74.58 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_F:
#   Installed Capacity: 24.86 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 117.80 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_G-I:
#   Installed Capacity: 39.27 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 143.40 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_J:
#   Installed Capacity: 47.80 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 132.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_K:
#   Installed Capacity: 44.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_s09_fast_m0_d360/s09_s09_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_s09_fast_m0_d360/s09_s09_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_s09_fast_m0_d360/s09_s09_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_s09_fast_m0_d360/s09_s09_ev_summary.csv
# Finished scenario 9: s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_fast_NYISO_flex/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360/s09_V2G_rps80_v1g0_v2g25_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 10,694,184,017.29
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
# Added detail-equivalent aggregate V2G store to NY_Z_A: max_power=702.27 MW, max_energy=702.27 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_B: max_power=534.09 MW, max_energy=534.09 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_C&E: max_power=1048.81 MW, max_energy=1048.81 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_D: max_power=117.10 MW, max_energy=117.10 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_F: max_power=669.88 MW, max_energy=669.88 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_G-I: max_power=1058.10 MW, max_energy=1058.10 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_J: max_power=1287.96 MW, max_energy=1287.96 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_K: max_power=1192.59 MW, max_energy=1192.59 MWh, window_hours=24
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator                     import           NY         False            3  2100.000000
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 7.3968284130096436
# Variables Built: 3.4351754188537598
# Constraints Built: 62.08924078941345
# Objective Built: 8.075471639633179
# Problem Solved: 5404.027093172073
# Solution Graph Built: 59.36677837371826
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.4424149990081787
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 8 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 70.0%
# ============================================================================================================================================
#
# Gas Generation: 22,725,523 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      14,572.03      20,320.42          336,540.11          2,170.67       155
# solar                                8,460.55      11,997.46      20,458.01           80,759.09          1,126.85        64
# battery                                690.00       2,956.34       3,646.34          106,267.74            309.86         8
# import                               2,100.00           0.00       2,100.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# ev_v2g                               3,305.39           0.00       3,305.39                0.00              0.00         8
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,877.07           0.00     -33,877.07                0.00              0.00        24
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             13,264,839.23
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 8
# ====================================================================================================
#
# Total Objective: $6,026,477,410.02
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $2,170,671,353.86
#   solar                          $1,126,845,994.86
#   battery                        $ 309,859,965.56
#   TOTAL                          $3,607,377,314.29
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $ 612,214,843.44
#   natural gas combined cycle     $ 481,430,627.61
#   natural gas turbine            $  81,915,731.08
#   steam                          $  65,798,278.36
#   oil                            $  64,742,510.64
#   waste                          $  21,862,625.00
#   biomass                        $   9,431,960.39
#   large_hydro                    $   2,877,791.30
#   non-fossil                     $     442,005.48
#   small_hydro                    $     213,254.92
#   TOTAL                          $1,340,929,628.21
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 344,785,183.75
#   NY_Z_C&E:NY_Z_G-I              $ 321,954,149.44
#   NY_Z_F:NY_Z_G-I                $ 163,059,330.85
#   NY_Z_G-I:NY_Z_K                $  79,872,857.78
#   NY_Z_C&E:NY_Z_F                $  47,798,493.93
#   NY_Z_K:NY_Z_J                  $  36,512,197.47
#   NY_Z_D:NY_Z_C&E                $  28,185,079.50
#   NY_Z_B:NY_Z_C&E                $   6,478,001.38
#   NY_Z_A:NY_Z_B                  $   6,331,303.97
#   NY_Z_C&E:NY_Z_B                $   5,981,135.73
#   NY_Z_J:NY_Z_K                  $   5,776,134.20
#   NY_Z_B:NY_Z_A                  $   4,838,032.88
#   NY_Z_K:NY_Z_G-I                $   2,373,181.08
#   NY_Z_C&E:NY_Z_D                $     548,854.53
#   NY_Z_F:NY_Z_C&E                $       7,512.44
#   TOTAL                          $1,054,501,448.92
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $6,002,808,391.43
# Model Objective                $6,026,477,410.02
# Other Gap                      $  23,669,018.59
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 219.84 MWh
# NY_Z_B -> NY_Z_A via line_81: 167.99 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 224.93 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 207.68 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 19.06 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 1,659.67 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 5,052.70 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 978.65 MWh
# NY_Z_F -> NY_Z_C&E via line_90: 0.26 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 5,661.78 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 9,738.97 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 2,130.00 MWh
# NY_Z_J -> NY_Z_K via line_99: 200.56 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 82.40 MWh
# NY_Z_K -> NY_Z_J via line_102: 452.35 MWh
#
# Total transmission across all lines: 26,796.84 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR  Scenario   8 ✓
