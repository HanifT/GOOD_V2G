# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "CAISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)


YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "CA"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/California_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    "mid",
    # "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    # "midnight": {
    #     "profile": "timed_charging",
    #     "description": "Midnight timed charging",
    # },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "WECC_SCE": 0.638000,  # 9,567.7 MW
    "WEC_CALN": 0.205963,  # 3,088.7 MW
    "WEC_LADW": 0.060054,  #   900.6 MW
    "WEC_SDGE": 0.095983,  # 1,439.4 MW
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

CAISO_REGIONS = [
    "WEC_CALN",
    "WEC_LADW",
    "WEC_SDGE",
    "WECC_SCE",
]

STATE_TO_REGIONS = {
    "CA": CAISO_REGIONS,
    "CAISO": CAISO_REGIONS,
}

RETIREMENT_POLICIES = {
    "CA": {
        "oil": 0.1113,
        "nuclear": 0.50,
        "natural gas turbine": 0.0005,
        "natural gas combined cycle": 0.0,
        "coal": 0.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "CA": {
        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}
FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 15700,
        },
    },
    "CA": {
        "battery": {
            "total_power_mw": 15700,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 2.08e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "CA": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "CA": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (mid)
# # Charging scenarios: 2 (arrive, flex)
# # Total combinations: 2
# # Total runs: 30 (= 15 scenarios × 2 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: MID
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: MID adoption + Immediate arrival charging
# Results Directory: Output/CAISO/scenario_results_2030_mid_CAISO_arrive
# ================================================================================
#
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.7, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.057413578033447
# Variables Built: 2.649801731109619
# Constraints Built: 22.258129119873047
# Objective Built: 1.2748827934265137
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.5, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.019408702850342
# Variables Built: 2.565487861633301
# Constraints Built: 22.299580097198486
# Objective Built: 1.2747845649719238
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.6, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.035450220108032
# Variables Built: 2.6140787601470947
# Constraints Built: 22.308104991912842
# Objective Built: 1.2734720706939697
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.6, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.259094476699829
# Variables Built: 2.820340633392334
# Constraints Built: 23.009925365447998
# Objective Built: 2.8007121086120605
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.5, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.204373359680176
# Variables Built: 2.7952685356140137
# Constraints Built: 23.194530248641968
# Objective Built: 2.839545488357544
# Problem Solved: 1371.573671579361
# Solution Graph Built: 20.867103099822998
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.423048734664917
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 133,895,496 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 7,877.07       5,182.00      13,059.07          108,452.25            636.98        52
# solar                               22,904.57       2,915.43      25,820.00           94,787.16            265.53        95
# oil                                    254.52           0.00         254.52                0.00              0.00         3
# waste                                  755.23           0.00         755.23                0.00              0.00         4
# unknown                            -65,696.95           0.00     -65,696.95                0.00              0.00         8
# steam                                  623.00           0.00         623.00                0.00              0.00         2
# small_hydro                          1,745.64           0.00       1,745.64                0.00              0.00         4
# pump hydro                               0.24           0.00           0.24                0.00              0.00         3
# battery                             15,700.00           0.00      15,700.00          106,267.74              0.00         4
# biomass                                543.70           0.00         543.70                0.00              0.00         2
# natural gas turbine                 13,316.81           0.00      13,316.81                0.00              0.00         5
# natural gas combined cycle          17,963.95           0.00      17,963.95                0.00              0.00         4
# large_hydro                          7,605.89           0.00       7,605.89                0.00              0.00         3
# import                               4,250.00           0.00       4,250.00                0.00              0.00         3
# geothermal                           1,452.33           0.00       1,452.33                0.00              0.00         2
# coal                                    73.30           0.00          73.30                0.00              0.00         2
# non-fossil                             158.20           0.00         158.20                0.00              0.00         4
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                 56,068.32
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $5,064,154,962.67
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 636,979,041.10
#   solar                          $ 265,526,237.80
#   TOTAL                          $ 902,505,278.90
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $3,331,731,757.20
#   natural gas turbine            $ 536,501,514.16
#   steam                          $  53,159,227.20
#   oil                            $  42,671,426.54
#   waste                          $  40,943,523.38
#   geothermal                     $  14,534,756.66
#   coal                           $  12,194,182.43
#   non-fossil                     $   9,319,841.44
#   large_hydro                    $   3,715,600.10
#   biomass                        $   1,370,507.05
#   small_hydro                    $     123,279.07
#   TOTAL                          $4,046,265,615.23
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WEC_CALN:WECC_SCE              $  37,038,920.12
#   WECC_SCE:WEC_CALN              $   9,354,928.55
#   WEC_LADW:WECC_SCE              $   4,860,449.59
#   WECC_SCE:WEC_SDGE              $   4,318,799.11
#   WECC_SCE:WEC_LADW              $   1,057,945.79
#   WEC_SDGE:WECC_SCE              $     299,086.69
#   TOTAL                          $  56,930,129.85
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,005,701,023.97
# Model Objective                $5,064,154,962.67
# Other Gap                      $  58,453,938.69
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WEC_CALN -> WECC_SCE via line_257: 1,286.07 MWh
# WEC_LADW -> WECC_SCE via line_261: 168.77 MWh
# WEC_SDGE -> WECC_SCE via line_266: 10.38 MWh
# WECC_SCE -> WEC_CALN via line_234: 324.82 MWh
# WECC_SCE -> WEC_LADW via line_235: 36.73 MWh
# WECC_SCE -> WEC_SDGE via line_236: 149.96 MWh
#
# Total transmission across all lines: 1,976.74 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================  Scenario   1 ✓
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              120,438.83      17,963.95           0.00      17,963.95         4
# battery                                  17,772.54      15,700.00           0.00      15,700.00         4
# natural gas turbine                      13,456.67      13,316.81           0.00      13,316.81         5
# geothermal                               12,529.96       1,452.33           0.00       1,452.33         2
# large_hydro                              10,972.35       7,605.89           0.00       7,605.89         3
# waste                                     6,467.19         755.23           0.00         755.23         4
# small_hydro                               2,399.80       1,745.64           0.00       1,745.64         4
# oil                                       2,172.83         254.52           0.00         254.52         3
# steam                                     1,374.53         623.00           0.00         623.00         2
# non-fossil                                1,343.50         158.20           0.00         158.20         4
# coal                                        510.08          73.30           0.00          73.30         2
# biomass                                      28.44         543.70           0.00         543.70         2
# pump hydro                                    1.37           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -49,469.57       7,877.07       5,182.00      13,059.07        52
# solar                                   -79,429.87      22,904.57       2,915.43      25,820.00        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      56,068.32
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 2,022.48 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 1,370.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 501.31 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 1,569.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_s01_mid_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_s01_mid_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_s01_mid_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_s01_mid_m0_d360/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_mid_CAISO_arrive/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 5,064,154,962.67
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.7, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923Problem Solved: 1449.26846575737
# Solution Graph Built: 15.318825721740723
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.8883068561553955
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 106,700,304 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# solar                               22,904.57      12,187.20      35,091.77           94,787.16          1,127.98        95
# wind                                 7,877.07       5,882.00      13,759.07          108,452.25            738.23        52
# oil                                    254.52           0.00         254.52                0.00              0.00         3
# waste                                  755.23           0.00         755.23                0.00              0.00         4
# unknown                            -65,696.95           0.00     -65,696.95                0.00              0.00         8
# steam                                  623.00           0.00         623.00                0.00              0.00         2
# small_hydro                          1,745.64           0.00       1,745.64                0.00              0.00         4
# pump hydro                               0.24           0.00           0.24                0.00              0.00         3
# battery                             15,700.00           0.00      15,700.00          106,267.74              0.00         4
# biomass                                543.70           0.00         543.70                0.00              0.00         2
# natural gas turbine                 13,316.81           0.00      13,316.81                0.00              0.00         5
# natural gas combined cycle          17,963.95           0.00      17,963.95                0.00              0.00         4
# large_hydro                          7,605.89           0.00       7,605.89                0.00              0.00         3
# import                               4,250.00           0.00       4,250.00                0.00              0.00         3
# geothermal                           1,452.33           0.00       1,452.33                0.00              0.00         2
# coal                                    73.30           0.00          73.30                0.00              0.00         2
# non-fossil                             158.20           0.00         158.20                0.00              0.00         4
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              1,957,284.42
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $5,411,102,421.55
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   solar                          $1,127,977,539.89
#   wind                           $ 738,232,160.06
#   TOTAL                          $1,866,209,699.94
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,649,931,731.15
#   natural gas turbine            $ 439,422,040.83
#   biomass                        $ 164,802,125.47
#   steam                          $  62,948,015.87
#   waste                          $  38,043,554.52
#   oil                            $  33,779,079.83
#   geothermal                     $  13,814,732.19
#   coal                           $   8,979,680.29
#   non-fossil                     $   7,902,410.05
#   large_hydro                    $   3,163,401.99
#   small_hydro                    $     118,434.14
#   TOTAL                          $3,422,905,206.34
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WEC_CALN:WECC_SCE              $  35,862,648.89
#   WECC_SCE:WEC_CALN              $  15,982,198.25
#   WECC_SCE:WEC_SDGE              $   5,015,744.85
#   WECC_SCE:WEC_LADW              $   2,847,973.21
#   WEC_LADW:WECC_SCE              $   2,539,146.65
#   WEC_SDGE:WECC_SCE              $   1,067,471.97
#   TOTAL                          $  63,315,183.82
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,352,430,090.10
# Model Objective                $5,411,102,421.55
# Other Gap                      $  58,672,331.44
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WEC_CALN -> WECC_SCE via line_257: 1,245.23 MWh
# WEC_LADW -> WECC_SCE via line_261: 88.16 MWh
# WEC_SDGE -> WECC_SCE via line_266: 37.06 MWh
# WECC_SCE -> WEC_CALN via line_234: 554.94 MWh
# WECC_SCE -> WEC_LADW via line_235: 98.89 MWh
# WECC_SCE -> WEC_SDGE via line_236: 174.16 MWh
#
# Total transmission across all lines: 2,198.44 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# ================================================================================
#
# Parameters Built: 5.20023512840271
# Variables Built: 7.8177759647369385
# Constraints Built: 26.591613292694092
# Objective Built: 3.2148561477661133
#   Scenario   2 ✓
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               95,724.29      17,963.95           0.00      17,963.95         4
# battery                                  27,842.43      15,700.00           0.00      15,700.00         4
# geothermal                               11,909.25       1,452.33           0.00       1,452.33         2
# natural gas turbine                      10,976.01      13,316.81           0.00      13,316.81         5
# large_hydro                               9,330.61       7,605.89           0.00       7,605.89         3
# waste                                     6,026.88         755.23           0.00         755.23         4
# biomass                                   3,414.30         543.70           0.00         543.70         2
# small_hydro                               2,301.48       1,745.64           0.00       1,745.64         4
# oil                                       1,720.03         254.52           0.00         254.52         3
# steam                                     1,627.63         623.00           0.00         623.00         2
# non-fossil                                1,139.17         158.20           0.00         158.20         4
# coal                                        377.07          73.30           0.00          73.30         2
# pump hydro                                    1.31           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -52,160.46       7,877.07       5,882.00      13,759.07        52
# solar                                  -107,487.13      22,904.57      12,187.20      35,091.77        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   1,957,284.42
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 2,022.48 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_LADW:
# ...
# pump hydro                                    1.36           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -65,968.75       7,877.07       9,683.00      17,560.07        52
# solar                                  -138,920.06      22,904.57      22,457.32      45,361.90        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  13,301,437.04
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 890.28 MW
#   Max Shift Down: -444.61 MW
#   Total Shifting: 2,740,596.13 MWh
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 603.41 MW
#   Max Shift Down: -301.34 MW
#   Total Shifting: 2,017,587.96 MWh
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 220.67 MW
#   Max Shift Down: -110.20 MW
#   Total Shifting: 629,379.79 MWh
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 691.03 MW
#   Max Shift Down: -345.10 MW
#   Total Shifting: 2,134,641.46 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_s12_mid_m0_d360/s12_s12_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_s12_mid_m0_d360/s12_s12_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_s12_mid_m0_d360/s12_s12_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_s12_mid_m0_d360/s12_s12_ev_summary.csv
# Finished scenario 12: s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360/s12_V1G_rps70_v1g50_v2g0_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 6,295,352,237.96
#
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              124,190.97      17,963.95           0.00      17,963.95         4
# battery                                  15,446.10      15,700.00           0.00      15,700.00         4
# geothermal                               12,541.45       1,452.33           0.00       1,452.33         2
# large_hydro                              10,995.94       7,605.89           0.00       7,605.89         3
# natural gas turbine                      10,372.21      13,316.81           0.00      13,316.81         5
# waste                                     6,520.72         755.23           0.00         755.23         4
# small_hydro                               2,403.56       1,745.64           0.00       1,745.64         4
# oil                                       2,194.69         254.52           0.00         254.52         3
# ev_v2g                                    1,482.23       7,809.42           0.00       7,809.42         4
# non-fossil                                1,366.17         158.20           0.00         158.20         4
# coal                                        513.61          73.30           0.00          73.30         2
# steam                                       451.46         623.00           0.00         623.00         2
# pump hydro                                    1.37           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# biomass                                       0.00         543.70           0.00         543.70         2
# wind                                    -49,077.74       7,877.07       5,084.90      12,961.98        52
# solar                                   -79,541.58      22,904.57       2,956.10      25,860.67        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_s13_mid_m0_d360/s13_s13_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_s13_mid_m0_d360/s13_s13_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_s13_mid_m0_d360/s13_s13_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_s13_mid_m0_d360/s13_s13_ev_summary.csv
# Finished scenario 13: s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps50_v1g0_v2g50_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 5,006,879,404.28
#
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              100,491.02      17,963.95           0.00      17,963.95         4
# battery                                  21,663.41      15,700.00           0.00      15,700.00         4
# geothermal                               12,355.80       1,452.33           0.00       1,452.33         2
# large_hydro                              10,223.16       7,605.89           0.00       7,605.89         3
# waste                                     6,195.25         755.23           0.00         755.23         4
# natural gas turbine                       5,967.45      13,316.81           0.00      13,316.81         5
# ev_v2g                                    4,531.48       7,809.42           0.00       7,809.42         4
# small_hydro                               2,366.90       1,745.64           0.00       1,745.64         4
# oil                                       1,926.89         254.52           0.00         254.52         3
# non-fossil                                1,235.98         158.20           0.00         158.20         4
# coal                                        413.05          73.30           0.00          73.30         2
# steam                                       248.79         623.00           0.00         623.00         2
# biomass                                     248.16         543.70           0.00         543.70         2
# pump hydro                                    1.24           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -52,160.46       7,877.07       5,882.00      13,759.07        52
# solar                                  -107,966.68      22,904.57      12,300.80      35,205.37        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                     533,752.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_CALN:
#   Installed Capacity: 890.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_LADW:
#   Installed Capacity: 603.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_SDGE:
#   Installed Capacity: 220.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_SCE:
#   Installed Capacity: 691.03 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_s14_mid_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_s14_mid_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_s14_mid_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_s14_mid_m0_d360/s14_s14_ev_summary.csv
# Finished scenario 14: s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_mid_CAISO_flex/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 5,190,676,827.65
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/CAISO/scenario_results_2030_mid_CAISO_flex/all_scenarios_summary.csv
