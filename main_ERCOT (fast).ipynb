# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 3
CPLEX_THREADS_PER_SCENARIO = 40

IPM_REGION = "ERCOT"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)
YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "TX"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/Texas_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 138  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
                      # "mid",
    "fast"
                     ]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    # "arrive": {
    #     "profile": "min_delay",
    #     "description": "Immediate arrival charging",
    # },
    # "flex": {
    #     "profile": "load_leveling",
    #     "description": "Flexible load leveling",
    # },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "ERC_REST": 0.60,
    "ERC_WEST": 0.40,
    "ERC_GWAY": 0.0,
    "ERC_FRNT": 0.0,
    "ERC_PHDL": 0.0,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

ERCOT_REGIONS = [
    "ERC_FRNT",
    "ERC_PHDL",
    "ERC_GWAY",
    "ERC_REST",
    "ERC_WEST",
]

STATE_TO_REGIONS = {
    "TX": ERCOT_REGIONS,
    "ERCOT": ERCOT_REGIONS,
}
RETIREMENT_POLICIES = {
    "TX": {
        "coal": 1 / 3,
    },

    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },

    "CA": {
        "oil": 0.70,
        "nuclear": 1.00,
        "natural gas turbine": 0.20,
        "natural gas combined cycle": 0.04,
        "coal": 1.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "TX": {
        # ERCOT 2030 central logic:
        # Nuclear is small in capacity but high in energy output, so keep it highly must-run.
        # Coal is still meaningful, but do NOT force it at 45% in a 2030 renewable-heavy case.
        # Combined-cycle gas should provide reliability, but not behave as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },
    },

    "CA": {
        # CAISO / California 2030 central logic:
        # Do not add a nuclear constraint unless your GOOD input data explicitly includes CA nuclear.
        # California policy still treats Diablo Canyon as a transition/reliability resource, not a long-run
        # 2030+ baseload expansion resource.
        # Gas must stay flexible because CA has solar-heavy duck-curve conditions.

        # If your GOOD data has a CA "nuclear" category and you are modeling a 2030 week
        # before Diablo Canyon Unit 2 retirement, you may add this sensitivity:
        #
        # "nuclear": {
        #     "must_run_fraction": 0.60,
        #     "ramp_rate": 0.03,
        # },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.08,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "FL": {
        # Florida / FRCC 2030 central logic:
        # Nuclear is baseload.
        # Florida relies heavily on natural gas, especially combined-cycle gas.
        # Coal still exists but should have a low floor because coal retirements and solar growth continue.
        # Oil should not be must-run.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.04,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.18,
            "ramp_rate": 0.18,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.60,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "PJM": {
        # PJM 2030 central logic:
        # Nuclear is large and should remain highly must-run.
        # Coal is still important, but a 45% hourly floor is too high for a 2030 policy/RPS case.
        # Combined-cycle gas is important for reliability and load growth, but it should not be forced
        # as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 17500,
        },
    },

    "CA": {
        "battery": {
            "total_power_mw": 16900,
        },
    },

    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },

    "TX": {
        "battery": {
            "total_power_mw": 17500,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": True,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (fast)
# # Charging scenarios: 1 (midnight)
# # Total combinations: 1
# # Total runs: 15 (= 15 scenarios × 1 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: FAST
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: FAST adoption + Midnight timed charging
# Results Directory: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.6, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.3077588081359863
# Parameters Built: 3.291044235229492
# Parameters Built: 3.3169424533843994
# Variables Built: 1.2462880611419678
# Variables Built: 1.2747588157653809
# Variables Built: 1.2885279655456543
# Constraints Built: 15.598723411560059
# Constraints Built: 15.773353576660156
# Constraints Built: 15.753834009170532
# Objective Built: 1.592177391052246
# Objective Built: 1.5975348949432373
# Objective Built: 1.596982717514038
# Problem Solved: 60.50425052642822
# Solution Graph Built: 5.695882797241211
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.6853330135345459
# Problem Solved: 66.89591550827026
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 135,417,881 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      70,485.91     107,628.41           98,282.12          7,058.64        81
# solar                               36,639.68      41,846.20      78,485.88           87,465.64          3,437.25        59
# battery                             17,500.00       4,800.15      22,300.15          106,267.74            503.11         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -141,195.28           0.00    -141,195.28                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             52,207,653.95
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $16,436,693,547.98
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $7,058,637,869.80
#   solar                          $3,437,245,272.07
#   battery                        $ 503,113,021.25
#   TOTAL                          $10,998,996,163.12
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,974,352,428.19
#   nuclear                        $ 829,638,422.26
#   coal                           $ 685,144,870.21
#   steam                          $  90,530,036.26
#   natural gas turbine            $  31,953,740.02
#   waste                          $  11,230,342.42
#   non-fossil                     $   3,666,563.13
#   biomass                        $     174,451.49
#   oil                            $     160,619.26
#   large_hydro                    $      12,310.68
#   small_hydro                    $       8,479.61
#   TOTAL                          $4,626,872,263.54
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 610,717,095.27
#   ERC_PHDL:ERC_WEST              $ 114,056,149.11
#   ERC_REST:ERC_WEST              $   3,072,456.96
#   ERC_WEST:ERC_PHDL              $       6,770.23
#   TOTAL                          $ 727,852,471.57
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,353,720,898.23
# Model Objective                $16,436,693,547.98
# Other Gap                      $  82,972,649.75
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,960.28 MWh
# ERC_REST -> ERC_WEST via line_5: 106.68 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.24 MWh
# ERC_WEST -> ERC_REST via line_8: 21,205.45 MWh
#
# Total transmission across all lines: 25,272.66 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,600.42      35,044.70           0.00      35,044.70         2
# nuclear                                  41,411.75       4,960.00           0.00       4,960.00         1
# coal                                     30,472.40       8,603.07           0.00       8,603.07         1
# battery                                  22,715.97      17,500.00       4,800.15      22,300.15         3
# steam                                     2,534.21       9,055.70           0.00       9,055.70         2
# waste                                     1,611.79         210.40           0.00         210.40         2
# natural gas turbine                         817.46       8,608.50           0.00       8,608.50         2
# non-fossil                                  528.69          68.80           0.00          68.80         1
# small_hydro                                 300.86         341.10           0.00         341.10         1
# large_hydro                                 180.81         208.00           0.00         208.00         1
# oil                                           8.16           1.40           0.00           1.40         1
# biomass                                       3.29         117.50           0.00         117.50         1
# solar                                  -205,847.73      36,639.68      41,846.20      78,485.88        59
# wind                                   -417,326.90      37,142.50      70,485.91     107,628.41        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  52,207,653.95
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 29.68 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 3,026.15 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 139.45 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_s02_fast_m0_d360/s02_s02_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_s02_fast_m0_d360/s02_s02_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_s02_fast_m0_d360/s02_s02_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_s02_fast_m0_d360/s02_s02_ev_summary.csv
# Solution Graph Built: 5.446705102920532
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Problem Solved: 73.08679699897766
# Solution DataFrame Built: 0.7035727500915527
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 135,401,491 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      70,487.91     107,630.41           98,282.12          7,058.84        81
# solar                               36,639.68      41,849.86      78,489.55           87,465.64          3,437.43        59
# battery                             17,500.00       4,800.35      22,300.35          106,267.74            503.13         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -141,195.28           0.00    -141,195.28                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             52,207,748.42
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $16,436,694,885.15
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $7,058,841,844.15
#   solar                          $3,437,431,393.63
#   battery                        $ 503,134,371.25
#   TOTAL                          $10,999,407,609.04
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,974,026,321.71
#   nuclear                        $ 829,613,644.82
#   coal                           $ 685,246,702.43
#   steam                          $  90,486,543.26
#   natural gas turbine            $  31,905,992.37
#   waste                          $  11,229,854.24
#   non-fossil                     $   3,666,424.53
#   biomass                        $     174,451.49
#   oil                            $     160,430.26
#   large_hydro                    $      12,310.32
#   small_hydro                    $       8,479.58
#   TOTAL                          $4,626,531,155.02
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 610,674,098.48
#   ERC_PHDL:ERC_WEST              $ 114,029,080.46
#   ERC_REST:ERC_WEST              $   3,072,724.39
#   ERC_WEST:ERC_PHDL              $       6,770.23
#   TOTAL                          $ 727,782,673.56
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,353,721,437.61
# Model Objective                $16,436,694,885.15
# Other Gap                      $  82,973,447.54
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,959.34 MWh
# ERC_REST -> ERC_WEST via line_5: 106.69 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.24 MWh
# ERC_WEST -> ERC_REST via line_8: 21,203.96 MWh
#
# Total transmission across all lines: 25,270.23 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,585.26      35,044.70           0.00      35,044.70         2
# nuclear                                  41,410.51       4,960.00           0.00       4,960.00         1
# coal                                     30,476.92       8,603.07           0.00       8,603.07         1
# battery                                  22,718.02      17,500.00       4,800.35      22,300.35         3
# steam                                     2,533.00       9,055.70           0.00       9,055.70         2
# waste                                     1,611.72         210.40           0.00         210.40         2
# natural gas turbine                         816.23       8,608.50           0.00       8,608.50         2
# non-fossil                                  528.67          68.80           0.00          68.80         1
# small_hydro                                 300.85         341.10           0.00         341.10         1
# large_hydro                                 180.81         208.00           0.00         208.00         1
# oil                                           8.15           1.40           0.00           1.40         1
# biomass                                       3.29         117.50           0.00         117.50         1
# solar                                  -205,855.48      36,639.68      41,849.86      78,489.55        59
# wind                                   -417,334.01      37,142.50      70,487.91     107,630.41        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  52,207,748.42
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 29.68 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 3,026.15 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 139.45 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s03_s03_fast_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s03_s03_fast_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s03_s03_fast_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s03_s03_fast_m0_d360/s03_s03_ev_summary.csv
# Solution Graph Built: 5.412034749984741
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Finished scenario 2: s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 16,436,693,547.98
#   Scenario   2 ✓
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Solution DataFrame Built: 0.7060225009918213
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 135,232,620 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      70,486.05     107,628.55           98,282.12          7,058.65        81
# solar                               36,639.68      41,853.30      78,492.98           87,465.64          3,437.67        59
# battery                             17,500.00       4,800.48      22,300.48          106,267.74            503.15         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -141,195.28           0.00    -141,195.28                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             52,196,573.92
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $16,436,694,547.81
#
# Parameters Built: 3.389317750930786
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $7,058,652,119.12
#   solar                          $3,437,673,850.46
#   battery                        $ 503,147,574.67
#   TOTAL                          $10,999,473,544.25
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,970,297,614.26
#   nuclear                        $ 828,911,842.16
#   coal                           $ 689,024,589.99
#   steam                          $  91,027,627.16
#   natural gas turbine            $  31,899,293.09
#   waste                          $  11,239,491.52
#   non-fossil                     $   3,658,358.94
#   biomass                        $     180,681.90
#   oil                            $     160,291.96
#   large_hydro                    $      12,310.68
#   small_hydro                    $       8,479.80
#   TOTAL                          $4,626,420,581.46
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 610,724,435.52
#   ERC_PHDL:ERC_WEST              $ 114,033,009.87
#   ERC_REST:ERC_WEST              $   3,063,270.56
#   ERC_WEST:ERC_PHDL              $       6,770.23
#   TOTAL                          $ 727,827,486.18
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,353,721,611.89
# ...
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 14.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 14.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,513.08 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 1,513.08 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 69.72 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 69.72 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_s14_fast_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_s14_fast_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_s14_fast_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_s14_fast_m0_d360/s14_s14_ev_summary.csv
# Finished scenario 14: s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 15,934,781,202.00
#   Scenario  14 ✓
# Problem Solved: 106.28490447998047
# Solution Graph Built: 7.642080068588257
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.7187602519989014
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 15 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 132,838,569 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      70,086.15     107,228.65           98,282.12          7,018.04        81
# solar                               36,639.68      43,344.15      79,983.83           87,465.64          3,557.00        59
# battery                             17,500.00           0.00      17,500.00          106,267.74              0.00         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# ev_v2g                              15,618.40           0.00      15,618.40                0.00              0.00         3
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -141,195.28           0.00    -141,195.28                0.00              0.00         8
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,847,654.94
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 15
# ====================================================================================================
#
# Total Objective: $15,934,781,742.07
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $7,018,040,618.57
#   solar                          $3,557,000,165.64
#   TOTAL                          $10,575,040,784.21
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,918,818,859.38
#   nuclear                        $ 828,486,451.95
#   coal                           $ 685,102,380.48
#   steam                          $  84,821,240.18
#   natural gas turbine            $  29,678,652.12
#   waste                          $  11,147,518.28
#   non-fossil                     $   3,641,080.52
#   biomass                        $     216,561.85
#   oil                            $     156,745.20
#   large_hydro                    $      12,265.14
#   small_hydro                    $       8,406.38
#   TOTAL                          $4,562,090,161.49
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 589,848,986.02
#   ERC_PHDL:ERC_WEST              $ 120,873,060.87
#   ERC_REST:ERC_WEST              $   2,905,178.59
#   ERC_WEST:ERC_PHDL              $          59.82
#   TOTAL                          $ 713,627,285.30
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $15,850,758,231.00
# Model Objective                $15,934,781,742.07
# Other Gap                      $  84,023,511.08
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 4,196.98 MWh
# ERC_REST -> ERC_WEST via line_5: 100.87 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.00 MWh
# ERC_WEST -> ERC_REST via line_8: 20,480.87 MWh
#
# Total transmission across all lines: 24,778.73 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              132,080.35      35,044.70           0.00      35,044.70         2
# nuclear                                  41,354.25       4,960.00           0.00       4,960.00         1
# coal                                     30,470.51       8,603.07           0.00       8,603.07         1
# battery                                  19,407.06      17,500.00           0.00      17,500.00         3
# steam                                     2,373.88       9,055.70           0.00       9,055.70         2
# ev_v2g                                    1,887.65       3,904.60           0.00       3,904.60         3
# waste                                     1,599.91         210.40           0.00         210.40         2
# natural gas turbine                         758.22       8,608.50           0.00       8,608.50         2
# non-fossil                                  525.02          68.80           0.00          68.80         1
# small_hydro                                 298.26         341.10           0.00         341.10         1
# large_hydro                                 180.15         208.00           0.00         208.00         1
# oil                                           7.97           1.40           0.00           1.40         1
# biomass                                       4.08         117.50           0.00         117.50         1
# solar                                  -209,190.26      36,639.68      43,344.15      79,983.83        59
# wind                                   -415,911.94      37,142.50      70,086.15     107,228.65        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  51,847,654.94
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 14.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 14.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,513.08 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 1,513.08 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 69.72 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 69.72 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_s15_fast_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_s15_fast_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_s15_fast_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_s15_fast_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 15: s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 15,934,781,742.07
#   Scenario  15 ✓
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/ERCOT/scenario_results_2030_fast_ERCOT_midnight/all_scenarios_summary.csv
