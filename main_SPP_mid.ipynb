# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 50
IPM_REGION = "SPP"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    # "slow",
    "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

SPP_REGIONS = [
    "SPP_KIAM",
    "SPP_N",
    "SPP_NEBR",
    "SPP_SPS",
    "SPP_WAUE",
    "SPP_WEST",
]

STATE_TO_REGIONS = {
    "SPP": SPP_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EPA NEEDS active battery capacity
#
# SPP_KIAM     0.0 MW
# SPP_N        2.2 MW
# SPP_NEBR     2.9 MW
# SPP_SPS    256.0 MW
# SPP_WAUE     0.8 MW
# SPP_WEST   222.0 MW
#
# Total      483.9 MW
#
# Pumped storage is excluded because these weights are
# specifically for battery storage.

BATTERY_WEIGHTS = {
    "SPP_KIAM": 0.0000,
    "SPP_N": 0.0045,
    "SPP_NEBR": 0.0060,
    "SPP_SPS": 0.5290,
    "SPP_WAUE": 0.0017,
    "SPP_WEST": 0.4588,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# Fractions are calculated from explicit 2029–2030
# retirement years in the EPA NEEDS active-resource sheet.
#
# Units already placed in the NEEDS "retire by 2028" sheet
# are not part of the active fleet and are therefore not
# retired again here.

RETIREMENT_POLICIES = {
    "SPP": {
        # 1,736 MW scheduled retirement
        # from 17,968.5 MW of active coal capacity.
        "coal": 0.0966,

        # 219 MW scheduled retirement
        # from 9,546.9 MW of active O/G steam capacity.
        "oil": 0.0229,

        # 20.3 MW scheduled retirement
        # from 13,472.5 MW of combustion-turbine capacity.
        "natural gas turbine": 0.0015,

        # No explicit retirement through 2030.
        "natural gas combined cycle": 0.00,

        # No explicit retirement through 2030.
        "nuclear": 0.00,
    }
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "SPP": {
        # SPP 2030 central logic:
        #
        # SPP has a large wind fleet together with substantial
        # coal and natural-gas capacity.
        #
        # Nuclear remains highly must-run.
        #
        # Coal retains a limited minimum-output requirement,
        # but the floor is kept low to accommodate high wind output.
        #
        # Combined-cycle gas provides reliability while retaining
        # enough flexibility to respond to changing wind generation.
        #
        # Combustion turbines and O/G steam units are not forced
        # online because they mainly provide peaking and reliability
        # support.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 488,
        },
    },
    "MISO": {
        "battery": {
            "total_power_mw": 488,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "MISO": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "MISO": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 2 (mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 8
# # Total runs: 120 (= 15 scenarios × 8 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: MID
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: MID adoption + Midnight timed charging
# Results Directory: Output/SPP/scenario_results_2030_mid_SPP_midnight
# ================================================================================
#
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.05, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.4, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.05, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.4, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7Base load peak scaling is OFF. Using original graph load.
#
# ================================================================================
#
# EV profile market key: SPP
# Created RPS policies:
#   rps_SPP_MO: ratio=0.15, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.5, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.15, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.5, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.25, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.6, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
# Missing EV profiles for these regions:
# ['SPP_KIAM']
# Missing EV profiles for these regions:
# ['SPP_KIAM']
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# coal retirement summary
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# Processed 477 renewable plants with capex
# Retired fraction : 9.66%
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# Skipped 25 renewable plants (no valid capex_cost)
#
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2================================================================================
#
#
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3Capacity before  : 19,770.02 MW
#
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5Capacity after   : 17,860.24 MW
#
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MWcoal retirement summary
#
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.262316703796387
# Parameters Built: 12.449199914932251
# Parameters Built: 12.45871376991272
# Parameters Built: 12.470272779464722
# Parameters Built: 12.573805809020996
# Variables Built: 5.423588514328003
# Variables Built: 5.429610252380371
# Variables Built: 5.436690092086792
# Variables Built: 5.485219955444336
# Variables Built: 5.479163646697998
# Constraints Built: 45.69181442260742
# Constraints Built: 45.63784623146057
# Constraints Built: 45.76018452644348
# Constraints Built: 46.99142575263977
# Constraints Built: 47.14361023902893
# Objective Built: 2.510638952255249
# Objective Built: 2.4886703491210938
# Objective Built: 2.5240931510925293
# Objective Built: 5.193216323852539
# Objective Built: 5.238781213760376
# Problem Solved: 558.6043610572815
# Solution Graph Built: 44.57932257652283
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.7030112743377686
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 4 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 32,861,979 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,765.56      36,310.16          102,983.77            196.26       299
# solar                               14,821.17       1,566.75      16,387.92           85,776.13            129.53       203
# battery                                488.00         360.10         848.10          106,267.74             37.74         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,154.51           0.00     -55,154.51                0.00              0.00        15
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,568,143.02
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 4
# ====================================================================================================
#
# Total Objective: $2,685,191,231.33
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 196,260,405.54
#   solar                          $ 129,525,259.03
#   battery                        $  37,743,026.53
#   TOTAL                          $ 363,528,691.10
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 992,706,396.09
#   natural gas combined cycle     $ 702,727,573.36
#   nuclear                        $ 291,078,793.76
#   steam                          $  52,681,883.97
#   natural gas turbine            $  36,795,368.44
#   oil                            $  30,135,333.99
#   waste                          $   3,473,973.18
#   large_hydro                    $   2,722,106.75
#   non-fossil                     $   1,242,498.75
#   small_hydro                    $      93,041.41
#   biomass                        $         551.46
#   TOTAL                          $2,113,657,521.17
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   SPP_N:SPP_WEST                 $  58,799,323.56
#   SPP_SPS:SPP_WEST               $  27,629,933.11
#   SPP_NEBR:SPP_N                 $  23,056,570.33
#   SPP_NEBR:SPP_WAUE              $  21,428,661.41
#   SPP_WEST:SPP_SPS               $  16,025,911.56
#   SPP_WEST:SPP_N                 $  14,070,096.62
#   SPP_N:SPP_NEBR                 $  13,980,741.40
#   SPP_WAUE:SPP_NEBR              $  12,743,793.40
#   SPP_N:SPP_SPS                  $   9,134,784.56
#   SPP_SPS:SPP_N                  $   7,934,631.89
#   TOTAL                          $ 204,804,447.84
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $2,681,990,660.10
# Model Objective                $2,685,191,231.33
# Other Gap                      $   3,200,571.22
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# SPP_NEBR -> SPP_N via line_154: 800.58 MWh
# SPP_NEBR -> SPP_WAUE via line_155: 744.05 MWh
# SPP_N -> SPP_NEBR via line_149: 485.44 MWh
# SPP_N -> SPP_WEST via line_151: 2,041.64 MWh
# SPP_N -> SPP_SPS via line_150: 317.18 MWh
# SPP_WEST -> SPP_N via line_168: 488.55 MWh
# SPP_WEST -> SPP_SPS via line_169: 556.46 MWh
# SPP_SPS -> SPP_N via line_156: 275.51 MWh
# SPP_SPS -> SPP_WEST via line_157: 959.37 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 442.49 MWh
#
# Total transmission across all lines: 7,111.27 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     50,203.11      17,860.24           0.00      17,860.24         9
# natural gas combined cycle               31,797.06       9,888.90           0.00       9,888.90        10
# nuclear                                  16,062.05       1,995.00           0.00       1,995.00         2
# large_hydro                               9,078.99       4,148.60           0.00       4,148.60         9
# battery                                   2,939.70         488.00         360.10         848.10         5
# steam                                     1,538.00       4,989.40           0.00       4,989.40         9
# small_hydro                               1,354.62         678.00           0.00         678.00         5
# oil                                       1,160.47         780.90           0.00         780.90        11
# natural gas turbine                       1,064.92      10,264.08           0.00      10,264.08        17
# waste                                       501.10          97.42           0.00          97.42        15
# non-fossil                                  179.11          40.80           0.00          40.80         2
# pump hydro                                    0.26           0.03           0.00           0.03         3
# biomass                                       0.01          10.40           0.00          10.40         2
# solar                                   -42,349.31      14,821.17       1,566.75      16,387.92       203
# wind                                   -137,219.08      34,544.60       1,765.56      36,310.16       299
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  10,568,143.02
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 203
# Wind assets found : 299
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_SPP_NEBR:
#   Installed Capacity: 153.60 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_NEBR:
#   Installed Capacity: 51.20 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 51.20 MW
#   Max Shift Down: -25.41 MW
#   Total Shifting: 117,093.78 MWh
#
# ev_load_fixed_SPP_N:
#   Installed Capacity: 380.82 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_N:
#   Installed Capacity: 126.94 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 126.94 MW
#   Max Shift Down: -63.44 MW
#   Total Shifting: 277,437.51 MWh
#
# ev_load_fixed_SPP_WEST:
#   Installed Capacity: 343.64 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WEST:
#   Installed Capacity: 114.55 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 114.55 MW
#   Max Shift Down: -57.10 MW
#   Total Shifting: 239,197.33 MWh
#
# ev_load_fixed_SPP_SPS:
#   Installed Capacity: 64.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_SPS:
#   Installed Capacity: 21.59 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 21.59 MW
#   Max Shift Down: -10.66 MW
#   Total Shifting: 44,265.91 MWh
#
# ev_load_fixed_SPP_WAUE:
#   Installed Capacity: 55.56 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WAUE:
#   Installed Capacity: 18.52 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 18.52 MW
#   Max Shift Down: -9.26 MW
#   Total Shifting: 44,089.22 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_s04_mid_m0_d360/s04_s04_cost_components.csv
# Capex detail CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_s04_mid_m0_d360/s04_s04_capex_detail.csv
# Capex summary CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_s04_mid_m0_d360/s04_s04_capex_summary.csv
# EV summary CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_s04_mid_m0_d360/s04_s04_ev_summary.csv
# Finished scenario 4: s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360
# Solution JSON: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360/s04_V1G_rps-10_v1g25_v2g0_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 2,685,191,231.33
#   Scenario   4 ✓
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.25, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.6, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.53695797920227
# Variables Built: 4.0890703201293945
# Problem Solved: 695.6501126289368
# Problem Solved: 725.9776837825775
# Constraints Built: 59.295854568481445
# Objective Built: 2.639913320541382
# Solution Graph Built: 41.114506244659424
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.6427409648895264
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 10.0%
# ============================================================================================================================================
#
# Gas Generation: 32,779,920 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,661.68      36,206.28          102,983.77            185.27       299
# solar                               14,821.17       1,545.97      16,367.15           85,776.13            127.81       203
# battery                                488.00         724.53       1,212.53          106,267.74             75.94         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,154.51           0.00     -55,154.51                0.00              0.00        10
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,149,115.42
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $2,710,156,277.24
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 185,266,249.83
#   solar                          $ 127,807,768.79
#   battery                        $  75,938,935.73
#   TOTAL                          $ 389,012,954.36
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 999,465,555.33
#   natural gas combined cycle     $ 702,931,517.09
#   nuclear                        $ 291,118,190.45
#   steam                          $  48,805,099.92
#   natural gas turbine            $  33,360,704.66
#   oil                            $  30,227,964.51
#   waste                          $   3,498,882.79
#   large_hydro                    $   2,735,688.78
#   non-fossil                     $   1,246,823.23
#   small_hydro                    $      93,562.83
#   biomass                        $         821.36
#   TOTAL                          $2,113,484,810.94
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   SPP_N:SPP_WEST                 $  57,881,090.64
#   SPP_SPS:SPP_WEST               $  27,510,338.30
#   SPP_NEBR:SPP_N                 $  23,371,561.85
#   SPP_NEBR:SPP_WAUE              $  21,274,119.65
#   SPP_WEST:SPP_SPS               $  15,483,791.90
#   SPP_WEST:SPP_N                 $  13,980,232.26
#   SPP_N:SPP_NEBR                 $  13,800,018.42
#   SPP_WAUE:SPP_NEBR              $  12,874,045.90
#   SPP_N:SPP_SPS                  $   8,944,902.17
#   SPP_SPS:SPP_N                  $   7,963,360.50
#   TOTAL                          $ 203,083,461.59
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $2,705,581,226.89
# Model Objective                $2,710,156,277.24
# Other Gap                      $   4,575,050.35
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# SPP_NEBR -> SPP_N via line_154: 811.51 MWh
# SPP_NEBR -> SPP_WAUE via line_155: 738.68 MWh
# SPP_N -> SPP_NEBR via line_149: 479.17 MWh
# SPP_N -> SPP_WEST via line_151: 2,009.76 MWh
# SPP_N -> SPP_SPS via line_150: 310.59 MWh
# SPP_WEST -> SPP_N via line_168: 485.42 MWh
# SPP_WEST -> SPP_SPS via line_169: 537.63 MWh
# SPP_SPS -> SPP_N via line_156: 276.51 MWh
# SPP_SPS -> SPP_WEST via line_157: 955.22 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 447.02 MWh
#
# Total transmission across all lines: 7,051.51 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     50,542.46      17,860.24           0.00      17,860.24         9
# natural gas combined cycle               31,813.25       9,888.90           0.00       9,888.90        10
# nuclear                                  16,064.23       1,995.00           0.00       1,995.00         2
# large_hydro                               9,124.52       4,148.60           0.00       4,148.60         9
# battery                                   4,166.81         488.00         724.53       1,212.53         5
# steam                                     1,423.93       4,989.40           0.00       4,989.40         9
# small_hydro                               1,362.23         678.00           0.00         678.00         5
# oil                                       1,164.83         780.90           0.00         780.90        11
# natural gas turbine                         966.67      10,264.08           0.00      10,264.08        17
# waste                                       504.69          97.42           0.00          97.42        15
# non-fossil                                  179.74          40.80           0.00          40.80         2
# pump hydro                                    0.25           0.03           0.00           0.03         3
# biomass                                       0.02          10.40           0.00          10.40         2
# solar                                   -42,298.70      14,821.17       1,545.97      16,367.15       203
# wind                                   -136,850.67      34,544.60       1,661.68      36,206.28       299
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  10,149,115.42
# ...
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 13.218122482299805
# Variables Built: 4.316466569900513
# Constraints Built: 68.23094487190247
# Objective Built: 6.279839277267456
# Problem Solved: 696.1499397754669
# Solution Graph Built: 44.103193044662476
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.6689951419830322
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 11 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 32,830,014 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,731.53      36,276.13          102,983.77            192.66       299
# solar                               14,821.17       1,547.92      16,369.10           85,776.13            127.97       203
# battery                                488.00         361.51         849.51          106,267.74             37.89         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,154.51           0.00     -55,154.51                0.00              0.00        15
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,401,580.74
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 11
# ====================================================================================================
#
# Total Objective: $2,676,851,712.62
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 192,658,425.84
#   solar                          $ 127,969,060.82
#   battery                        $  37,890,468.23
#   TOTAL                          $ 358,517,954.88
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 993,910,285.27
#   natural gas combined cycle     $ 702,880,694.40
#   nuclear                        $ 291,053,767.56
#   steam                          $  50,412,015.13
#   natural gas turbine            $  35,079,861.22
#   oil                            $  30,077,252.83
#   waste                          $   3,486,520.79
#   large_hydro                    $   2,729,619.25
#   non-fossil                     $   1,245,916.71
#   small_hydro                    $      93,489.06
#   biomass                        $         265.12
#   TOTAL                          $2,110,969,687.34
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   SPP_N:SPP_WEST                 $  58,388,833.96
#   SPP_SPS:SPP_WEST               $  27,702,700.62
#   SPP_NEBR:SPP_N                 $  23,065,114.29
#   SPP_NEBR:SPP_WAUE              $  21,409,795.23
#   SPP_WEST:SPP_SPS               $  16,007,050.73
#   SPP_WEST:SPP_N                 $  13,912,520.61
#   SPP_N:SPP_NEBR                 $  13,797,479.32
#   SPP_WAUE:SPP_NEBR              $  12,754,345.02
#   SPP_N:SPP_SPS                  $   9,132,817.00
#   SPP_SPS:SPP_N                  $   7,987,823.82
#   TOTAL                          $ 204,158,480.59
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $2,673,646,122.81
# Model Objective                $2,676,851,712.62
# Other Gap                      $   3,205,589.81
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# SPP_NEBR -> SPP_N via line_154: 800.87 MWh
# SPP_NEBR -> SPP_WAUE via line_155: 743.40 MWh
# SPP_N -> SPP_NEBR via line_149: 479.08 MWh
# SPP_N -> SPP_WEST via line_151: 2,027.39 MWh
# SPP_N -> SPP_SPS via line_150: 317.11 MWh
# SPP_WEST -> SPP_N via line_168: 483.07 MWh
# SPP_WEST -> SPP_SPS via line_169: 555.80 MWh
# SPP_SPS -> SPP_N via line_156: 277.35 MWh
# SPP_SPS -> SPP_WEST via line_157: 961.90 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 442.86 MWh
#
# Total transmission across all lines: 7,088.84 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# Problem Solved: 575.8056738376617
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     50,266.15      17,860.24           0.00      17,860.24         9
# natural gas combined cycle               31,813.00       9,888.90           0.00       9,888.90        10
# nuclear                                  16,060.67       1,995.00           0.00       1,995.00         2
# large_hydro                               9,105.80       4,148.60           0.00       4,148.60         9
# battery                                   2,931.20         488.00         361.51         849.51         5
# steam                                     1,472.39       4,989.40           0.00       4,989.40         9
# small_hydro                               1,361.10         678.00           0.00         678.00         5
# oil                                       1,159.38         780.90           0.00         780.90        11
# natural gas turbine                       1,017.01      10,264.08           0.00      10,264.08        17
# waste                                       502.91          97.42           0.00          97.42        15
# non-fossil                                  179.60          40.80           0.00          40.80         2
# pump hydro                                    0.26           0.03           0.00           0.03         3
# biomass                                       0.01          10.40           0.00          10.40         2
# solar                                   -42,303.45      14,821.17       1,547.92      16,369.10       203
# wind                                   -137,098.38      34,544.60       1,731.53      36,276.13       299
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  10,401,580.74
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 203
# Wind assets found : 299
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_SPP_NEBR:
#   Installed Capacity: 102.40 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_NEBR:
#   Installed Capacity: 102.40 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 102.40 MW
#   Max Shift Down: -50.81 MW
#   Total Shifting: 232,233.45 MWh
#
# ev_load_fixed_SPP_N:
#   Installed Capacity: 253.88 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_N:
#   Installed Capacity: 253.88 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 253.88 MW
#   Max Shift Down: -126.89 MW
#   Total Shifting: 550,101.17 MWh
#
# ev_load_fixed_SPP_WEST:
#   Installed Capacity: 229.09 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WEST:
#   Installed Capacity: 229.09 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 229.09 MW
#   Max Shift Down: -114.20 MW
#   Total Shifting: 474,640.99 MWh
#
# ev_load_fixed_SPP_SPS:
#   Installed Capacity: 43.19 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_SPS:
#   Installed Capacity: 43.19 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 43.19 MW
#   Max Shift Down: -21.32 MW
#   Total Shifting: 88,685.78 MWh
#
# ev_load_fixed_SPP_WAUE:
#   Installed Capacity: 37.04 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WAUE:
#   Installed Capacity: 37.04 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 37.04 MW
#   Max Shift Down: -18.51 MW
#   Total Shifting: 87,293.90 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s11_s11_mid_m0_d360/s11_s11_cost_components.csv
# Capex detail CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s11_s11_mid_m0_d360/s11_s11_capex_detail.csv
# Capex summary CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s11_s11_mid_m0_d360/s11_s11_capex_summary.csv
# EV summary CSV: Output/SPP/scenario_results_2030_mid_SPP_midnight/s11_s11_mid_m0_d360/s11_s11_ev_summary.csv
