# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 50
IPM_REGION = "NWPP"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    # "slow",
    # "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    # "midnight": {
    #     "profile": "timed_charging",
    #     "description": "Midnight timed charging",
    # },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}
# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

NWPP_REGIONS = [
    "WECC_MT",
    "WEC_BANC",
    "WECC_ID",
    "WECC_NNV",
    "WECC_SNV",
    "WECC_UT",
    "WECC_PNW",
]

STATE_TO_REGIONS = {
    "NWPP": NWPP_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EIA-860M operating battery capacity, June 2026:
#
# WECC_MT        0.0 MW
# WEC_BANC       0.0 MW
# WECC_ID      659.0 MW
# WECC_NNV     210.0 MW
# WECC_SNV   1,494.0 MW
# WECC_UT      920.0 MW
# WECC_PNW     527.0 MW
#
# Total      3,810.0 MW
#
# These totals include generators whose EIA technology is
# "Batteries" and whose status is "(OP) Operating."
#
# Pumped-storage hydro, planned batteries, and out-of-service
# batteries are excluded.
#
# EIA reports approximately 12,183.8 MWh of associated energy
# capacity for these operating batteries.

BATTERY_WEIGHTS = {
    "WECC_MT": 0.0000,
    "WEC_BANC": 0.0000,
    "WECC_ID": 0.1730,
    "WECC_NNV": 0.0551,
    "WECC_SNV": 0.3921,
    "WECC_UT": 0.2415,
    "WECC_PNW": 0.1383,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# Thermal capacity in the EPA NEEDS active fleet:
#
# Coal steam:            4,458.0 MW
# O/G steam:               563.0 MW
# Combustion turbine:     4,374.1 MW
# Combined cycle:        14,587.2 MW
# Nuclear:                1,151.0 MW
#
# The latest EPA NEEDS active-resource sheet does not contain
# an explicit 2029–2030 retirement for coal, O/G steam,
# combustion turbines, or nuclear in these seven regions.
#
# EIA-860M identifies one combined-cycle facility with a
# planned 2030 retirement:
#
# Nevada Cogen Associates 2 Black Mountain:
#     GTA: 21.7 MW in the model
#     GTB: 21.7 MW in the model
#     GTC: 21.7 MW in the model
#     STM: 28.0 MW in the model
#
# EIA's current nameplate capacity is 96.3 MW. The fraction
# below uses the current EIA retirement capacity divided by
# the model's active combined-cycle capacity.

RETIREMENT_POLICIES = {
    "NWPP": {
        # The previous 2030 retirement assumption for the
        # 458 MW Bonanza coal plant is no longer included in
        # the latest EPA NEEDS release. The owner is pursuing
        # continued operation with additional controls.
        "coal": 0.0000,

        # No explicit O/G steam retirement through 2030.
        "oil": 0.0000,

        # No explicit combustion-turbine retirement through 2030.
        "natural gas turbine": 0.0000,

        # Nevada Cogen Associates 2:
        #
        # 96.3 / 14,587.2 MW
        "natural gas combined cycle": 0.0066,

        # Columbia Generating Station remains active beyond 2030.
        "nuclear": 0.0000,
    }
}


# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "NWPP": {
        # NWPP 2030 central assumptions:
        #
        # The region has approximately:
        #
        # Hydro:                 36,879.7 MW
        # Combined cycle:       14,587.2 MW
        # Wind:                 10,610.4 MW
        # Solar:                 9,554.8 MW
        # Coal:                  4,458.0 MW
        # Combustion turbine:    4,374.1 MW
        # Nuclear:               1,151.0 MW
        # O/G steam:               563.0 MW
        #
        # Columbia Generating Station is the region's nuclear
        # plant and is represented as a highly committed resource.
        #
        # Coal is concentrated in Montana and Utah. A 15%
        # aggregated floor represents partial fleet commitment
        # without forcing all coal units online during periods
        # of high hydro, wind, or solar generation.
        #
        # Combined-cycle gas receives a smaller 8% floor because
        # NWPP has substantial hydroelectric flexibility.
        #
        # Combustion turbines are peaking resources and receive
        # no must-run floor.
        #
        # All 563 MW in the NEEDS O/G steam category is gas-fired
        # steam capacity. The 10% floor represents a limited
        # committed portion of this fleet. The 8% hourly limit
        # is an aggregated commitment/startup approximation.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 12183,
        },
    },
    "NWPP": {
        "battery": {
            "total_power_mw": 12183,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "NWPP": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "NWPP": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (fast)
# # Charging scenarios: 2 (arrive, flex)
# # Total combinations: 2
# # Total runs: 30 (= 15 scenarios × 2 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: FAST
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: FAST adoption + Immediate arrival charging
# Results Directory: Output/NWPP/scenario_results_2030_fast_NWPP_arrive
# ================================================================================
#
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.5, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.4, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.12178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.05, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ================================================================================
#
# natural gas combined cycle retirement summary
# Retired fraction : 0.66%
# Capacity before  : 14,395.60 MW
# Capacity after   : 14,300.59 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 141
# Exact duplicate groups: 8
# Assets contained in duplicate groups: 17
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 132
# ================================================================================
#
# Largest exact groups:
# WECC_NNV     | NV  | solar  | assets=  3 | profile=WECC_NNV:solar:5
# WECC_MT      | MT  | solar  | assets=  2 | profile=WECC_MT:solar:2
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WECC_ID      | ID  | solar  | assets=  2 | profile=WECC_ID:solar:3
# WECC_NNV     | NV  | solar  | assets=  2 | profile=WECC_NNV:solar:4
# WECC_SNV     | NV  | solar  | assets=  2 | profile=WECC_SNV:solar:5
# WECC_UT      | UT  | solar  | assets=  2 | profile=WECC_UT:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NWPP_CA excluded   generator                     import           CA         False            1  1550.000000
# rps_NWPP_CA excluded   generator natural gas combined cycle           CA         False            1  1175.193605
# rps_NWPP_CA excluded   generator        natural gas turbine           CA         False            3   530.839462
# rps_NWPP_CA excluded   generator                        oil           CA         False            1    12.000000
# rps_NWPP_CA excluded large_hydro                large_hydro           CA         False            1   665.800000
# rps_NWPP_CA included   generator                    biomass           CA          True            1     9.000000
# rps_NWPP_CA included   generator                      waste           CA          True            1    27.868724
# rps_NWPP_CA included small_hydro                small_hydro           CA          True            2   129.900000
# rps_NWPP_CA included       solar                      solar           CA          True           37  1402.242294
# rps_NWPP_CA included        wind                       wind           CA          True           12     0.000000
# rps_NWPP_NV excluded   generator                       coal           NV         False            1   218.000000
# rps_NWPP_NV excluded   generator natural gas combined cycle           NV         False            2  4784.611760
# rps_NWPP_NV excluded   generator        natural gas turbine           NV         False            2  1517.585572
# rps_NWPP_NV excluded   generator                 non-fossil           NV         False            1     6.500000
# rps_NWPP_NV excluded   generator                      steam           NV         False            1   334.000000
# rps_NWPP_NV excluded large_hydro                large_hydro           NV         False            1  1037.000000
# rps_NWPP_NV included   generator                      waste           NV          True            2    13.273396
# rps_NWPP_NV included  geothermal                 geothermal           NV          True            1   604.300000
# rps_NWPP_NV included small_hydro                small_hydro           NV          True            2    14.400000
# rps_NWPP_NV included       solar                      solar           NV          True           44  8068.958374
# rps_NWPP_NV included        wind                       wind           NV          True            1   150.000000
# rps_NWPP_OR excluded   generator natural gas combined cycle           OR         False            1  3360.572860
# rps_NWPP_OR excluded   generator        natural gas turbine           OR         False            1  1111.556595
# rps_NWPP_OR excluded   generator                 non-fossil           OR         False            1     9.000000
# rps_NWPP_OR excluded   generator                        oil           OR         False            1   394.800000
# rps_NWPP_OR excluded large_hydro                large_hydro           OR         False            1  7707.199999
# rps_NWPP_OR included   generator                    biomass           OR          True            1   127.700000
# rps_NWPP_OR included   generator                      waste           OR          True            1    47.200000
# rps_NWPP_OR included  geothermal                 geothermal           OR          True            1    19.500000
# rps_NWPP_OR included small_hydro                small_hydro           OR          True            1   682.000001
# rps_NWPP_OR included       solar                      solar           OR          True           15  5134.261172
# rps_NWPP_OR included        wind                       wind           OR          True           19  4310.200000
# rps_NWPP_WA excluded   generator natural gas combined cycle           WA         False            1  2618.205040
# rps_NWPP_WA excluded   generator        natural gas turbine           WA         False            1  2105.395783
# rps_NWPP_WA excluded   generator                 non-fossil           WA         False            1   107.700000
# rps_NWPP_WA excluded   generator                    nuclear           WA         False            1  1163.000000
# rps_NWPP_WA excluded   generator                        oil           WA         False            1     3.500000
# rps_NWPP_WA excluded large_hydro                large_hydro           WA         False            1 20174.500000
# rps_NWPP_WA included   generator                    biomass           WA          True            1   102.700000
# rps_NWPP_WA included   generator                      waste           WA          True            1    95.286403
# rps_NWPP_WA included small_hydro                small_hydro           WA          True            1  1070.000000
# rps_NWPP_WA included       solar                      solar           WA          True            8  6356.107143
# rps_NWPP_WA included        wind                       wind           WA          True           13  3539.900000
# ================================================================================
#
# Parameters Built: 6.526914358139038
# Variables Built: 4.660862684249878
# Constraints Built: 35.67092728614807
# Objective Built: 5.030767202377319
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.6, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.5, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.22178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.15, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ================================================================================
#
# natural gas combined cycle retirement summary
# Retired fraction : 0.66%
# Capacity before  : 14,395.60 MW
# Capacity after   : 14,300.59 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 141
# Exact duplicate groups: 8
# Assets contained in duplicate groups: 17
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 132
# ================================================================================
#
# Largest exact groups:
# WECC_NNV     | NV  | solar  | assets=  3 | profile=WECC_NNV:solar:5
# WECC_MT      | MT  | solar  | assets=  2 | profile=WECC_MT:solar:2
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WECC_ID      | ID  | solar  | assets=  2 | profile=WECC_ID:solar:3
# WECC_NNV     | NV  | solar  | assets=  2 | profile=WECC_NNV:solar:4
# WECC_SNV     | NV  | solar  | assets=  2 | profile=WECC_SNV:solar:5
# WECC_UT      | UT  | solar  | assets=  2 | profile=WECC_UT:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NWPP_CA excluded   generator                     import           CA         False            1  1550.000000
# rps_NWPP_CA excluded   generator natural gas combined cycle           CA         False            1  1175.193605
# rps_NWPP_CA excluded   generator        natural gas turbine           CA         False            3   530.839462
# rps_NWPP_CA excluded   generator                        oil           CA         False            1    12.000000
# rps_NWPP_CA excluded large_hydro                large_hydro           CA         False            1   665.800000
# rps_NWPP_CA included   generator                    biomass           CA          True            1     9.000000
# rps_NWPP_CA included   generator                      waste           CA          True            1    27.868724
# rps_NWPP_CA included small_hydro                small_hydro           CA          True            2   129.900000
# rps_NWPP_CA included       solar                      solar           CA          True           37  1402.242294
# rps_NWPP_CA included        wind                       wind           CA          True           12     0.000000
# rps_NWPP_NV excluded   generator                       coal           NV         False            1   218.000000
# rps_NWPP_NV excluded   generator natural gas combined cycle           NV         False            2  4784.611760
# rps_NWPP_NV excluded   generator        natural gas turbine           NV         False            2  1517.585572
# rps_NWPP_NV excluded   generator                 non-fossil           NV         False            1     6.500000
# rps_NWPP_NV excluded   generator                      steam           NV         False            1   334.000000
# rps_NWPP_NV excluded large_hydro                large_hydro           NV         False            1  1037.000000
# rps_NWPP_NV included   generator                      waste           NV          True            2    13.273396
# rps_NWPP_NV included  geothermal                 geothermal           NV          True            1   604.300000
# rps_NWPP_NV included small_hydro                small_hydro           NV          True            2    14.400000
# rps_NWPP_NV included       solar                      solar           NV          True           44  8068.958374
# rps_NWPP_NV included        wind                       wind           NV          True            1   150.000000
# rps_NWPP_OR excluded   generator natural gas combined cycle           OR         False            1  3360.572860
# rps_NWPP_OR excluded   generator        natural gas turbine           OR         False            1  1111.556595
# rps_NWPP_OR excluded   generator                 non-fossil           OR         False            1     9.000000
# rps_NWPP_OR excluded   generator                        oil           OR         False            1   394.800000
# rps_NWPP_OR excluded large_hydro                large_hydro           OR         False            1  7707.199999
# rps_NWPP_OR included   generator                    biomass           OR          True            1   127.700000
# rps_NWPP_OR included   generator                      waste           OR          True            1    47.200000
# rps_NWPP_OR included  geothermal                 geothermal           OR          True            1    19.500000
# rps_NWPP_OR included small_hydro                small_hydro           OR          True            1   682.000001
# rps_NWPP_OR included       solar                      solar           OR          True           15  5134.261172
# rps_NWPP_OR included        wind                       wind           OR          True           19  4310.200000
# rps_NWPP_WA excluded   generator natural gas combined cycle           WA         False            1  2618.205040
# rps_NWPP_WA excluded   generator        natural gas turbine           WA         False            1  2105.395783
# rps_NWPP_WA excluded   generator                 non-fossil           WA         False            1   107.700000
# rps_NWPP_WA excluded   generator                    nuclear           WA         False            1  1163.000000
# rps_NWPP_WA excluded   generator                        oil           WA         False            1     3.500000
# rps_NWPP_WA excluded large_hydro                large_hydro           WA         False            1 20174.500000
# rps_NWPP_WA included   generator                    biomass           WA          True            1   102.700000
# rps_NWPP_WA included   generator                      waste           WA          True            1    95.286403
# rps_NWPP_WA included small_hydro                small_hydro           WA          True            1  1070.000000
# rps_NWPP_WA included       solar                      solar           WA          True            8  6356.107143
# rps_NWPP_WA included        wind                       wind           WA          True           13  3539.900000
# ================================================================================
#
# Parameters Built: 6.584021806716919
# Variables Built: 4.724109649658203
# Constraints Built: 35.49645781517029
# Objective Built: 5.009368181228638
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.7, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.6, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.32178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.25, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ================================================================================
#
# natural gas combined cycle retirement summary
# Retired fraction : 0.66%
# Capacity before  : 14,395.60 MW
# Capacity after   : 14,300.59 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 141
# Exact duplicate groups: 8
# Assets contained in duplicate groups: 17
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 132
# ================================================================================
#
# Largest exact groups:
# WECC_NNV     | NV  | solar  | assets=  3 | profile=WECC_NNV:solar:5
# WECC_MT      | MT  | solar  | assets=  2 | profile=WECC_MT:solar:2
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WECC_ID      | ID  | solar  | assets=  2 | profile=WECC_ID:solar:3
# WECC_NNV     | NV  | solar  | assets=  2 | profile=WECC_NNV:solar:4
# WECC_SNV     | NV  | solar  | assets=  2 | profile=WECC_SNV:solar:5
# WECC_UT      | UT  | solar  | assets=  2 | profile=WECC_UT:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NWPP_CA excluded   generator                     import           CA         False            1  1550.000000
# rps_NWPP_CA excluded   generator natural gas combined cycle           CA         False            1  1175.193605
# rps_NWPP_CA excluded   generator        natural gas turbine           CA         False            3   530.839462
# rps_NWPP_CA excluded   generator                        oil           CA         False            1    12.000000
# rps_NWPP_CA excluded large_hydro                large_hydro           CA         False            1   665.800000
# rps_NWPP_CA included   generator                    biomass           CA          True            1     9.000000
# rps_NWPP_CA included   generator                      waste           CA          True            1    27.868724
# rps_NWPP_CA included small_hydro                small_hydro           CA          True            2   129.900000
# rps_NWPP_CA included       solar                      solar           CA          True           37  1402.242294
# rps_NWPP_CA included        wind                       wind           CA          True           12     0.000000
# rps_NWPP_NV excluded   generator                       coal           NV         False            1   218.000000
# rps_NWPP_NV excluded   generator natural gas combined cycle           NV         False            2  4784.611760
# rps_NWPP_NV excluded   generator        natural gas turbine           NV         False            2  1517.585572
# rps_NWPP_NV excluded   generator                 non-fossil           NV         False            1     6.500000
# rps_NWPP_NV excluded   generator                      steam           NV         False            1   334.000000
# rps_NWPP_NV excluded large_hydro                large_hydro           NV         False            1  1037.000000
# rps_NWPP_NV included   generator                      waste           NV          True            2    13.273396
# rps_NWPP_NV included  geothermal                 geothermal           NV          True            1   604.300000
# rps_NWPP_NV included small_hydro                small_hydro           NV          True            2    14.400000
# rps_NWPP_NV included       solar                      solar           NV          True           44  8068.958374
# rps_NWPP_NV included        wind                       wind           NV          True            1   150.000000
# rps_NWPP_OR excluded   generator natural gas combined cycle           OR         False            1  3360.572860
# rps_NWPP_OR excluded   generator        natural gas turbine           OR         False            1  1111.556595
# rps_NWPP_OR excluded   generator                 non-fossil           OR         False            1     9.000000
# rps_NWPP_OR excluded   generator                        oil           OR         False            1   394.800000
# rps_NWPP_OR excluded large_hydro                large_hydro           OR         False            1  7707.199999
# rps_NWPP_OR included   generator                    biomass           OR          True            1   127.700000
# rps_NWPP_OR included   generator                      waste           OR          True            1    47.200000
# rps_NWPP_OR included  geothermal                 geothermal           OR          True            1    19.500000
# rps_NWPP_OR included small_hydro                small_hydro           OR          True            1   682.000001
# rps_NWPP_OR included       solar                      solar           OR          True           15  5134.261172
# rps_NWPP_OR included        wind                       wind           OR          True           19  4310.200000
# rps_NWPP_WA excluded   generator natural gas combined cycle           WA         False            1  2618.205040
# rps_NWPP_WA excluded   generator        natural gas turbine           WA         False            1  2105.395783
# rps_NWPP_WA excluded   generator                 non-fossil           WA         False            1   107.700000
# rps_NWPP_WA excluded   generator                    nuclear           WA         False            1  1163.000000
# rps_NWPP_WA excluded   generator                        oil           WA         False            1     3.500000
# rps_NWPP_WA excluded large_hydro                large_hydro           WA         False            1 20174.500000
# rps_NWPP_WA included   generator                    biomass           WA          True            1   102.700000
# rps_NWPP_WA included   generator                      waste           WA          True            1    95.286403
# rps_NWPP_WA included small_hydro                small_hydro           WA          True            1  1070.000000
# rps_NWPP_WA included       solar                      solar           WA          True            8  6356.107143
# rps_NWPP_WA included        wind                       wind           WA          True           13  3539.900000
# ================================================================================
#
# Parameters Built: 6.550475597381592
# Variables Built: 4.674785375595093
# Constraints Built: 36.07702708244324
# Objective Built: 5.0313074588775635
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.5, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.4, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.12178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.05, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ================================================================================
#
# natural gas combined cycle retirement summary
# Retired fraction : 0.66%
# Capacity before  : 14,395.60 MW
# Capacity after   : 14,300.59 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 141
# Exact duplicate groups: 8
# Assets contained in duplicate groups: 17
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 132
# ================================================================================
#
# Largest exact groups:
# WECC_NNV     | NV  | solar  | assets=  3 | profile=WECC_NNV:solar:5
# WECC_MT      | MT  | solar  | assets=  2 | profile=WECC_MT:solar:2
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WECC_ID      | ID  | solar  | assets=  2 | profile=WECC_ID:solar:3
# WECC_NNV     | NV  | solar  | assets=  2 | profile=WECC_NNV:solar:4
# WECC_SNV     | NV  | solar  | assets=  2 | profile=WECC_SNV:solar:5
# WECC_UT      | UT  | solar  | assets=  2 | profile=WECC_UT:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NWPP_CA excluded   generator                     import           CA         False            1  1550.000000
# rps_NWPP_CA excluded   generator natural gas combined cycle           CA         False            1  1175.193605
# rps_NWPP_CA excluded   generator        natural gas turbine           CA         False            3   530.839462
# rps_NWPP_CA excluded   generator                        oil           CA         False            1    12.000000
# rps_NWPP_CA excluded large_hydro                large_hydro           CA         False            1   665.800000
# rps_NWPP_CA included   generator                    biomass           CA          True            1     9.000000
# rps_NWPP_CA included   generator                      waste           CA          True            1    27.868724
# rps_NWPP_CA included small_hydro                small_hydro           CA          True            2   129.900000
# rps_NWPP_CA included       solar                      solar           CA          True           37  1402.242294
# rps_NWPP_CA included        wind                       wind           CA          True           12     0.000000
# rps_NWPP_NV excluded   generator                       coal           NV         False            1   218.000000
# rps_NWPP_NV excluded   generator natural gas combined cycle           NV         False            2  4784.611760
# rps_NWPP_NV excluded   generator        natural gas turbine           NV         False            2  1517.585572
# rps_NWPP_NV excluded   generator                 non-fossil           NV         False            1     6.500000
# rps_NWPP_NV excluded   generator                      steam           NV         False            1   334.000000
# rps_NWPP_NV excluded large_hydro                large_hydro           NV         False            1  1037.000000
# rps_NWPP_NV included   generator                      waste           NV          True            2    13.273396
# rps_NWPP_NV included  geothermal                 geothermal           NV          True            1   604.300000
# rps_NWPP_NV included small_hydro                small_hydro           NV          True            2    14.400000
# rps_NWPP_NV included       solar                      solar           NV          True           44  8068.958374
# rps_NWPP_NV included        wind                       wind           NV          True            1   150.000000
# rps_NWPP_OR excluded   generator natural gas combined cycle           OR         False            1  3360.572860
# rps_NWPP_OR excluded   generator        natural gas turbine           OR         False            1  1111.556595
# rps_NWPP_OR excluded   generator                 non-fossil           OR         False            1     9.000000
# rps_NWPP_OR excluded   generator                        oil           OR         False            1   394.800000
# rps_NWPP_OR excluded large_hydro                large_hydro           OR         False            1  7707.199999
# rps_NWPP_OR included   generator                    biomass           OR          True            1   127.700000
# rps_NWPP_OR included   generator                      waste           OR          True            1    47.200000
# rps_NWPP_OR included  geothermal                 geothermal           OR          True            1    19.500000
# rps_NWPP_OR included small_hydro                small_hydro           OR          True            1   682.000001
# rps_NWPP_OR included       solar                      solar           OR          True           15  5134.261172
# rps_NWPP_OR included        wind                       wind           OR          True           19  4310.200000
# rps_NWPP_WA excluded   generator natural gas combined cycle           WA         False            1  2618.205040
# rps_NWPP_WA excluded   generator        natural gas turbine           WA         False            1  2105.395783
# rps_NWPP_WA excluded   generator                 non-fossil           WA         False            1   107.700000
# rps_NWPP_WA excluded   generator                    nuclear           WA         False            1  1163.000000
# rps_NWPP_WA excluded   generator                        oil           WA         False            1     3.500000
# rps_NWPP_WA excluded large_hydro                large_hydro           WA         False            1 20174.500000
# rps_NWPP_WA included   generator                    biomass           WA          True            1   102.700000
# rps_NWPP_WA included   generator                      waste           WA          True            1    95.286403
# rps_NWPP_WA included small_hydro                small_hydro           WA          True            1  1070.000000
# rps_NWPP_WA included       solar                      solar           WA          True            8  6356.107143
# rps_NWPP_WA included        wind                       wind           WA          True           13  3539.900000
# ================================================================================
#
# Parameters Built: 6.913243055343628
# Variables Built: 5.059818744659424
# Constraints Built: 37.31484055519104
# Objective Built: 5.196379899978638
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.6, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.5, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.22178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.15, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ================================================================================
#
# natural gas combined cycle retirement summary
# Retired fraction : 0.66%
# Capacity before  : 14,395.60 MW
# Capacity after   : 14,300.59 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 141
# Exact duplicate groups: 8
# Assets contained in duplicate groups: 17
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 132
# ================================================================================
#
# Largest exact groups:
# WECC_NNV     | NV  | solar  | assets=  3 | profile=WECC_NNV:solar:5
# WECC_MT      | MT  | solar  | assets=  2 | profile=WECC_MT:solar:2
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WEC_BANC     | CA  | solar  | assets=  2 | profile=WEC_BANC:solar:4
# WECC_ID      | ID  | solar  | assets=  2 | profile=WECC_ID:solar:3
# WECC_NNV     | NV  | solar  | assets=  2 | profile=WECC_NNV:solar:4
# WECC_SNV     | NV  | solar  | assets=  2 | profile=WECC_SNV:solar:5
# WECC_UT      | UT  | solar  | assets=  2 | profile=WECC_UT:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NWPP_CA excluded   generator                     import           CA         False            1  1550.000000
# rps_NWPP_CA excluded   generator natural gas combined cycle           CA         False            1  1175.193605
# rps_NWPP_CA excluded   generator        natural gas turbine           CA         False            3   530.839462
# rps_NWPP_CA excluded   generator                        oil           CA         False            1    12.000000
# rps_NWPP_CA excluded large_hydro                large_hydro           CA         False            1   665.800000
# rps_NWPP_CA included   generator                    biomass           CA          True            1     9.000000
# rps_NWPP_CA included   generator                      waste           CA          True            1    27.868724
# rps_NWPP_CA included small_hydro                small_hydro           CA          True            2   129.900000
# rps_NWPP_CA included       solar                      solar           CA          True           37  1402.242294
# rps_NWPP_CA included        wind                       wind           CA          True           12     0.000000
# rps_NWPP_NV excluded   generator                       coal           NV         False            1   218.000000
# rps_NWPP_NV excluded   generator natural gas combined cycle           NV         False            2  4784.611760
# rps_NWPP_NV excluded   generator        natural gas turbine           NV         False            2  1517.585572
# rps_NWPP_NV excluded   generator                 non-fossil           NV         False            1     6.500000
# rps_NWPP_NV excluded   generator                      steam           NV         False            1   334.000000
# rps_NWPP_NV excluded large_hydro                large_hydro           NV         False            1  1037.000000
# rps_NWPP_NV included   generator                      waste           NV          True            2    13.273396
# rps_NWPP_NV included  geothermal                 geothermal           NV          True            1   604.300000
# rps_NWPP_NV included small_hydro                small_hydro           NV          True            2    14.400000
# rps_NWPP_NV included       solar                      solar           NV          True           44  8068.958374
# rps_NWPP_NV included        wind                       wind           NV          True            1   150.000000
# rps_NWPP_OR excluded   generator natural gas combined cycle           OR         False            1  3360.572860
# rps_NWPP_OR excluded   generator        natural gas turbine           OR         False            1  1111.556595
# rps_NWPP_OR excluded   generator                 non-fossil           OR         False            1     9.000000
# rps_NWPP_OR excluded   generator                        oil           OR         False            1   394.800000
# rps_NWPP_OR excluded large_hydro                large_hydro           OR         False            1  7707.199999
# rps_NWPP_OR included   generator                    biomass           OR          True            1   127.700000
# rps_NWPP_OR included   generator                      waste           OR          True            1    47.200000
# rps_NWPP_OR included  geothermal                 geothermal           OR          True            1    19.500000
# rps_NWPP_OR included small_hydro                small_hydro           OR          True            1   682.000001
# rps_NWPP_OR included       solar                      solar           OR          True           15  5134.261172
# rps_NWPP_OR included        wind                       wind           OR          True           19  4310.200000
# rps_NWPP_WA excluded   generator natural gas combined cycle           WA         False            1  2618.205040
# rps_NWPP_WA excluded   generator        natural gas turbine           WA         False            1  2105.395783
# rps_NWPP_WA excluded   generator                 non-fossil           WA         False            1   107.700000
# rps_NWPP_WA excluded   generator                    nuclear           WA         False            1  1163.000000
# rps_NWPP_WA excluded   generator                        oil           WA         False            1     3.500000
# rps_NWPP_WA excluded large_hydro                large_hydro           WA         False            1 20174.500000
# rps_NWPP_WA included   generator                    biomass           WA          True            1   102.700000
# rps_NWPP_WA included   generator                      waste           WA          True            1    95.286403
# rps_NWPP_WA included small_hydro                small_hydro           WA          True            1  1070.000000
# rps_NWPP_WA included       solar                      solar           WA          True            8  6356.107143
# rps_NWPP_WA included        wind                       wind           WA          True           13  3539.900000
# ================================================================================
#
# Parameters Built: 6.87640118598938
# Variables Built: 5.109944105148315
# Constraints Built: 38.552156925201416
# Objective Built: 5.475785493850708
#   Scenario   7 ✓
#
# WECC_PNW -> WECC_MT via line_227: 10.01 MWh
# WECC_PNW -> WECC_ID via line_226: 1,715.10 MWh
# WECC_PNW -> WECC_NNV via line_228: 119.34 MWh
#
# Total transmission across all lines: 5,737.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# large_hydro                              96,611.31      33,950.10           0.00      33,950.10         8
# natural gas combined cycle               49,157.65      14,300.59           0.00      14,300.59         8
# coal                                     31,970.93       4,674.00           0.00       4,674.00         3
# battery                                  16,199.02      12,183.00           0.00      12,183.00         7
# nuclear                                   9,490.36       1,163.00           0.00       1,163.00         1
# small_hydro                               9,392.93       3,133.00           0.00       3,133.00        10
# geothermal                                5,640.21         706.80           0.00         706.80         4
# natural gas turbine                       5,297.61      12,519.99           0.00      12,519.99        12
# ev_v2g                                    2,221.69       2,311.26           0.00       2,311.26         7
# oil                                       2,208.62         438.70           0.00         438.70         5
# waste                                     1,501.02         221.57           0.00         221.57         9
# non-fossil                                1,376.16         198.80           0.00         198.80         6
# biomass                                     237.25         276.50           0.00         276.50         6
# import                                      225.23       1,550.00           0.00       1,550.00         1
# steam                                         1.35         571.00           0.00         571.00         2
# pump hydro                                    0.11           0.02           0.00           0.02         1
# wind                                    -35,783.03      11,343.40          31.00      11,374.40        66
# solar                                   -82,033.91      26,508.72       2,163.84      28,672.56       171
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                     234,906.55
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 171
# Wind assets found : 66
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WECC_MT:
#   Installed Capacity: 72.57 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_MT:
#   Installed Capacity: 24.19 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_BANC:
#   Installed Capacity: 236.39 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_BANC:
#   Installed Capacity: 78.80 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_ID:
#   Installed Capacity: 138.30 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_ID:
#   Installed Capacity: 46.10 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_NNV:
#   Installed Capacity: 66.93 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_NNV:
#   Installed Capacity: 22.31 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_SNV:
#   Installed Capacity: 144.63 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_SNV:
#   Installed Capacity: 48.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_UT:
#   Installed Capacity: 256.81 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_UT:
#   Installed Capacity: 85.60 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_PNW:
#   Installed Capacity: 1,580.39 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_PNW:
#   Installed Capacity: 526.80 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_s07_fast_m0_d360/s07_s07_cost_components.csv
# Capex detail CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_s07_fast_m0_d360/s07_s07_capex_detail.csv
# Capex summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_s07_fast_m0_d360/s07_s07_capex_summary.csv
# EV summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_s07_fast_m0_d360/s07_s07_ev_summary.csv
# Finished scenario 7: s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360
# Solution JSON: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NWPP/scenario_results_2030_fast_NWPP_arrive/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360/s07_V2G_rps-10_v1g0_v2g25_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 2,853,775,098.84
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.6, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.5, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Objective = 2,884,523,036.01
# EV state: NWPP
# Model region: NWPP
# STATE_TO_REGIONS key used: NWPP
# GOOD regions used: ['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NWPP_CA: ratio=0.7, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_NV: ratio=0.6, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_OR: ratio=0.32178, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
#   rps_NWPP_WA: ratio=0.25, regions=['WECC_MT', 'WEC_BANC', 'WECC_ID', 'WECC_NNV', 'WECC_SNV', 'WECC_UT', 'WECC_PNW']
# Total battery assets removed: 6
# ================================================================================
#
# EV profile market key: NWPP
#
# Processed 221 renewable plants with capex
# Skipped 16 renewable plants (no valid capex_cost)
# ...
# Solution CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 3,278,302,923.50
#
#
# Total transmission across all lines: 5,795.72 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# large_hydro                              98,536.26      33,950.10           0.00      33,950.10         8
# natural gas combined cycle               47,800.92      14,300.59           0.00      14,300.59         8
# coal                                     32,436.97       4,674.00           0.00       4,674.00         3
# battery                                  15,147.94      12,183.00           0.00      12,183.00         7
# nuclear                                   9,491.02       1,163.00           0.00       1,163.00         1
# small_hydro                               9,413.64       3,133.00           0.00       3,133.00        10
# geothermal                                5,745.68         706.80           0.00         706.80         4
# natural gas turbine                       4,389.11      12,519.99           0.00      12,519.99        12
# ev_v2g                                    3,518.79       4,652.09           0.00       4,652.09         7
# oil                                       2,320.90         438.70           0.00         438.70         5
# waste                                     1,551.58         221.57           0.00         221.57         9
# non-fossil                                1,423.63         198.80           0.00         198.80         6
# biomass                                     232.87         276.50           0.00         276.50         6
# import                                       20.27       1,550.00           0.00       1,550.00         1
# pump hydro                                    0.12           0.02           0.00           0.02         1
# steam                                         0.00         571.00           0.00         571.00         2
# wind                                    -35,783.03      11,343.40          31.00      11,374.40        66
# solar                                   -81,596.46      26,508.72       1,974.29      28,483.01       171
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                     206,514.74
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 171
# Wind assets found : 66
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WECC_MT:
#   Installed Capacity: 35.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_MT:
#   Installed Capacity: 35.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_BANC:
#   Installed Capacity: 138.73 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_BANC:
#   Installed Capacity: 138.73 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_ID:
#   Installed Capacity: 61.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_ID:
#   Installed Capacity: 61.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_NNV:
#   Installed Capacity: 34.17 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_NNV:
#   Installed Capacity: 34.17 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_SNV:
#   Installed Capacity: 73.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_SNV:
#   Installed Capacity: 73.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_UT:
#   Installed Capacity: 127.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_UT:
#   Installed Capacity: 127.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_PNW:
#   Installed Capacity: 701.42 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_PNW:
#   Installed Capacity: 701.42 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_s13_fast_m0_d360/s13_s13_cost_components.csv
# Capex detail CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_s13_fast_m0_d360/s13_s13_capex_detail.csv
# Capex summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_s13_fast_m0_d360/s13_s13_capex_summary.csv
# EV summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_s13_fast_m0_d360/s13_s13_ev_summary.csv
# Finished scenario 13: s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 2,784,320,858.18
#
#
# Total transmission across all lines: 5,535.20 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# large_hydro                              91,055.63      33,950.10           0.00      33,950.10         8
# natural gas combined cycle               45,664.10      14,300.59           0.00      14,300.59         8
# coal                                     31,052.17       4,674.00           0.00       4,674.00         3
# battery                                  15,915.21      12,183.00           0.00      12,183.00         7
# nuclear                                   9,446.68       1,163.00           0.00       1,163.00         1
# small_hydro                               9,140.70       3,133.00           0.00       3,133.00        10
# geothermal                                5,623.79         706.80           0.00         706.80         4
# natural gas turbine                       4,458.25      12,519.99           0.00      12,519.99        12
# ev_v2g                                    4,094.22       4,652.09           0.00       4,652.09         7
# oil                                       1,928.07         438.70           0.00         438.70         5
# waste                                     1,397.47         221.57           0.00         221.57         9
# non-fossil                                1,294.74         198.80           0.00         198.80         6
# biomass                                     223.54         276.50           0.00         276.50         6
# import                                      101.99       1,550.00           0.00       1,550.00         1
# pump hydro                                    0.10           0.02           0.00           0.02         1
# steam                                         0.00         571.00           0.00         571.00         2
# wind                                    -35,783.03      11,343.40          31.00      11,374.40        66
# solar                                   -94,380.01      26,508.72       6,955.36      33,464.08       171
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                     876,091.73
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 171
# Wind assets found : 66
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WECC_MT:
#   Installed Capacity: 35.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_MT:
#   Installed Capacity: 35.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WEC_BANC:
#   Installed Capacity: 138.73 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WEC_BANC:
#   Installed Capacity: 138.73 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_ID:
#   Installed Capacity: 61.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_ID:
#   Installed Capacity: 61.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_NNV:
#   Installed Capacity: 34.17 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_NNV:
#   Installed Capacity: 34.17 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_SNV:
#   Installed Capacity: 73.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_SNV:
#   Installed Capacity: 73.84 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_UT:
#   Installed Capacity: 127.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_UT:
#   Installed Capacity: 127.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_WECC_PNW:
#   Installed Capacity: 701.42 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_WECC_PNW:
#   Installed Capacity: 701.42 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_s15_fast_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_s15_fast_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_s15_fast_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_s15_fast_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 15: s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/NWPP/scenario_results_2030_fast_NWPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 3,145,321,603.32
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/NWPP/scenario_results_2030_fast_NWPP_flex/all_scenarios_summary.csv
