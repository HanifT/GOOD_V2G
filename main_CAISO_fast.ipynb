# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "CAISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)


YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "CA"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/California_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    # "mid",
    "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "WECC_SCE": 0.638000,  # 9,567.7 MW
    "WEC_CALN": 0.205963,  # 3,088.7 MW
    "WEC_LADW": 0.060054,  #   900.6 MW
    "WEC_SDGE": 0.095983,  # 1,439.4 MW
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

CAISO_REGIONS = [
    "WEC_CALN",
    "WEC_LADW",
    "WEC_SDGE",
    "WECC_SCE",
]

STATE_TO_REGIONS = {
    "CA": CAISO_REGIONS,
    "CAISO": CAISO_REGIONS,
}

RETIREMENT_POLICIES = {
    "CA": {
        "oil": 0.1113,
        "nuclear": 0.50,
        "natural gas turbine": 0.0005,
        "natural gas combined cycle": 0.0,
        "coal": 0.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "CA": {
        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}
FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 15700,
        },
    },
    "CA": {
        "battery": {
            "total_power_mw": 15700,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 2.08e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "CA": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "CA": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 4
# # Total runs: 60 (= 15 scenarios × 4 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: FAST
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: FAST adoption + Midnight timed charging
# Results Directory: Output/CAISO/scenario_results_2030_fast_CAISO_midnight
# ================================================================================
#
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.6, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.056366443634033
# Variables Built: 2.558598279953003
# Constraints Built: 22.252479076385498
# Objective Built: 1.2891044616699219
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.7, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.04642915725708
# Variables Built: 2.556572675704956
# Constraints Built: 22.209463119506836
# Objective Built: 1.2794203758239746
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.5, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.067065477371216
# Variables Built: 2.6486706733703613
# Constraints Built: 22.19570803642273
# Objective Built: 1.2764158248901367
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.5, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.192291975021362
# Variables Built: 2.8638010025024414
# Constraints Built: 23.06767225265503
# Objective Built: 2.8073010444641113
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.6, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.206250429153442
# Variables Built: 2.832561731338501
# Constraints Built: 23.097215175628662
# Objective Built: 2.817338705062866
# Problem Solved: 1323.9751734733582
# Solution Graph Built: 22.913615465164185
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.361631155014038
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 134,506,027 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 7,877.07       5,182.00      13,059.07          108,452.25            636.98        52
# solar                               22,904.57       3,146.76      26,051.34           94,787.16            286.81        95
# oil                                    254.52           0.00         254.52                0.00              0.00         3
# waste                                  755.23           0.00         755.23                0.00              0.00         4
# unknown                            -66,143.95           0.00     -66,143.95                0.00              0.00         8
# steam                                  623.00           0.00         623.00                0.00              0.00         2
# small_hydro                          1,745.64           0.00       1,745.64                0.00              0.00         4
# pump hydro                               0.24           0.00           0.24                0.00              0.00         3
# battery                             15,700.00           0.00      15,700.00          106,267.74              0.00         4
# biomass                                543.70           0.00         543.70                0.00              0.00         2
# natural gas turbine                 13,316.81           0.00      13,316.81                0.00              0.00         5
# natural gas combined cycle          17,963.95           0.00      17,963.95                0.00              0.00         4
# large_hydro                          7,605.89           0.00       7,605.89                0.00              0.00         3
# import                               4,250.00           0.00       4,250.00                0.00              0.00         3
# geothermal                           1,452.33           0.00       1,452.33                0.00              0.00         2
# coal                                    73.30           0.00          73.30                0.00              0.00         2
# non-fossil                             158.20           0.00         158.20                0.00              0.00         4
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                 59,250.31
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $5,111,461,835.60
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 636,979,041.10
#   solar                          $ 286,807,229.96
#   TOTAL                          $ 923,786,271.06
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $3,337,995,349.58
#   natural gas turbine            $ 552,150,642.27
#   steam                          $  57,350,237.26
#   oil                            $  42,643,505.63
#   waste                          $  40,922,084.55
#   geothermal                     $  14,532,767.49
#   coal                           $  12,235,762.41
#   non-fossil                     $   9,311,986.66
#   large_hydro                    $   3,715,607.21
#   biomass                        $   1,400,647.69
#   small_hydro                    $     123,279.25
#   TOTAL                          $4,072,381,870.01
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WEC_CALN:WECC_SCE              $  36,575,985.17
#   WECC_SCE:WEC_CALN              $  10,197,953.25
#   WEC_LADW:WECC_SCE              $   4,473,723.80
#   WECC_SCE:WEC_SDGE              $   4,190,711.88
#   WECC_SCE:WEC_LADW              $   1,068,717.37
#   WEC_SDGE:WECC_SCE              $     328,085.97
#   TOTAL                          $  56,835,177.45
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,053,003,318.52
# Model Objective                $5,111,461,835.60
# Other Gap                      $  58,458,517.07
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WEC_CALN -> WECC_SCE via line_257: 1,270.00 MWh
# WEC_LADW -> WECC_SCE via line_261: 155.34 MWh
# WEC_SDGE -> WECC_SCE via line_266: 11.39 MWh
# WECC_SCE -> WEC_CALN via line_234: 354.10 MWh
# WECC_SCE -> WEC_LADW via line_235: 37.11 MWh
# WECC_SCE -> WEC_SDGE via line_236: 145.51 MWh
#
# Total transmission across all lines: 1,973.44 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================  Scenario   1 ✓
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              120,657.64      17,963.95           0.00      17,963.95         4
# battery                                  17,983.64      15,700.00           0.00      15,700.00         4
# natural gas turbine                      13,848.39      13,316.81           0.00      13,316.81         5
# geothermal                               12,528.25       1,452.33           0.00       1,452.33         2
# large_hydro                              10,972.14       7,605.89           0.00       7,605.89         3
# waste                                     6,464.01         755.23           0.00         755.23         4
# small_hydro                               2,399.80       1,745.64           0.00       1,745.64         4
# oil                                       2,171.41         254.52           0.00         254.52         3
# steam                                     1,482.89         623.00           0.00         623.00         2
# non-fossil                                1,342.37         158.20           0.00         158.20         4
# coal                                        511.16          73.30           0.00          73.30         2
# biomass                                      29.07         543.70           0.00         543.70         2
# pump hydro                                    1.40           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -49,469.57       7,877.07       5,182.00      13,059.07        52
# solar                                   -80,154.53      22,904.57       3,146.76      26,051.34        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      59,250.31
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 2,187.92 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 1,482.91 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 542.31 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 1,698.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_s01_fast_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_s01_fast_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_s01_fast_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_s01_fast_m0_d360/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_fast_CAISO_midnight/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360/s01_Base_only_rps50_v1g0_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 5,111,461,835.60
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.7, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923Problem Solved: 1395.9469754695892
# Solution Graph Built: 21.280053853988647
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.5031859874725342
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 107,201,405 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# solar                               22,904.57      12,410.51      35,315.08           94,787.16          1,148.57        95
# wind                                 7,877.07       5,945.99      13,823.06          108,452.25            750.51        52
# oil                                    254.52           0.00         254.52                0.00              0.00         3
# waste                                  755.23           0.00         755.23                0.00              0.00         4
# unknown                            -66,143.95           0.00     -66,143.95                0.00              0.00         8
# steam                                  623.00           0.00         623.00                0.00              0.00         2
# small_hydro                          1,745.64           0.00       1,745.64                0.00              0.00         4
# pump hydro                               0.24           0.00           0.24                0.00              0.00         3
# battery                             15,700.00           0.00      15,700.00          106,267.74              0.00         4
# biomass                                543.70           0.00         543.70                0.00              0.00         2
# natural gas turbine                 13,316.81           0.00      13,316.81                0.00              0.00         5
# natural gas combined cycle          17,963.95           0.00      17,963.95                0.00              0.00         4
# large_hydro                          7,605.89           0.00       7,605.89                0.00              0.00         3
# import                               4,250.00           0.00       4,250.00                0.00              0.00         3
# geothermal                           1,452.33           0.00       1,452.33                0.00              0.00         2
# coal                                    73.30           0.00          73.30                0.00              0.00         2
# non-fossil                             158.20           0.00         158.20                0.00              0.00         4
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              2,034,204.28
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $5,468,816,514.27
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   solar                          $1,148,572,841.51
#   wind                           $ 750,506,673.28
#   TOTAL                          $1,899,079,514.79
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,650,727,323.95
#   natural gas turbine            $ 458,398,825.08
#   biomass                        $ 165,935,746.81
#   steam                          $  67,319,594.61
#   waste                          $  37,979,924.24
#   oil                            $  33,666,046.82
#   geothermal                     $  13,797,312.95
#   coal                           $   8,943,576.45
#   non-fossil                     $   7,864,125.05
#   large_hydro                    $   3,153,141.83
#   small_hydro                    $     118,078.58
#   TOTAL                          $3,447,903,696.38
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WEC_CALN:WECC_SCE              $  35,957,344.34
#   WECC_SCE:WEC_CALN              $  16,019,724.63
#   WECC_SCE:WEC_SDGE              $   4,850,459.15
#   WECC_SCE:WEC_LADW              $   2,793,892.80
#   WEC_LADW:WECC_SCE              $   2,452,251.34
#   WEC_SDGE:WECC_SCE              $   1,083,580.91
#   TOTAL                          $  63,157,253.16
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,410,140,464.33
# Model Objective                $5,468,816,514.27
# Other Gap                      $  58,676,049.94
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WEC_CALN -> WECC_SCE via line_257: 1,248.52 MWh
# WEC_LADW -> WECC_SCE via line_261: 85.15 MWh
# WEC_SDGE -> WECC_SCE via line_266: 37.62 MWh
# WECC_SCE -> WEC_CALN via line_234: 556.24 MWh
# WECC_SCE -> WEC_LADW via line_235: 97.01 MWh
# WECC_SCE -> WEC_SDGE via line_236: 168.42 MWh
#
# Total transmission across all lines: 2,192.96 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================  Scenario   2 ✓
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               95,750.39      17,963.95           0.00      17,963.95         4
# battery                                  28,013.88      15,700.00           0.00      15,700.00         4
# geothermal                               11,894.24       1,452.33           0.00       1,452.33         2
# natural gas turbine                      11,451.01      13,316.81           0.00      13,316.81         5
# large_hydro                               9,300.52       7,605.89           0.00       7,605.89         3
# waste                                     6,016.78         755.23           0.00         755.23         4
# biomass                                   3,437.82         543.70           0.00         543.70         2
# small_hydro                               2,294.52       1,745.64           0.00       1,745.64         4
# steam                                     1,740.67         623.00           0.00         623.00         2
# oil                                       1,714.27         254.52           0.00         254.52         3
# non-fossil                                1,133.65         158.20           0.00         158.20         4
# coal                                        375.40          73.30           0.00          73.30         2
# pump hydro                                    1.33           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -52,419.25       7,877.07       5,945.99      13,823.06        52
# solar                                  -108,170.47      22,904.57      12,410.51      35,315.08        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   2,034,204.28
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 2,187.92 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 1,482.91 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 542.31 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ...
# biomass                                543.70           0.00         543.70                0.00              0.00         2
# natural gas turbine                 13,316.81           0.00      13,316.81                0.00              0.00         5
# natural gas combined cycle          17,963.95           0.00      17,963.95                0.00              0.00         4
# large_hydro                          7,605.89           0.00       7,605.89                0.00              0.00         3
# import                               4,250.00           0.00       4,250.00                0.00              0.00         3
# geothermal                           1,452.33           0.00       1,452.33                0.00              0.00         2
# coal                                    73.30           0.00          73.30                0.00              0.00         2
# non-fossil                             158.20           0.00         158.20                0.00              0.00         4
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                 24,312.01
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 10
# ====================================================================================================
#
# Total Objective: $5,076,833,982.59
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 636,979,041.10
#   solar                          $ 282,236,525.78
#   TOTAL                          $ 919,215,566.88
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $3,386,100,532.68
#   natural gas turbine            $ 499,368,097.87
#   oil                            $  42,839,285.95
#   waste                          $  41,040,267.22
#   steam                          $  36,365,507.63
#   geothermal                     $  14,527,661.07
#   coal                           $  12,158,535.11
#   non-fossil                     $   9,362,101.45
#   large_hydro                    $   3,718,825.25
#   biomass                        $   1,083,138.78
#   small_hydro                    $     123,354.32
#   TOTAL                          $4,046,687,307.32
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WEC_CALN:WECC_SCE              $  35,768,677.06
#   WECC_SCE:WEC_CALN              $   7,971,891.97
#   WECC_SCE:WEC_SDGE              $   4,788,136.10
#   WEC_LADW:WECC_SCE              $   3,177,346.27
#   WECC_SCE:WEC_LADW              $     548,223.95
#   WEC_SDGE:WECC_SCE              $     247,359.32
#   TOTAL                          $  52,501,634.67
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,018,404,508.87
# Model Objective                $5,076,833,982.59
# Other Gap                      $  58,429,473.72
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WEC_CALN -> WECC_SCE via line_257: 1,241.97 MWh
# WEC_LADW -> WECC_SCE via line_261: 110.32 MWh
# WEC_SDGE -> WECC_SCE via line_266: 8.59 MWh
# WECC_SCE -> WEC_CALN via line_234: 276.80 MWh
# WECC_SCE -> WEC_LADW via line_235: 19.04 MWh
# WECC_SCE -> WEC_SDGE via line_236: 166.25 MWh
#
# Total transmission across all lines: 1,822.97 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================  Scenario  10 ✓
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              122,372.69      17,963.95           0.00      17,963.95         4
# battery                                  16,644.48      15,700.00           0.00      15,700.00         4
# natural gas turbine                      12,535.00      13,316.81           0.00      13,316.81         5
# geothermal                               12,523.85       1,452.33           0.00       1,452.33         2
# large_hydro                              10,984.42       7,605.89           0.00       7,605.89         3
# waste                                     6,481.34         755.23           0.00         755.23         4
# small_hydro                               2,401.62       1,745.64           0.00       1,745.64         4
# oil                                       2,181.38         254.52           0.00         254.52         3
# non-fossil                                1,349.59         158.20           0.00         158.20         4
# steam                                       940.29         623.00           0.00         623.00         2
# coal                                        509.63          73.30           0.00          73.30         2
# biomass                                      22.48         543.70           0.00         543.70         2
# pump hydro                                    1.38           0.24           0.00           0.24         3
# import                                        0.00       4,250.00           0.00       4,250.00         3
# wind                                    -49,469.57       7,877.07       5,182.00      13,059.07        52
# solar                                   -79,998.44      22,904.57       3,097.97      26,002.54        95
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      24,312.01
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 95
# Wind assets found : 52
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WEC_CALN:
#   Installed Capacity: 1,093.96 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_CALN:
#   Installed Capacity: 1,093.96 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 1,093.96 MW
#   Max Shift Down: -542.71 MW
#   Total Shifting: 2,681,543.94 MWh
#
# ev_load_fixed_WEC_LADW:
#   Installed Capacity: 741.46 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_LADW:
#   Installed Capacity: 741.46 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 741.46 MW
#   Max Shift Down: -367.84 MW
#   Total Shifting: 2,103,365.15 MWh
#
# ev_load_fixed_WEC_SDGE:
#   Installed Capacity: 271.16 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WEC_SDGE:
#   Installed Capacity: 271.16 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 271.16 MW
#   Max Shift Down: -134.52 MW
#   Total Shifting: 572,701.02 MWh
#
# ev_load_fixed_WECC_SCE:
#   Installed Capacity: 849.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_WECC_SCE:
#   Installed Capacity: 849.13 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 849.13 MW
#   Max Shift Down: -421.25 MW
#   Total Shifting: 1,946,973.97 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_s10_fast_m0_d360/s10_s10_cost_components.csv
# Capex detail CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_s10_fast_m0_d360/s10_s10_capex_detail.csv
# Capex summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_s10_fast_m0_d360/s10_s10_capex_summary.csv
# EV summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_s10_fast_m0_d360/s10_s10_ev_summary.csv
# Finished scenario 10: s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/CAISO/scenario_results_2030_fast_CAISO_arrive/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360/s10_V1G_rps50_v1g50_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 5,076,833,982.59
# EV state: CA
# Model region: CAISO
# STATE_TO_REGIONS key used: CAISO
# GOOD regions used: ['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_CAISO: ratio=0.7, regions=['WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_SCE']
# Total battery assets removed: 4
# ================================================================================
#
# EV profile market key: CA
# Added detail-equivalent aggregate V2G store to WEC_CALN: max_power=12599.05 MW, max_energy=12599.05 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to WEC_LADW: max_power=8539.28 MW, max_energy=8539.28 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to WEC_SDGE: max_power=3122.89 MW, max_energy=3122.89 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to WECC_SCE: max_power=9779.32 MW, max_energy=9779.32 MWh, window_hours=24
#
# Processed 139 renewable plants with capex
# Skipped 8 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 11.13%
# Capacity before  : 286.40 MW
# Capacity after   : 254.52 MW
# nuclear retirement summary
# Retired fraction : 50.00%
# Capacity before  : 0.00 MW
# Capacity after   : 0.00 MW
# natural gas turbine retirement summary
# Retired fraction : 0.05%
# Capacity before  : 13,323.47 MW
# Capacity after   : 13,316.81 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 76
# Exact duplicate groups: 3
# Assets contained in duplicate groups: 6
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WEC_CALN     | CA  | solar  | assets=  2 | profile=WEC_CALN:solar:4
# WECC_SCE     | CA  | solar  | assets=  2 | profile=WECC_SCE:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_CAISO excluded   generator                       coal           CA         False            2    73.300000
# rps_CAISO excluded   generator                     import           CA         False            3  4250.000000
# rps_CAISO excluded   generator natural gas combined cycle           CA         False            4 17963.954778
# rps_CAISO excluded   generator        natural gas turbine           CA         False            5 13316.807746
# rps_CAISO excluded   generator                 non-fossil           CA         False            4   158.200000
# rps_CAISO excluded   generator                        oil           CA         False            3   254.523680
# rps_CAISO excluded   generator                      steam           CA         False            2   623.000002
# rps_CAISO excluded large_hydro                large_hydro           CA         False            3  7605.889927
# rps_CAISO included   generator                    biomass           CA          True            2   543.700000
# rps_CAISO included   generator                      waste           CA          True            4   755.231276
# rps_CAISO included  geothermal                 geothermal           CA          True            2  1452.330000
# rps_CAISO included small_hydro                small_hydro           CA          True            4  1745.640244
# rps_CAISO included       solar                      solar           CA          True           95 22904.571788
# rps_CAISO included        wind                       wind           CA          True           52  7877.073923
# ================================================================================
#
# Parameters Built: 4.571618556976318
# Variables Built: 2.0987324714660645
# Constraints Built: 32.211302280426025
# Objective Built: 1.538212776184082
