# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 4
CPLEX_THREADS_PER_SCENARIO = 30

IPM_REGION = "ERCOT"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)
YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "TX"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/Texas_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 138  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    "slow",
                      "mid", 
    # "fast"
                     ]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    # "midnight": {
    #     "profile": "timed_charging",
    #     "description": "Midnight timed charging",
    # },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "ERC_REST": 0.60,
    "ERC_WEST": 0.40,
    "ERC_GWAY": 0.0,
    "ERC_FRNT": 0.0,
    "ERC_PHDL": 0.0,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

ERCOT_REGIONS = [
    "ERC_FRNT",
    "ERC_PHDL",
    "ERC_GWAY",
    "ERC_REST",
    "ERC_WEST",
]

STATE_TO_REGIONS = {
    "TX": ERCOT_REGIONS,
    "ERCOT": ERCOT_REGIONS,
}
RETIREMENT_POLICIES = {
    "TX": {
        "coal": 1 / 3,
    },

    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },

    "CA": {
        "oil": 0.70,
        "nuclear": 1.00,
        "natural gas turbine": 0.20,
        "natural gas combined cycle": 0.04,
        "coal": 1.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "TX": {
        # ERCOT 2030 central logic:
        # Nuclear is small in capacity but high in energy output, so keep it highly must-run.
        # Coal is still meaningful, but do NOT force it at 45% in a 2030 renewable-heavy case.
        # Combined-cycle gas should provide reliability, but not behave as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },
    },

    "CA": {
        # CAISO / California 2030 central logic:
        # Do not add a nuclear constraint unless your GOOD input data explicitly includes CA nuclear.
        # California policy still treats Diablo Canyon as a transition/reliability resource, not a long-run
        # 2030+ baseload expansion resource.
        # Gas must stay flexible because CA has solar-heavy duck-curve conditions.

        # If your GOOD data has a CA "nuclear" category and you are modeling a 2030 week
        # before Diablo Canyon Unit 2 retirement, you may add this sensitivity:
        #
        # "nuclear": {
        #     "must_run_fraction": 0.60,
        #     "ramp_rate": 0.03,
        # },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.08,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "FL": {
        # Florida / FRCC 2030 central logic:
        # Nuclear is baseload.
        # Florida relies heavily on natural gas, especially combined-cycle gas.
        # Coal still exists but should have a low floor because coal retirements and solar growth continue.
        # Oil should not be must-run.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.04,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.18,
            "ramp_rate": 0.18,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.60,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "PJM": {
        # PJM 2030 central logic:
        # Nuclear is large and should remain highly must-run.
        # Coal is still important, but a 45% hourly floor is too high for a 2030 policy/RPS case.
        # Combined-cycle gas is important for reliability and load growth, but it should not be forced
        # as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 17500,
        },
    },

    "CA": {
        "battery": {
            "total_power_mw": 16900,
        },
    },

    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },

    "TX": {
        "battery": {
            "total_power_mw": 17500,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": True,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 2 (slow, mid)
# # Charging scenarios: 2 (arrive, flex)
# # Total combinations: 4
# # Total runs: 60 (= 15 scenarios × 4 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Immediate arrival charging
# Results Directory: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.342566967010498
# Variables Built: 1.329286813735962
# Constraints Built: 15.71610426902771
# Objective Built: 1.5693209171295166
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.6, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.3549039363861084
# Variables Built: 1.3047208786010742
# Constraints Built: 15.806437969207764
# Objective Built: 1.5983858108520508
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.331045627593994
# Variables Built: 1.3303160667419434
# Constraints Built: 15.833606481552124
# Objective Built: 1.6024353504180908
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.4625165462493896
# Variables Built: 1.3492202758789062
# Constraints Built: 17.424002408981323
# Objective Built: 0.6966409683227539
# Problem Solved: 63.190572023391724
# Solution Graph Built: 5.629579782485962
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.7044262886047363
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 135,377,308 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,798.17     106,940.67           98,282.12          6,988.80        81
# solar                               36,639.68      41,521.01      78,160.70           87,465.64          3,410.58        59
# battery                             17,500.00       4,765.19      22,265.19          106,267.74            499.45         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -139,948.14           0.00    -139,948.14                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,850,084.37
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $16,338,488,112.99
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,988,795,406.82
#   solar                          $3,410,583,005.80
#   battery                        $ 499,449,677.82
#   TOTAL                          $10,898,828,090.44
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,973,658,333.13
#   nuclear                        $ 829,832,515.85
#   coal                           $ 687,254,629.74
#   steam                          $  89,726,255.28
#   natural gas turbine            $  31,592,383.21
#   waste                          $  11,250,486.81
#   non-fossil                     $   3,671,074.03
#   biomass                        $     186,912.31
#   oil                            $     161,224.25
#   large_hydro                    $      12,330.82
#   small_hydro                    $       8,493.18
#   TOTAL                          $4,627,354,638.63
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 612,506,451.98
#   ERC_PHDL:ERC_WEST              $ 113,936,147.12
#   ERC_REST:ERC_WEST              $   3,016,649.18
#   ERC_WEST:ERC_PHDL              $       4,259.51
#   TOTAL                          $ 729,463,507.80
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,255,646,236.87
# Model Objective                $16,338,488,112.99
# Other Gap                      $  82,841,876.12
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,956.12 MWh
# ERC_REST -> ERC_WEST via line_5: 104.74 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.15 MWh
# ERC_WEST -> ERC_REST via line_8: 21,267.59 MWh
#
# Total transmission across all lines: 25,328.59 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,568.91      35,044.70           0.00      35,044.70         2Problem Solved: 66.42193698883057
# Solution Graph Built: 5.400489330291748
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.710637092590332
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 135,223,735 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,798.17     106,940.67           98,282.12          6,988.80        81
# solar                               36,639.68      41,521.01      78,160.70           87,465.64          3,410.58        59
# battery                             17,500.00       4,765.19      22,265.19          106,267.74            499.45         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -139,948.14           0.00    -139,948.14                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,837,816.13
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $16,338,498,048.93
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,988,795,406.82
#   solar                          $3,410,583,005.80
#   battery                        $ 499,449,677.82
#   TOTAL                          $10,898,828,090.44
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,970,285,222.47
#   nuclear                        $ 829,107,122.79
#   coal                           $ 690,791,536.07
#   steam                          $  90,194,895.22
#   natural gas turbine            $  31,562,288.19
#   waste                          $  11,251,234.80
#   non-fossil                     $   3,672,744.09
#   biomass                        $     203,258.82
#   oil                            $     160,931.67
#   large_hydro                    $      12,330.82
#   small_hydro                    $       8,496.01
#   TOTAL                          $4,627,250,060.95
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 612,604,806.82
#   ERC_PHDL:ERC_WEST              $ 113,947,633.13
#   ERC_REST:ERC_WEST              $   3,022,141.02
#   ERC_WEST:ERC_PHDL              $       4,259.51
#   TOTAL                          $ 729,578,840.49
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,255,656,991.88
# Model Objective                $16,338,498,048.93
# Other Gap                      $  82,841,057.05
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,956.52 MWh
# ERC_REST -> ERC_WEST via line_5: 104.94 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.15 MWh
# ERC_WEST -> ERC_REST via line_8: 21,271.00 MWh
#
# Total transmission across all lines: 25,332.60 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,416.07      35,044.70           0.00      35,044.70         2Problem Solved: 68.44351124763489
# Solution Graph Built: 5.436540126800537
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.7277038097381592
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 135,392,424 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,798.17     106,940.67           98,282.12          6,988.80        81
# solar                               36,639.68      41,521.01      78,160.70           87,465.64          3,410.58        59
# battery                             17,500.00       4,765.19      22,265.19          106,267.74            499.45         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -139,948.14           0.00    -139,948.14                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,850,065.81
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $16,338,488,423.46
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,988,795,406.82
#   solar                          $3,410,583,005.80
#   battery                        $ 499,449,677.82
#   TOTAL                          $10,898,828,090.44
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,973,990,115.77
#   nuclear                        $ 829,825,695.19
#   coal                           $ 686,943,912.16
#   steam                          $  89,722,516.06
#   natural gas turbine            $  31,593,727.72
#   waste                          $  11,250,479.56
#   non-fossil                     $   3,671,074.03
#   biomass                        $     186,912.31
#   oil                            $     161,177.97
#   large_hydro                    $      12,330.82
#   small_hydro                    $       8,490.41
#   TOTAL                          $4,627,366,431.98
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 612,498,890.89
#   ERC_PHDL:ERC_WEST              $ 113,931,238.13
#   ERC_REST:ERC_WEST              $   3,017,538.50
#   ERC_WEST:ERC_PHDL              $       4,259.51
#   TOTAL                          $ 729,451,927.04
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,255,646,449.46
# Model Objective                $16,338,488,423.46
# Other Gap                      $  82,841,973.99
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,955.95 MWh
# ERC_REST -> ERC_WEST via line_5: 104.78 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.15 MWh
# ERC_WEST -> ERC_REST via line_8: 21,267.32 MWh
#
# Total transmission across all lines: 25,328.19 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,583.98      35,044.70           0.00      35,044.70         2  Scenario   3 ✓
#
# nuclear                                  41,421.44       4,960.00           0.00       4,960.00         1
# coal                                     30,566.23       8,603.07           0.00       8,603.07         1
# battery                                  22,646.77      17,500.00       4,765.19      22,265.19         3
# steam                                     2,511.63       9,055.70           0.00       9,055.70         2
# waste                                     1,614.69         210.40           0.00         210.40         2
# natural gas turbine                         808.40       8,608.50           0.00       8,608.50         2
# non-fossil                                  529.34          68.80           0.00          68.80         1
# small_hydro                                 301.34         341.10           0.00         341.10         1
# large_hydro                                 181.11         208.00           0.00         208.00         1
# oil                                           8.19           1.40           0.00           1.40         1
# biomass                                       3.52         117.50           0.00         117.50         1
# solar                                  -205,018.27      36,639.68      41,521.01      78,160.70        59
# wind                                   -414,892.64      37,142.50      69,798.17     106,940.67        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  51,850,084.37
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 18.10 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,845.02 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 85.02 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
# Finished scenario 3: s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,338,488,112.99
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ...
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -139,948.14           0.00    -139,948.14                0.00              0.00         8
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,306,582.49
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 4
# ====================================================================================================
#
# Total Objective: $16,316,208,308.82
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,972,521,914.25
#   solar                          $3,392,778,277.39
#   battery                        $ 496,726,793.60
#   TOTAL                          $10,862,026,985.24
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,983,206,289.53
#   nuclear                        $ 829,306,118.44
#   coal                           $ 689,774,377.91
#   steam                          $  90,111,488.33
#   natural gas turbine            $  31,546,016.16
#   waste                          $  11,269,956.33
#   non-fossil                     $   3,679,774.60
#   biomass                        $     193,142.73
#   oil                            $     161,581.85
#   large_hydro                    $      12,377.62
#   small_hydro                    $       8,507.50
#   TOTAL                          $4,639,269,630.98
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 614,901,970.56
#   ERC_PHDL:ERC_WEST              $ 114,269,091.86
#   ERC_REST:ERC_WEST              $   2,997,894.37
#   ERC_WEST:ERC_PHDL              $       3,241.80
#   TOTAL                          $ 732,172,198.59
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,233,468,814.82
# Model Objective                $16,316,208,308.82
# Other Gap                      $  82,739,494.00
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,967.68 MWh
# ERC_REST -> ERC_WEST via line_5: 104.09 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.11 MWh
# ERC_WEST -> ERC_REST via line_8: 21,350.76 MWh
#
# Total transmission across all lines: 25,422.65 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              135,002.55      35,044.70           0.00      35,044.70         2  Scenario   4 ✓
#
# nuclear                                  41,395.16       4,960.00           0.00       4,960.00         1
# coal                                     30,678.30       8,603.07           0.00       8,603.07         1
# battery                                  22,356.45      17,500.00       4,739.22      22,239.22         3
# steam                                     2,522.37       9,055.70           0.00       9,055.70         2
# waste                                     1,617.48         210.40           0.00         210.40         2
# natural gas turbine                         807.26       8,608.50           0.00       8,608.50         2
# non-fossil                                  530.60          68.80           0.00          68.80         1
# small_hydro                                 301.85         341.10           0.00         341.10         1
# large_hydro                                 181.80         208.00           0.00         208.00         1
# oil                                           8.21           1.40           0.00           1.40         1
# biomass                                       3.64         117.50           0.00         117.50         1
# solar                                  -204,458.55      36,639.68      41,299.58      77,939.26        59
# wind                                   -414,325.45      37,142.50      69,637.93     106,780.43        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  51,306,582.49
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 13.57 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_ERC_PHDL:
#   Installed Capacity: 4.52 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 4.52 MW
#   Max Shift Down: -2.25 MW
#   Total Shifting: 6,274.23 MWh
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,383.77 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_ERC_REST:
#   Installed Capacity: 461.26 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 461.26 MW
#   Max Shift Down: -230.49 MW
#   Total Shifting: 861,814.23 MWh
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 63.77 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_ERC_WEST:
#   Installed Capacity: 21.26 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 21.26 MW
#   Max Shift Down: -10.62 MW
#   Total Shifting: 40,923.05 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_s04_slow_m0_d360/s04_s04_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_s04_slow_m0_d360/s04_s04_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_s04_slow_m0_d360/s04_s04_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_s04_slow_m0_d360/s04_s04_ev_summary.csv
# Finished scenario 4: s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360/s04_V1G_rps0_v1g25_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,316,208,308.82
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
# Added detail-equivalent aggregate V2G store to ERC_PHDL: max_power=43.40 MW, max_energy=43.40 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to ERC_REST: max_power=4424.82 MW, max_energy=4424.82 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to ERC_WEST: max_power=203.90 MW, max_energy=203.90 MWh, window_hours=24
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.4432766437530518
# Variables Built: 0.9589054584503174
# Constraints Built: 19.20833468437195
# Objective Built: 0.7107207775115967
#
# ================================================================================
#
# Parameters Built: 3.4949941635131836
# Variables Built: 0.9608335494995117
# Constraints Built: 18.832855701446533
# Objective Built: 0.7023184299468994
#
# ================================================================================
#
# Parameters Built: 3.676347255706787
# Variables Built: 1.029792070388794
# Constraints Built: 21.306803226470947
# Objective Built: 0.7855629920959473
#
# ================================================================================
#
# Parameters Built: 3.6947214603424072
# Variables Built: 1.0286552906036377
# Constraints Built: 21.65692925453186
# Objective Built: 0.8185303211212158
