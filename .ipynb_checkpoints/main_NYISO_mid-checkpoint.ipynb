# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "NYISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"
with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)

YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "NY"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/New_York_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    "mid", 
    # "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "NY_Z_J": 0.40,      # NYC - highest demand, most valuable storage
    "NY_Z_K": 0.20,      # Long Island - high demand, constrained transmission
    "NY_Z_F": 0.10,      # Capital region
    "NY_Z_C&E": 0.10,    # Central
    "NY_Z_G-I": 0.10,    # Hudson Valley - transmission relief
    "NY_Z_A": 0.05,      # Western NY
    "NY_Z_B": 0.025,     # Genesee
    "NY_Z_D": 0.025,     # North
}

STATE_TO_REGIONS = {
    "NY": [
        "NY_Z_A",
        "NY_Z_B",
        "NY_Z_C&E",
        "NY_Z_D",
        "NY_Z_F",
        "NY_Z_G-I",
        "NY_Z_J",
        "NY_Z_K"
    ],
}

RETIREMENT_POLICIES = {
    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },
}

ASSET_CONSTRAINT_POLICIES = {

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 690,
        },
    },
    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (mid)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 4
# # Total runs: 60 (= 15 scenarios × 4 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: MID
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: MID adoption + Midnight timed charging
# Results Directory: Output/NYISO/scenario_results_2030_mid_NYISO_midnight
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 5.988184690475464
# Parameters Built: 5.979314804077148
# Parameters Built: 6.015851736068726
# Parameters Built: 6.244729042053223
# Parameters Built: 6.295036315917969
# Variables Built: 4.054199695587158
# Variables Built: 4.022575616836548
# Variables Built: 4.100804090499878
# Variables Built: 4.436988353729248
# Variables Built: 4.479702472686768
# Constraints Built: 43.0123872756958
# Constraints Built: 43.13111639022827
# Constraints Built: 43.16691875457764
# Objective Built: 2.382355213165283
# Objective Built: 2.3577558994293213
# Objective Built: 2.3443236351013184
# Constraints Built: 45.04066729545593
# Constraints Built: 45.49748706817627
# Objective Built: 4.888557195663452
# Objective Built: 4.920242071151733
# Problem Solved: 1734.3682672977448
# Solution Graph Built: 69.10753083229065
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.033644676208496
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 31,213,978 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39       9,359.90      15,108.30          336,540.11          1,290.20       155
# solar                                8,460.55       6,033.31      14,493.86           80,759.09            565.97        64
# battery                                690.00           0.00         690.00          106,267.74              0.00         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,786.81           0.00     -33,786.81                0.00              0.00        16
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              4,304,091.91
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $4,366,251,682.42
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,290,202,345.08
#   solar                          $ 565,965,344.21
#   TOTAL                          $1,856,167,689.29
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $ 659,527,338.23
#   nuclear                        $ 612,304,982.37
#   import                         $ 239,195,771.45
#   steam                          $ 122,752,922.46
#   natural gas turbine            $ 108,945,710.41
#   oil                            $  78,499,344.98
#   waste                          $  25,151,597.67
#   biomass                        $  14,685,535.53
#   large_hydro                    $   7,352,289.40
#   non-fossil                     $     802,285.59
#   small_hydro                    $     241,002.35
#   TOTAL                          $1,869,458,780.45
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 195,930,475.83
#   NY_Z_F:NY_Z_G-I                $ 124,199,611.81
#   NY_Z_C&E:NY_Z_G-I              $ 113,121,807.11
#   NY_Z_C&E:NY_Z_F                $  92,848,996.61
#   NY_Z_G-I:NY_Z_K                $  52,070,984.86
#   NY_Z_D:NY_Z_C&E                $  23,423,179.84
#   NY_Z_K:NY_Z_J                  $   7,384,362.84
#   NY_Z_C&E:NY_Z_B                $   6,239,807.28
#   NY_Z_B:NY_Z_A                  $   5,844,405.42
#   NY_Z_A:NY_Z_B                  $   5,134,441.65
#   NY_Z_B:NY_Z_C&E                $   5,095,056.35
#   NY_Z_J:NY_Z_K                  $   3,639,422.04
#   NY_Z_K:NY_Z_G-I                $   2,495,019.31
#   NY_Z_C&E:NY_Z_D                $     617,759.43
#   TOTAL                          $ 638,045,330.38
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $4,363,671,800.11
# Model Objective                $4,366,251,682.42
# Other Gap                      $   2,579,882.31
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 178.28 MWh
# NY_Z_B -> NY_Z_A via line_81: 202.93 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 176.91 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 216.66 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 21.45 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 3,223.92 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,927.84 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 813.30 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 4,312.49 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 6,803.14 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 1,808.02 MWh
# NY_Z_J -> NY_Z_K via line_99: 126.37 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 86.63 MWh
# NY_Z_K -> NY_Z_J via line_102: 256.40 MWh
#
# Total transmission across all lines: 22,154.35 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               27,745.24      10,907.10           0.00      10,907.10         9
# nuclear                                  27,474.25       3,346.70           0.00       3,346.70         2
# large_hydro                               5,721.96       3,374.40           0.00       3,374.40         3
# small_hydro                               4,472.11       1,186.40           0.00       1,186.40         6
# steam                                     4,362.52      10,910.56           0.00      10,910.56         6
# import                                    3,796.76       5,850.00           0.00       5,850.00         3
# waste                                     3,626.38         473.20           0.00         473.20         8
# natural gas turbine                       3,468.74       2,545.92           0.00       2,545.92         8
# oil                                       2,505.60       1,699.11           0.00       1,699.11         5
# battery                                   1,283.10         690.00           0.00         690.00         8
# biomass                                     276.96          54.90           0.00          54.90         1
# non-fossil                                  115.65          20.20           0.00          20.20         2
# pump hydro                                    0.65           0.10           0.00           0.10         2
# solar                                   -27,997.09       8,460.55       6,033.31      14,493.86        64
# wind                                    -58,465.70       5,748.39       9,359.90      15,108.30       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   4,304,091.91
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 94.66 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 71.99 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 141.38 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 15.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 90.30 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 142.63 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 173.61 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 160.76 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_s01_mid_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_s01_mid_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_s01_mid_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_s01_mid_m0_d360/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_mid_NYISO_midnight/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 4,366,251,682.42
#   Scenario   1 ✓
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 11.279276847839355
# Variables Built: 3.9816770553588867
# Constraints Built: 78.54716849327087
# Objective Built: 3.9514870643615723
# Problem Solved: 2553.5334181785583
# Solution Graph Built: 62.774165868759155
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.4513027667999268
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 70.0%
# ============================================================================================================================================
#
# Gas Generation: 22,465,057 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      12,156.64      17,905.04          336,540.11          1,828.28       155
# solar                                8,460.55       8,236.07      16,696.61           80,759.09            776.14        64
# battery                                690.00         824.18       1,514.18          106,267.74             86.38         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,786.81           0.00     -33,786.81                0.00              0.00        24
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              8,877,869.38
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
# Total Objective: $5,612,507,610.41
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,828,279,537.69
#   solar                          $ 776,137,267.14
#   battery                        $  86,383,888.28
#   TOTAL                          $2,690,800,693.11
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   import                         $ 825,571,241.90
#   nuclear                        $ 612,206,756.54
#   natural gas combined cycle     $ 463,339,754.19
#   natural gas turbine            $ 103,209,840.44
#   oil                            $  56,969,647.53
#   steam                          $  46,002,890.74
#   waste                          $  22,702,581.04
#   biomass                        $  12,046,524.99
#   non-fossil                     $     414,709.40
#   small_hydro                    $     212,780.95
#   large_hydro                    $      32,601.30
#   TOTAL                          $2,142,709,329.02
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 244,953,837.08
#   NY_Z_F:NY_Z_G-I                $ 181,718,622.76
#   NY_Z_C&E:NY_Z_G-I              $ 107,585,026.29
#   NY_Z_C&E:NY_Z_F                $  79,824,704.91
#   NY_Z_G-I:NY_Z_K                $  63,237,028.82
#   NY_Z_D:NY_Z_C&E                $  39,441,755.46
#   NY_Z_J:NY_Z_K                  $  15,398,820.69
#   NY_Z_B:NY_Z_A                  $   8,584,063.70
#   NY_Z_K:NY_Z_J                  $   8,259,988.25
#   NY_Z_C&E:NY_Z_B                $   7,325,850.90
#   NY_Z_A:NY_Z_B                  $   7,153,773.60
#   NY_Z_B:NY_Z_C&E                $   5,779,088.53
#   NY_Z_K:NY_Z_G-I                $   2,834,074.88
#   NY_Z_C&E:NY_Z_D                $   1,220,529.15
#   NY_Z_F:NY_Z_C&E                $       4,554.75
#   TOTAL                          $ 773,321,719.75
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,606,831,741.88
# Model Objective                $5,612,507,610.41
# Other Gap                      $   5,675,868.53
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 248.39 MWh
# NY_Z_B -> NY_Z_A via line_81: 298.06 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 200.66 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 254.37 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 42.38 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 2,771.69 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,735.59 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 1,369.51 MWh
# NY_Z_F -> NY_Z_C&E via line_90: 0.16 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 6,309.67 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 8,505.34 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 2,195.73 MWh
# NY_Z_J -> NY_Z_K via line_99: 338.47 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 98.41 MWh
# NY_Z_K -> NY_Z_J via line_102: 286.81 MWh
#
# Total transmission across all lines: 26,655.24 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               19,178.93      10,907.10           0.00      10,907.10         9
# import                                   13,104.31       5,850.00           0.00       5,850.00         3
# small_hydro                               3,913.16       1,186.40           0.00       1,186.40         6
# battery                                   3,480.30         690.00         824.18       1,514.18         8
# natural gas turbine                       3,286.12       2,545.92           0.00       2,545.92         8
# waste                                     3,273.24         473.20           0.00         473.20         8
# oil                                       1,708.36       1,699.11           0.00       1,699.11         5
# steam                                     1,666.78      10,910.56           0.00      10,910.56         6
# biomass                                     227.19          54.90           0.00          54.90         1
# large_hydro                                 115.97       3,374.40           0.00       3,374.40         3
# ...
#   natural gas turbine            $ 110,760,228.16
#   oil                            $  81,618,668.26
#   waste                          $  25,445,396.64
#   biomass                        $  14,117,456.82
#   large_hydro                    $   7,554,783.04
#   non-fossil                     $     804,103.16
#   small_hydro                    $     243,930.98
#   TOTAL                          $1,779,408,200.37
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 208,278,204.42
#   NY_Z_F:NY_Z_G-I                $ 125,314,552.12
#   NY_Z_C&E:NY_Z_G-I              $ 114,763,030.49
#   NY_Z_C&E:NY_Z_F                $  94,736,244.84
#   NY_Z_G-I:NY_Z_K                $  43,259,550.48
#   NY_Z_D:NY_Z_C&E                $  22,960,563.04
#   NY_Z_K:NY_Z_J                  $   7,682,730.86
#   NY_Z_A:NY_Z_B                  $   5,754,497.41
#   NY_Z_C&E:NY_Z_B                $   5,291,984.02
#   NY_Z_B:NY_Z_A                  $   5,191,020.53
#   NY_Z_B:NY_Z_C&E                $   4,819,363.75
#   NY_Z_J:NY_Z_K                  $   3,765,505.22
#   NY_Z_K:NY_Z_G-I                $   2,656,708.43
#   NY_Z_C&E:NY_Z_D                $     526,018.98
#   TOTAL                          $ 644,999,974.58
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $4,285,702,263.54
# Model Objective                $4,300,713,509.78
# Other Gap                      $  15,011,246.24
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 199.81 MWh
# NY_Z_B -> NY_Z_A via line_81: 180.24 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 167.34 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 183.75 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 18.26 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 3,289.45 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,984.83 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 797.24 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 4,351.20 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 7,231.88 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 1,502.07 MWh
# NY_Z_J -> NY_Z_K via line_99: 130.75 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 92.25 MWh
# NY_Z_K -> NY_Z_J via line_102: 266.76 MWh
#
# Total transmission across all lines: 22,395.83 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               27,657.26      10,907.10           0.00      10,907.10         9
# nuclear                                  27,472.78       3,346.70           0.00       3,346.70         2
# large_hydro                               5,817.67       3,374.40           0.00       3,374.40         3
# steam                                     4,972.53      10,910.56           0.00      10,910.56         6
# small_hydro                               4,536.42       1,186.40           0.00       1,186.40         6
# waste                                     3,668.76         473.20           0.00         473.20         8
# natural gas turbine                       3,526.52       2,545.92           0.00       2,545.92         8
# oil                                       2,620.09       1,699.11           0.00       1,699.11         5
# import                                    2,078.50       5,850.00           0.00       5,850.00         3
# ev_v2g                                    1,243.25       1,304.35           0.00       1,304.35         8
# battery                                   1,229.57         690.00           0.00         690.00         8
# biomass                                     266.24          54.90           0.00          54.90         1
# non-fossil                                  115.92          20.20           0.00          20.20         2
# pump hydro                                    0.58           0.10           0.00           0.10         2
# solar                                   -28,682.95       8,460.55       6,362.22      14,822.76        64
# wind                                    -57,829.22       5,748.39       9,150.87      14,899.27       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   3,501,512.71
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 50.44 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_A:
#   Installed Capacity: 50.44 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 38.36 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_B:
#   Installed Capacity: 38.36 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 75.33 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_C&E:
#   Installed Capacity: 75.33 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 8.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_D:
#   Installed Capacity: 8.41 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 48.12 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_F:
#   Installed Capacity: 48.12 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 76.00 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_G-I:
#   Installed Capacity: 76.00 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 92.51 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_J:
#   Installed Capacity: 92.51 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 85.66 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_K:
#   Installed Capacity: 85.66 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_s13_mid_m0_d360/s13_s13_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_s13_mid_m0_d360/s13_s13_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_s13_mid_m0_d360/s13_s13_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_s13_mid_m0_d360/s13_s13_ev_summary.csv
# Finished scenario 14: s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 5,488,392,681.45
#   Scenario  14 ✓
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
# Added detail-equivalent aggregate V2G store to NY_Z_A: max_power=554.24 MW, max_energy=554.24 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_B: max_power=421.52 MW, max_energy=421.52 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_C&E: max_power=827.74 MW, max_energy=827.74 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_D: max_power=92.42 MW, max_energy=92.42 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_F: max_power=528.69 MW, max_energy=528.69 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_G-I: max_power=835.07 MW, max_energy=835.07 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_J: max_power=1016.49 MW, max_energy=1016.49 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to NY_Z_K: max_power=941.22 MW, max_energy=941.22 MWh, window_hours=24
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 7.097026348114014
# Finished scenario 13: s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_mid_NYISO_delay/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360/s13_V2G_rps60_v1g0_v2g50_bcapex315_mid_m0_d360_total_cost.csv
# Objective = 4,300,713,509.78
#   Scenario  13 ✓
# Variables Built: 3.297178030014038
