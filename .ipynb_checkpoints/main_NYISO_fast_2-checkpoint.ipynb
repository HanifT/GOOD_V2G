# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "NYISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"
with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)

YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "NY"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/New_York_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    "mid", 
    # "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "NY_Z_J": 0.40,      # NYC - highest demand, most valuable storage
    "NY_Z_K": 0.20,      # Long Island - high demand, constrained transmission
    "NY_Z_F": 0.10,      # Capital region
    "NY_Z_C&E": 0.10,    # Central
    "NY_Z_G-I": 0.10,    # Hudson Valley - transmission relief
    "NY_Z_A": 0.05,      # Western NY
    "NY_Z_B": 0.025,     # Genesee
    "NY_Z_D": 0.025,     # North
}

STATE_TO_REGIONS = {
    "NY": [
        "NY_Z_A",
        "NY_Z_B",
        "NY_Z_C&E",
        "NY_Z_D",
        "NY_Z_F",
        "NY_Z_G-I",
        "NY_Z_J",
        "NY_Z_K"
    ],
}

RETIREMENT_POLICIES = {
    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },
}

ASSET_CONSTRAINT_POLICIES = {

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 690,
        },
    },
    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "CA": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (slow)
# # Charging scenarios: 1 (arrive)
# # Total combinations: 1
# # Total runs: 15 (= 15 scenarios × 1 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Immediate arrival charging
# Results Directory: Output/NYISO/scenario_results_2030_slow_NYISO_arrive
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.062338590621948
# Variables Built: 4.186824321746826
# Constraints Built: 35.71782970428467
# Objective Built: 2.341989755630493
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.101719856262207
# Variables Built: 4.188841819763184
# Constraints Built: 35.67519783973694
# Objective Built: 2.3764758110046387
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.123179912567139
# Variables Built: 4.180830478668213
# Constraints Built: 35.92901635169983
# Objective Built: 2.375148296356201
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.468790531158447
# Variables Built: 4.487396478652954
# Constraints Built: 37.614776611328125
# Objective Built: 4.927057981491089
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.6385815143585205
# Variables Built: 4.4336817264556885
# Constraints Built: 37.53811073303223
# Objective Built: 4.9717278480529785
# Problem Solved: 1717.7412991523743
# Solution Graph Built: 70.73825407028198
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.259166717529297
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 31,136,886 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39       9,316.27      15,064.66          336,540.11          1,284.30       155
# solar                                8,460.55       6,026.17      14,486.72           80,759.09            565.28        64
# battery                                690.00           0.00         690.00          106,267.74              0.00         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,707.43           0.00     -33,707.43                0.00              0.00        16
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              4,302,242.83
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $4,356,046,484.76
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,284,295,216.65
#   solar                          $ 565,284,811.34
#   TOTAL                          $1,849,580,027.98
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $ 657,869,655.88
#   nuclear                        $ 612,307,027.04
#   import                         $ 238,356,619.45
#   steam                          $ 121,986,706.41
#   natural gas turbine            $ 108,712,179.00
#   oil                            $  78,366,256.39
#   waste                          $  25,150,676.12
#   biomass                        $  14,666,632.28
#   large_hydro                    $   7,335,744.64
#   non-fossil                     $     800,419.32
#   small_hydro                    $     240,954.25
#   TOTAL                          $1,865,792,870.79
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 196,014,569.10
#   NY_Z_F:NY_Z_G-I                $ 124,021,328.00
#   NY_Z_C&E:NY_Z_G-I              $ 113,126,675.27
#   NY_Z_C&E:NY_Z_F                $  92,993,274.06
#   NY_Z_G-I:NY_Z_K                $  52,105,071.55
#   NY_Z_D:NY_Z_C&E                $  23,289,224.84
#   NY_Z_K:NY_Z_J                  $   7,432,770.73
#   NY_Z_C&E:NY_Z_B                $   6,260,463.05
#   NY_Z_B:NY_Z_A                  $   5,868,328.38
#   NY_Z_A:NY_Z_B                  $   5,116,487.70
#   NY_Z_B:NY_Z_C&E                $   5,088,257.58
#   NY_Z_J:NY_Z_K                  $   3,659,504.75
#   NY_Z_K:NY_Z_G-I                $   2,492,379.81
#   NY_Z_C&E:NY_Z_D                $     625,224.46
#   TOTAL                          $ 638,093,559.30
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $4,353,466,458.07
# Model Objective                $4,356,046,484.76
# Other Gap                      $   2,580,026.69
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 177.66 MWh
# NY_Z_B -> NY_Z_A via line_81: 203.76 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 176.68 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 217.38 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 21.71 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 3,228.93 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,928.01 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 808.65 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 4,306.30 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 6,806.06 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 1,809.20 MWh
# NY_Z_J -> NY_Z_K via line_99: 127.07 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 86.54 MWh
# NY_Z_K -> NY_Z_J via line_102: 258.08 MWh
#
# Total transmission across all lines: 22,156.03 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================  Scenario   1 ✓
#
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               27,675.58      10,907.10           0.00      10,907.10         9
# nuclear                                  27,474.34       3,346.70           0.00       3,346.70         2
# large_hydro                               5,705.56       3,374.40           0.00       3,374.40         3
# small_hydro                               4,471.27       1,186.40           0.00       1,186.40         6
# steam                                     4,336.12      10,910.56           0.00      10,910.56         6
# import                                    3,783.44       5,850.00           0.00       5,850.00         3
# waste                                     3,626.24         473.20           0.00         473.20         8
# natural gas turbine                       3,461.30       2,545.92           0.00       2,545.92         8
# oil                                       2,500.64       1,699.11           0.00       1,699.11         5
# battery                                   1,289.76         690.00           0.00         690.00         8
# biomass                                     276.60          54.90           0.00          54.90         1
# non-fossil                                  115.38          20.20           0.00          20.20         2
# pump hydro                                    0.65           0.10           0.00           0.10         2
# solar                                   -27,981.97       8,460.55       6,026.17      14,486.72        64
# wind                                    -58,324.99       5,748.39       9,316.27      15,064.66       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   4,302,242.83
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 86.23 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 65.58 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 128.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 14.38 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 82.25 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 129.92 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 158.15 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 146.44 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_s01_slow_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_s01_slow_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_s01_slow_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_s01_slow_m0_d360/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 4,356,046,484.76
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 10.424424886703491
# Variables Built: 3.7537410259246826
# Constraints Built: 70.60025453567505
# Objective Built: 3.0781476497650146
# Problem Solved: 2188.0863909721375
# Solution Graph Built: 55.11097311973572
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.442211389541626
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 70.0%
# ============================================================================================================================================
#
# Gas Generation: 22,392,374 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      12,145.00      17,893.39          336,540.11          1,826.89       155
# solar                                8,460.55       8,205.36      16,665.91           80,759.09            773.21        64
# battery                                690.00         825.16       1,515.16          106,267.74             86.49         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,707.43           0.00     -33,707.43                0.00              0.00        24
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              8,898,201.51
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
# Total Objective: $5,601,737,716.52
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,826,890,889.63
#   solar                          $ 773,213,547.67
#   battery                        $  86,486,855.20
#   TOTAL                          $2,686,591,292.51
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   import                         $ 821,623,787.51
#   nuclear                        $ 612,206,756.54
#   natural gas combined cycle     $ 461,886,909.94
#   natural gas turbine            $ 102,829,363.97
#   oil                            $  56,925,711.17
#   steam                          $  45,579,956.61
#   waste                          $  22,684,654.38
#   biomass                        $  12,014,842.86
#   non-fossil                     $     413,476.02
#   small_hydro                    $     212,547.28
#   large_hydro                    $      32,347.31
#   TOTAL                          $2,136,410,353.58
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 245,174,753.65
#   NY_Z_F:NY_Z_G-I                $ 181,838,008.34
#   NY_Z_C&E:NY_Z_G-I              $ 107,625,387.99
#   NY_Z_C&E:NY_Z_F                $  79,692,586.29
#   NY_Z_G-I:NY_Z_K                $  63,234,208.82
#   NY_Z_D:NY_Z_C&E                $  39,242,474.37
#   NY_Z_J:NY_Z_K                  $  15,192,715.73
#   NY_Z_B:NY_Z_A                  $   8,627,287.97
#   NY_Z_K:NY_Z_J                  $   8,230,570.42
#   NY_Z_C&E:NY_Z_B                $   7,331,548.47
#   NY_Z_A:NY_Z_B                  $   7,052,945.16
#   NY_Z_B:NY_Z_C&E                $   5,742,995.51
#   NY_Z_K:NY_Z_G-I                $   2,836,125.88
#   NY_Z_C&E:NY_Z_D                $   1,230,597.06
#   NY_Z_F:NY_Z_C&E                $       3,931.79
#   TOTAL                          $ 773,056,137.46
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,596,057,783.55
# Model Objective                $5,601,737,716.52
# Other Gap                      $   5,679,932.97
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 244.89 MWh
# NY_Z_B -> NY_Z_A via line_81: 299.56 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 199.41 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 254.57 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 42.73 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 2,767.10 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,736.99 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 1,362.59 MWh
# NY_Z_F -> NY_Z_C&E via line_90: 0.14 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 6,313.82 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 8,513.01 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 2,195.63 MWh
# NY_Z_J -> NY_Z_K via line_99: 338.19 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 98.48 MWh
# NY_Z_K -> NY_Z_J via line_102: 285.78 MWh
#
# Total transmission across all lines: 26,652.89 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================  Scenario   5 ✓
#
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               19,118.36      10,907.10           0.00      10,907.10         9
# import                                   13,041.65       5,850.00           0.00       5,850.00         3
# small_hydro                               3,908.28       1,186.40           0.00       1,186.40         6
# battery                                   3,500.17         690.00         825.16       1,515.16         8
# natural gas turbine                       3,274.01       2,545.92           0.00       2,545.92         8
# waste                                     3,270.65         473.20           0.00         473.20         8
# oil                                       1,706.72       1,699.11           0.00       1,699.11         5
# steam                                     1,650.25      10,910.56           0.00      10,910.56         6
# biomass                                     226.59          54.90           0.00          54.90         1
# ...
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s09_V2G_rps80_v1g0_v2g25_bcapex315_slow_m0_d360/s09_V2G_rps80_v1g0_v2g25_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 10,146,915,395.85
#
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                 126,392.07         690.00      25,672.33      26,362.33         8
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               10,167.59      10,907.10           0.00      10,907.10         9
# small_hydro                               3,885.60       1,186.40           0.00       1,186.40         6
# waste                                     3,059.70         473.20           0.00         473.20         8
# import                                    1,954.73       5,850.00           0.00       5,850.00         3
# oil                                       1,470.98       1,699.11           0.00       1,699.11         5
# natural gas turbine                         879.02       2,545.92           0.00       2,545.92         8
# biomass                                     199.91          54.90           0.00          54.90         1
# steam                                        26.12      10,910.56           0.00      10,910.56         6
# non-fossil                                    3.07          20.20           0.00          20.20         2
# pump hydro                                    0.36           0.10           0.00           0.10         2
# large_hydro                                   0.00       3,374.40           0.00       3,374.40         3
# solar                                   -64,700.95       8,460.55      24,199.19      32,659.74        64
# wind                                    -86,682.33       5,748.39      16,895.76      22,644.16       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  13,667,354.80
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 64.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_A:
#   Installed Capacity: 21.56 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 21.56 MW
#   Max Shift Down: -10.73 MW
#   Total Shifting: 39,857.33 MWh
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 49.19 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_B:
#   Installed Capacity: 16.40 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 16.40 MW
#   Max Shift Down: -8.16 MW
#   Total Shifting: 34,765.98 MWh
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 96.59 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_C&E:
#   Installed Capacity: 32.20 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 32.20 MW
#   Max Shift Down: -16.03 MW
#   Total Shifting: 69,938.63 MWh
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 10.78 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_D:
#   Installed Capacity: 3.59 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 3.59 MW
#   Max Shift Down: -1.79 MW
#   Total Shifting: 6,776.32 MWh
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 61.69 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_F:
#   Installed Capacity: 20.56 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 20.56 MW
#   Max Shift Down: -10.24 MW
#   Total Shifting: 50,639.54 MWh
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 97.44 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_G-I:
#   Installed Capacity: 32.48 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 32.48 MW
#   Max Shift Down: -16.17 MW
#   Total Shifting: 84,542.73 MWh
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 118.61 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_J:
#   Installed Capacity: 39.54 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 39.54 MW
#   Max Shift Down: -19.69 MW
#   Total Shifting: 103,335.48 MWh
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 109.83 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_K:
#   Installed Capacity: 36.61 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 36.61 MW
#   Max Shift Down: -18.23 MW
#   Total Shifting: 80,811.40 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_s06_slow_m0_d360/s06_s06_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_s06_slow_m0_d360/s06_s06_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_s06_slow_m0_d360/s06_s06_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_s06_slow_m0_d360/s06_s06_ev_summary.csv
# Finished scenario 6: s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360/s06_V1G_rps80_v1g25_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 10,171,037,502.51
#
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                 126,214.36         690.00      25,601.31      26,291.31         8
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               10,159.73      10,907.10           0.00      10,907.10         9
# small_hydro                               3,883.34       1,186.40           0.00       1,186.40         6
# waste                                     3,058.28         473.20           0.00         473.20         8
# import                                    1,942.76       5,850.00           0.00       5,850.00         3
# oil                                       1,470.86       1,699.11           0.00       1,699.11         5
# natural gas turbine                         877.61       2,545.92           0.00       2,545.92         8
# biomass                                     200.08          54.90           0.00          54.90         1
# steam                                        25.82      10,910.56           0.00      10,910.56         6
# non-fossil                                    3.07          20.20           0.00          20.20         2
# pump hydro                                    0.37           0.10           0.00           0.10         2
# large_hydro                                   0.00       3,374.40           0.00       3,374.40         3
# solar                                   -64,693.66       8,460.55      24,193.63      32,654.18        64
# wind                                    -86,651.36       5,748.39      16,888.00      22,636.39       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  13,634,846.86
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 43.12 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_A:
#   Installed Capacity: 43.12 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 43.12 MW
#   Max Shift Down: -21.47 MW
#   Total Shifting: 79,813.03 MWh
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 32.79 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_B:
#   Installed Capacity: 32.79 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 32.79 MW
#   Max Shift Down: -16.33 MW
#   Total Shifting: 69,142.93 MWh
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 64.39 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_C&E:
#   Installed Capacity: 64.39 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 64.39 MW
#   Max Shift Down: -32.06 MW
#   Total Shifting: 139,715.66 MWh
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 7.19 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_D:
#   Installed Capacity: 7.19 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 7.19 MW
#   Max Shift Down: -3.58 MW
#   Total Shifting: 13,525.66 MWh
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 41.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_F:
#   Installed Capacity: 41.13 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 41.13 MW
#   Max Shift Down: -20.48 MW
#   Total Shifting: 101,160.91 MWh
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 64.96 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_G-I:
#   Installed Capacity: 64.96 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 64.96 MW
#   Max Shift Down: -32.34 MW
#   Total Shifting: 168,972.91 MWh
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 79.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_J:
#   Installed Capacity: 79.07 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 79.07 MW
#   Max Shift Down: -39.37 MW
#   Total Shifting: 205,649.99 MWh
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 73.22 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_K:
#   Installed Capacity: 73.22 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 73.22 MW
#   Max Shift Down: -36.46 MW
#   Total Shifting: 162,311.65 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_s12_slow_m0_d360/s12_s12_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_s12_slow_m0_d360/s12_s12_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_s12_slow_m0_d360/s12_s12_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_s12_slow_m0_d360/s12_s12_ev_summary.csv
# Finished scenario 12: s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 10,159,550,895.65
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/NYISO/scenario_results_2030_slow_NYISO_arrive/all_scenarios_summary.csv
