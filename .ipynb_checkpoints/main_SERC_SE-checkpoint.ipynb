# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 10
IPM_REGION = "SERC-E"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}
# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

SERC_E_REGIONS = [
    "S_VACA",
]

STATE_TO_REGIONS = {
    "SERC-E": SERC_E_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EIA-860M operating battery capacity, June 2026
#
# S_VACA    368.8 MW
#
# North Carolina    280.8 MW
# South Carolina     88.0 MW
#
# Total             368.8 MW
#
# EPA NEEDS January 2024 contained only 176.3 MW.
# The EIA value is used because it represents the newer
# operating battery fleet.
#
# Pumped storage is excluded.

BATTERY_WEIGHTS = {
    "S_VACA": 1.0000,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# Denominators come from the EPA NEEDS January 2024
# active-resource sheet.
#
# The coal retirement amount includes:
#
# 3,780 MW identified in NEEDS for retirement by 2029
# 1,130 MW at Winyah identified by EIA for retirement in 2030
#
# Total coal retirement through 2030: 4,910 MW

RETIREMENT_POLICIES = {
    "SERC-E": {
        # 4,910 MW scheduled retirement
        # from 13,598 MW of active coal capacity.
        #
        # Roxboro:       1,047 MW
        # Marshall:        740 MW
        # Mayo:            704 MW
        # Wateree:         684 MW
        # Williams:        605 MW
        # Winyah:        1,130 MW
        "coal": 0.3611,

        # No identified retirement through 2030
        # from 797.5 MW of active O/G steam capacity.
        "oil": 0.0000,

        # No identified retirement through 2030
        # from 9,453.9 MW of combustion-turbine capacity.
        "natural gas turbine": 0.0000,

        # No identified retirement through 2030
        # from 8,806 MW of combined-cycle capacity.
        "natural gas combined cycle": 0.0000,

        # No identified retirement through 2030
        # from 11,800 MW of nuclear capacity.
        "nuclear": 0.0000,
    }
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "SERC-E": {
        # SERC-E 2030 central logic:
        #
        # S_VACA primarily represents the Virginia-Carolinas region.
        # The region has large nuclear, coal, natural-gas, hydro,
        # solar, and pumped-storage fleets.
        #
        # Nuclear remains highly must-run because it provides a large
        # share of reliable, low-carbon generation.
        #
        # Coal retains a moderate aggregated minimum-output floor.
        # The floor accounts for the operation of the remaining coal
        # units but leaves room for growing solar generation and
        # scheduled coal retirements.
        #
        # Combined-cycle gas supports reliability and changing demand
        # without being forced to operate as baseload in every hour.
        #
        # Combustion turbines remain flexible peaking resources.
        #
        # The O/G steam category contains approximately 797.5 MW and
        # is almost entirely natural-gas-fired steam capacity. A small
        # minimum-output floor represents some steam capacity remaining
        # online. Its ramp limit is an hourly planning approximation.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.20,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            # Represents the NEEDS O/G steam category.
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 368,
        },
    },
    "SERC-E": {
        "battery": {
            "total_power_mw": 368,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "SERC-E": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "SERC-E": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 3 (slow, mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 12
# # Total runs: 180 (= 15 scenarios × 12 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight
# ================================================================================
#
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.025, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.21, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.125, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.31, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.225, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.41, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.125, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.31, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.025, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.21, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# Parameters Built: 1.80745267868042
# Parameters Built: 1.8490326404571533
# Parameters Built: 1.8658578395843506
# Parameters Built: 1.8789730072021484
# Parameters Built: 2.0038628578186035
# Variables Built: 1.3907957077026367
# Variables Built: 1.4053056240081787
# Variables Built: 1.4357798099517822
# Variables Built: 1.5308690071105957
# Variables Built: 1.5243468284606934
# Constraints Built: 8.662657976150513
# Constraints Built: 8.736175537109375
# Constraints Built: 9.026848077774048
# Constraints Built: 9.560741662979126
# Objective Built: 1.1543922424316406
# Objective Built: 1.1252250671386719
# Constraints Built: 9.907636880874634
# Objective Built: 0.5700042247772217
# Objective Built: 1.1670043468475342
# Objective Built: 0.5680856704711914
# Problem Solved: 33.32683348655701
# Solution Graph Built: 2.491579532623291
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Problem Solved: 35.9305202960968
# Solution DataFrame Built: 0.41365981101989746
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Problem Solved: 37.07220721244812
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 64,693,371 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                368.00      12,151.22      12,519.22          106,267.74          1,273.59         1
# biomass                                307.70           0.00         307.70                0.00              0.00         2
# coal                                 9,120.94           0.00       9,120.94                0.00              0.00         2
# large_hydro                          1,260.50           0.00       1,260.50                0.00              0.00         2
# natural gas combined cycle          11,654.82           0.00      11,654.82                0.00              0.00         3
# natural gas turbine                 14,326.60           0.00      14,326.60                0.00              0.00         3
# non-fossil                              53.70           0.00          53.70                0.00              0.00         2
# nuclear                             11,729.80           0.00      11,729.80                0.00              0.00         2
# oil                                    498.10           0.00         498.10                0.00              0.00         2
# pump hydro                               0.21           0.00           0.21                0.00              0.00         1
# small_hydro                          1,181.90           0.00       1,181.90                0.00              0.00         3
# solar                                9,825.53           0.00       9,825.53           82,086.34              0.00        31
# steam                                  519.30           0.00         519.30                0.00              0.00         2
# unknown                            -50,401.68           0.00     -50,401.68                0.00              0.00         2
# waste                                  145.33           0.00         145.33                0.00              0.00         3
# wind                                 6,777.33           0.00       6,777.33          111,351.88              0.00        32
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $5,940,224,214.29
#
# Solution Graph Built: 2.441239833831787
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   battery                        $1,273,593,654.92
#   TOTAL                          $1,273,593,654.92
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $2,272,710,894.30
#   natural gas combined cycle     $1,631,621,074.39
#   coal                           $ 604,611,168.72
#   oil                            $  90,789,699.87
#   waste                          $   8,560,254.11
#   natural gas turbine            $   6,028,319.05
#   non-fossil                     $   3,152,237.02
#   steam                          $   1,515,286.03
#   biomass                        $     755,639.88
#   large_hydro                    $     324,151.01
#   small_hydro                    $     135,724.96
#   TOTAL                          $4,620,204,449.35
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,893,798,104.27
# Model Objective                $5,940,224,214.29
# Other Gap                      $  46,426,110.02
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# Solution DataFrame Built: 0.4060938358306885
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# nuclear                                 100,560.92      11,729.80           0.00      11,729.80         2
# natural gas combined cycle               64,557.86      11,654.82           0.00      11,654.82         3
# coal                                     20,586.33       9,120.94           0.00       9,120.94         2
# battery                                   5,632.48         368.00      12,151.22      12,519.22         1
# large_hydro                               2,665.01       1,260.50           0.00       1,260.50         2
# small_hydro                               2,515.53       1,181.90           0.00       1,181.90         3
# waste                                     1,229.80         145.33           0.00         145.33         3
# non-fossil                                  454.41          53.70           0.00          53.70         2
# oil                                         430.36         498.10           0.00         498.10         2
# natural gas turbine                         135.51      14,326.60           0.00      14,326.60         3
# steam                                        45.54         519.30           0.00         519.30         2
# biomass                                      22.94         307.70           0.00         307.70         2
# pump hydro                                    2.08           0.21           0.00           0.21         1
# solar                                   -24,406.04       9,825.53           0.00       9,825.53        31
# wind                                    -24,634.54       6,777.33           0.00       6,777.33        32
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 31
# Wind assets found : 32
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_VACA:
#   Installed Capacity: 1,465.86 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s01_s01_slow_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s01_s01_slow_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s01_s01_slow_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s01_s01_slow_m0_d360/s01_s01_ev_summary.csv
# Problem Solved: 38.6577422618866
# Solution Graph Built: 2.566359758377075
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 64,691,271 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                368.00      12,151.22      12,519.22          106,267.74          1,273.59         1
# biomass                                307.70           0.00         307.70                0.00              0.00         2
# coal                                 9,120.94           0.00       9,120.94                0.00              0.00         2
# large_hydro                          1,260.50           0.00       1,260.50                0.00              0.00         2
# natural gas combined cycle          11,654.82           0.00      11,654.82                0.00              0.00         3
# natural gas turbine                 14,326.60           0.00      14,326.60                0.00              0.00         3
# non-fossil                              53.70           0.00          53.70                0.00              0.00         2
# nuclear                             11,729.80           0.00      11,729.80                0.00              0.00         2
# oil                                    498.10           0.00         498.10                0.00              0.00         2
# pump hydro                               0.21           0.00           0.21                0.00              0.00         1
# small_hydro                          1,181.90           0.00       1,181.90                0.00              0.00         3
# solar                                9,825.53           0.00       9,825.53           82,086.34              0.00        31
# steam                                  519.30           0.00         519.30                0.00              0.00         2
# unknown                            -50,401.68           0.00     -50,401.68                0.00              0.00         2
# waste                                  145.33           0.00         145.33                0.00              0.00         3
# wind                                 6,777.33           0.00       6,777.33          111,351.88              0.00        32
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Solution DataFrame Built: 0.40651392936706543
# Total Objective: $5,940,292,244.76
#
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   battery                        $1,273,593,654.92
#   TOTAL                          $1,273,593,654.92
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $2,272,876,219.54
#   natural gas combined cycle     $1,631,596,999.44
#   coal                           $ 604,560,328.55
#   oil                            $  90,789,699.87
#   waste                          $   8,560,254.11
#   natural gas turbine            $   6,028,325.98
#   non-fossil                     $   3,152,237.02
#   steam                          $   1,500,210.63
#   biomass                        $     742,705.16
#   large_hydro                    $     326,332.02
#   small_hydro                    $     135,849.05
#   TOTAL                          $4,620,269,161.39
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,893,862,816.31
# Model Objective                $5,940,292,244.76
# Other Gap                      $  46,429,428.45
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# nuclear                                 100,568.27      11,729.80           0.00      11,729.80         2
# natural gas combined cycle               64,555.76      11,654.82           0.00      11,654.82         3
# coal                                     20,584.30       9,120.94           0.00       9,120.94         2
# battery                                   5,785.49         368.00      12,151.22      12,519.22         1
# large_hydro                               2,684.72       1,260.50           0.00       1,260.50         2
# small_hydro                               2,519.24       1,181.90           0.00       1,181.90         3
# waste                                     1,229.80         145.33           0.00         145.33         3
# non-fossil                                  454.41          53.70           0.00          53.70         2
# oil                                         430.36         498.10           0.00         498.10         2
# natural gas turbine                         135.51      14,326.60           0.00      14,326.60         3
# steam                                        45.11         519.30           0.00         519.30         2
# biomass                                      22.54         307.70           0.00         307.70         2
# pump hydro                                    2.10           0.21           0.00           0.21         1
# solar                                   -24,406.04       9,825.53           0.00       9,825.53        31
# wind                                    -24,634.54       6,777.33           0.00       6,777.33        32
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 31
# Wind assets found : 32
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_VACA:
#   Installed Capacity: 1,465.86 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s02_s02_slow_m0_d360/s02_s02_cost_components.csv
# Capex detail CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s02_s02_slow_m0_d360/s02_s02_capex_detail.csv
# Capex summary CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s02_s02_slow_m0_d360/s02_s02_capex_summary.csv
# EV summary CSV: Output/SERC-E/scenario_results_2030_slow_SERC-E_midnight/s02_s02_slow_m0_d360/s02_s02_ev_summary.csv
# Solution Graph Built: 2.485884189605713
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 64,632,563 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                368.00      11,981.27      12,349.27          106,267.74          1,255.78         1
# biomass                                307.70           0.00         307.70                0.00              0.00         2
# coal                                 9,120.94           0.00       9,120.94                0.00              0.00         2
# large_hydro                          1,260.50           0.00       1,260.50                0.00              0.00         2
# natural gas combined cycle          11,654.82           0.00      11,654.82                0.00              0.00         3
# natural gas turbine                 14,326.60           0.00      14,326.60                0.00              0.00         3
# non-fossil                              53.70           0.00          53.70                0.00              0.00         2
# nuclear                             11,729.80           0.00      11,729.80                0.00              0.00         2
# oil                                    498.10           0.00         498.10                0.00              0.00         2
# pump hydro                               0.21           0.00           0.21                0.00              0.00         1
# small_hydro                          1,181.90           0.00       1,181.90                0.00              0.00         3
# solar                                9,825.53           0.00       9,825.53           82,086.34              0.00        31
# steam                                  519.30           0.00         519.30                0.00              0.00         2
# unknown                            -50,401.68           0.00     -50,401.68                0.00              0.00         3
# waste                                  145.33           0.00         145.33                0.00              0.00         3
# wind                                 6,777.33           0.00       6,777.33          111,351.88              0.00        32
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
# Solution DataFrame Built: 0.39119768142700195
# Total Objective: $5,920,674,313.39
#
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   battery                        $1,255,780,762.06
#   TOTAL                          $1,255,780,762.06
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $2,273,091,989.55
#   natural gas combined cycle     $1,630,005,634.08
#   coal                           $ 604,762,506.13
#   oil                            $  90,789,699.87
#   waste                          $   8,559,242.50
#   natural gas turbine            $   5,999,564.48
#   non-fossil                     $   3,152,031.63
#   steam                          $   1,511,975.95
#   biomass                        $     765,029.22
#   large_hydro                    $     325,867.57
#   small_hydro                    $     135,699.28
#   TOTAL                          $4,619,099,240.26
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,874,880,002.33
# Model Objective                $5,920,674,313.39
# Other Gap                      $  45,794,311.06
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# Finished scenario 1: s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d360
# ...
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.025, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.21, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.025, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.21, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.225, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.41, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.125, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.31, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# EV state: SERC-E
# Model region: SERC-E
# STATE_TO_REGIONS key used: SERC-E
# GOOD regions used: ['S_VACA']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SERC-E_NC: ratio=0.125, regions=['S_VACA']
#   rps_SERC-E_VA: ratio=0.31, regions=['S_VACA']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-E
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# Processed 58 renewable plants with capex
# Skipped 5 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 36.11%
# Capacity before  : 14,276.00 MW
# Capacity after   : 9,120.94 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 35
# Exact duplicate groups: 0
# Assets contained in duplicate groups: 0
# Assets potentially removable: 0
# CAPEX variables after exact aggregation: 35
# ================================================================================
#
# Largest exact groups:
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
#        policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SERC-E_NC excluded   generator                       coal           NC         False            1  5808.878800
# rps_SERC-E_NC excluded   generator natural gas combined cycle           NC         False            1  7413.393094
# rps_SERC-E_NC excluded   generator        natural gas turbine           NC         False            1  9348.947192
# rps_SERC-E_NC excluded   generator                 non-fossil           NC         False            1     5.200000
# rps_SERC-E_NC excluded   generator                    nuclear           NC         False            1  5153.600000
# rps_SERC-E_NC excluded   generator                        oil           NC         False            1   274.100000
# rps_SERC-E_NC excluded   generator                      steam           NC         False            1     1.000000
# rps_SERC-E_NC excluded large_hydro                large_hydro           NC         False            1   486.000000
# rps_SERC-E_NC included   generator                    biomass           NC          True            1    83.500000
# rps_SERC-E_NC included   generator                      waste           NC          True            1    92.009012
# rps_SERC-E_NC included small_hydro                small_hydro           NC          True            1   615.400000
# rps_SERC-E_NC included       solar                      solar           NC          True           15  6657.523715
# rps_SERC-E_NC included        wind                       wind           NC          True           19  3787.270113
# ================================================================================
#
# Parameters Built: 1.8144207000732422
# Parameters Built: 1.8083648681640625
# Parameters Built: 1.853529691696167
# Parameters Built: 1.8804993629455566
# Parameters Built: 1.8617160320281982
# Variables Built: 1.4171721935272217
# Variables Built: 1.3914060592651367
# Variables Built: 1.4494688510894775
# Variables Built: 1.5089070796966553
# Variables Built: 1.5284340381622314
# Constraints Built: 8.656702756881714
# Constraints Built: 8.798782348632812
# Constraints Built: 9.055756092071533
# Objective Built: 1.1216347217559814
# Objective Built: 1.1500191688537598
# Constraints Built: 9.86476993560791
# Constraints Built: 9.817562580108643
# Objective Built: 1.1759247779846191
# Objective Built: 0.5667111873626709
# Objective Built: 0.5742628574371338
