# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 1
CPLEX_THREADS_PER_SCENARIO = 120
IPM_REGION = "PJM"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 7

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    # "mid",
    # "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    # "arrive": {
    #     "profile": "min_delay",
    #     "description": "Immediate arrival charging",
    # },
    # "flex": {
    #     "profile": "load_leveling",
    #     "description": "Flexible load leveling",
    # },
}

# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------
PJM_REGIONS = [
    "PJM_AP",
    "PJM_ATSI",
    "PJM_COMD",
    "PJM_Dom",
    "PJM_EMAC",
    "PJM_PENE",
    "PJM_SMAC",
    "PJM_WMAC",
    "PJM_West",
]

STATE_TO_REGIONS = {
    "PJM": PJM_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
BATTERY_WEIGHTS = {
    "PJM_Dom": 0.18,
    "PJM_COMD": 0.16,
    "PJM_West": 0.14,
    "PJM_AP": 0.12,
    "PJM_ATSI": 0.12,
    "PJM_SMAC": 0.10,
    "PJM_EMAC": 0.08,
    "PJM_PENE": 0.06,
    "PJM_WMAC": 0.04,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# These are for single-state regions.
# PJM state-specific retirement should come from the scenario JSON
# or from s_runner if you add that support there.
RETIREMENT_POLICIES = {
    "TX": {
        "coal": 1 / 3,
    },
    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },
    "CA": {
        "oil": 0.70,
        "nuclear": 1.00,
        "natural gas turbine": 0.20,
        "natural gas combined cycle": 0.04,
        "coal": 1.00,
    },
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "TX": {
        # ERCOT 2030 central logic:
        # Nuclear is small in capacity but high in energy output, so keep it highly must-run.
        # Coal is still meaningful, but do NOT force it at 45% in a 2030 renewable-heavy case.
        # Combined-cycle gas should provide reliability, but not behave as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },
    },

    "CA": {
        # CAISO / California 2030 central logic:
        # Do not add a nuclear constraint unless your GOOD input data explicitly includes CA nuclear.
        # California policy still treats Diablo Canyon as a transition/reliability resource, not a long-run
        # 2030+ baseload expansion resource.
        # Gas must stay flexible because CA has solar-heavy duck-curve conditions.

        # If your GOOD data has a CA "nuclear" category and you are modeling a 2030 week
        # before Diablo Canyon Unit 2 retirement, you may add this sensitivity:
        #
        # "nuclear": {
        #     "must_run_fraction": 0.60,
        #     "ramp_rate": 0.03,
        # },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.08,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "FL": {
        # Florida / FRCC 2030 central logic:
        # Nuclear is baseload.
        # Florida relies heavily on natural gas, especially combined-cycle gas.
        # Coal still exists but should have a low floor because coal retirements and solar growth continue.
        # Oil should not be must-run.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.04,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.18,
            "ramp_rate": 0.18,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.60,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "PJM": {
        # PJM 2030 central logic:
        # Nuclear is large and should remain highly must-run.
        # Coal is still important, but a 45% hourly floor is too high for a 2030 policy/RPS case.
        # Combined-cycle gas is important for reliability and load growth, but it should not be forced
        # as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 400,
        },
    },
    "CA": {
        "battery": {
            "total_power_mw": 16900,
        },
    },
    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },
    "TX": {
        "battery": {
            "total_power_mw": 17900,
        },
    },
    "PJM": {
        "battery": {
            "total_power_mw": 400,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
    "CA": {},
    "TX": {},
    "PJM": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
    "CA": {},
    "TX": {},
    "PJM": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (slow)
# # Charging scenarios: 1 (midnight)
# # Total combinations: 1
# # Total runs: 15 (= 15 scenarios × 1 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/PJM/scenario_results_2030_slow_PJM_midnight
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.1, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.025, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.21, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_PJM_DE excluded   generator                       coal           DE         False            1   410.000000
# rps_PJM_DE excluded   generator natural gas combined cycle           DE         False            1  1511.000000
# rps_PJM_DE excluded   generator        natural gas turbine           DE         False            1   348.174346
# rps_PJM_DE excluded   generator                        oil           DE         False            1   114.100000
# rps_PJM_DE excluded   generator                      steam           DE         False            1   710.000000
# rps_PJM_DE included   generator                      waste           DE          True            1   151.896811
# rps_PJM_DE included       solar                      solar           DE          True            8   493.856581
# rps_PJM_DE included        wind                       wind           DE          True           13     2.000000
# rps_PJM_IL excluded   generator                       coal           IL         False            1  1578.400000
# rps_PJM_IL excluded   generator natural gas combined cycle           IL         False            1  4858.900000
# rps_PJM_IL excluded   generator        natural gas turbine           IL         False            1  7232.200000
# rps_PJM_IL excluded   generator                 non-fossil           IL         False            1     3.000000
# rps_PJM_IL excluded   generator                    nuclear           IL         False            1 10517.400000
# rps_PJM_IL excluded   generator                        oil           IL         False            1   351.100000
# rps_PJM_IL excluded   generator                      steam           IL         False            1  1378.000000
# rps_PJM_IL included   generator                      waste           IL          True            1    77.082203
# rps_PJM_IL included small_hydro                small_hydro           IL          True            1    29.700000
# rps_PJM_IL included       solar                      solar           IL          True            8  1237.873000
# rps_PJM_IL included        wind                       wind           IL          True           19  4583.900000
# rps_PJM_MD excluded   generator                       coal           MD         False            2  1758.000000
# rps_PJM_MD excluded   generator natural gas combined cycle           MD         False            2  2849.100000
# rps_PJM_MD excluded   generator        natural gas turbine           MD         False            2  1966.828626
# rps_PJM_MD excluded   generator                 non-fossil           MD         False            1     1.800000
# rps_PJM_MD excluded   generator                    nuclear           MD         False            1  1725.800000
# rps_PJM_MD excluded   generator                        oil           MD         False            2   364.400002
# rps_PJM_MD excluded   generator                      steam           MD         False            2  1922.000000
# rps_PJM_MD excluded large_hydro                large_hydro           MD         False            1   572.000000
# rps_PJM_MD included   generator                      waste           MD          True            3   159.673876
# rps_PJM_MD included small_hydro                small_hydro           MD          True            1    18.000000
# rps_PJM_MD included       solar                      solar           MD          True           24  5670.461318
# rps_PJM_MD included        wind                       wind           MD          True           50  1967.391403
# rps_PJM_MI excluded   generator natural gas combined cycle           MI         False            1  1084.000000
# rps_PJM_MI excluded   generator        natural gas turbine           MI         False            1     6.000000
# rps_PJM_MI excluded   generator                    nuclear           MI         False            1  2177.000000
# rps_PJM_MI included   generator                      waste           MI          True            1     9.231113
# rps_PJM_MI included small_hydro                small_hydro           MI          True            1     9.800000
# rps_PJM_MI included       solar                      solar           MI          True            8    54.615856
# rps_PJM_MI included        wind                       wind           MI          True           12     0.000000
# rps_PJM_NC excluded   generator natural gas combined cycle           NC         False            1   165.000000
# rps_PJM_NC excluded   generator                 non-fossil           NC         False            1    71.000000
# rps_PJM_NC excluded   generator                        oil           NC         False            1    17.400000
# rps_PJM_NC excluded large_hydro                large_hydro           NC         False            1   220.000000
# rps_PJM_NC included   generator                    biomass           NC          True            1    43.400000
# rps_PJM_NC included   generator                      waste           NC          True            1     0.419017
# rps_PJM_NC included small_hydro                small_hydro           NC          True            1    95.000000
# rps_PJM_NC included       solar                      solar           NC          True           15  1484.908165
# rps_PJM_NC included        wind                       wind           NC          True           13   208.000000
# rps_PJM_NJ excluded   generator                       coal           NJ         False            1    11.600000
# rps_PJM_NJ excluded   generator natural gas combined cycle           NJ         False            1  7286.200000
# rps_PJM_NJ excluded   generator        natural gas turbine           NJ         False            1  2334.393358
# rps_PJM_NJ excluded   generator                    nuclear           NJ         False            1  3500.200000
# rps_PJM_NJ excluded   generator                        oil           NJ         False            1   153.100000
# rps_PJM_NJ included   generator                      waste           NJ          True            1   252.021644
# rps_PJM_NJ included small_hydro                small_hydro           NJ          True            1    12.300000
# rps_PJM_NJ included       solar                      solar           NJ          True            8  2609.906518
# rps_PJM_NJ included        wind                       wind           NJ          True           19  3507.600000
# rps_PJM_VA excluded   generator                       coal           VA         False            2  1501.700000
# rps_PJM_VA excluded   generator natural gas combined cycle           VA         False            2  8966.400000
# rps_PJM_VA excluded   generator        natural gas turbine           VA         False            4  4227.447443
# rps_PJM_VA excluded   generator                 non-fossil           VA         False            1   123.300000
# rps_PJM_VA excluded   generator                    nuclear           VA         False            1  3568.000000
# rps_PJM_VA excluded   generator                        oil           VA         False            4   827.500000
# rps_PJM_VA excluded   generator                      steam           VA         False            2   541.100000
# rps_PJM_VA excluded large_hydro                large_hydro           VA         False            2   628.800000
# rps_PJM_VA included   generator                    biomass           VA          True            2   237.000000
# rps_PJM_VA included   generator                      waste           VA          True            4   209.877278
# rps_PJM_VA included small_hydro                small_hydro           VA          True            3   236.800000
# rps_PJM_VA included       solar                      solar           VA          True           53 14050.845550
# rps_PJM_VA included        wind                       wind           VA          True           50  1349.000000
# ================================================================================
#
# Parameters Built: 1.2151329517364502
# Variables Built: 0.16904973983764648
# Constraints Built: 1.9931485652923584
# Objective Built: 0.10523700714111328
# Problem Solved: 5.98306679725647
# Solution Graph Built: 2.372788429260254
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.12802791595458984
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 5,575,002 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                26,099.29      14,901.82      41,001.11          198,688.09             34.50       394
# solar                               34,946.77       4,070.94      39,017.71           79,766.00              6.74       220
# battery                                400.00         472.12         872.12          106,267.74              0.96         9
# biomass                                293.40           0.00         293.40                0.00              0.00         6
# coal                                37,892.10           0.00      37,892.10                0.00              0.00        15
# large_hydro                          2,209.50           0.00       2,209.50                0.00              0.00         8
# natural gas combined cycle          60,677.44           0.00      60,677.44                0.00              0.00        19
# natural gas turbine                 27,006.43           0.00      27,006.43                0.00              0.00        23
# non-fossil                             241.50           0.00         241.50                0.00              0.00         9
# nuclear                             31,376.60           0.00      31,376.60                0.00              0.00         9
# oil                                  3,718.22           0.00       3,718.22                0.00              0.00        17
# pump hydro                               0.36           0.00           0.36                0.00              0.00         5
# small_hydro                          1,133.90           0.00       1,133.90                0.00              0.00        19
# steam                                9,323.20           0.00       9,323.20                0.00              0.00        14
# unknown                           -173,867.18           0.00    -173,867.18                0.00              0.00        18
# waste                                1,548.25           0.00       1,548.25                0.00              0.00        25
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                 26,494.42
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $376,006,182.06
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $  34,501,760.65
#   solar                          $   6,735,805.66
#   battery                        $     962,192.39
#   TOTAL                          $  42,199,758.70
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $ 113,407,383.40
#   nuclear                        $ 107,021,791.03
#   coal                           $  52,550,769.26
#   oil                            $   4,613,562.93
#   steam                          $   2,826,631.65
#   waste                          $   1,699,745.63
#   natural gas turbine            $     432,141.69
#   non-fossil                     $     270,102.42
#   biomass                        $      86,860.06
#   large_hydro                    $      30,339.04
#   small_hydro                    $       4,963.91
#   TOTAL                          $ 282,944,291.00
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   PJM_COMD:PJM_West              $  35,709,238.50
#   PJM_EMAC:PJM_SMAC              $   2,792,436.67
#   PJM_PENE:PJM_WMAC              $   2,226,329.82
#   PJM_AP:PJM_SMAC                $   2,206,691.32
#   PJM_AP:PJM_Dom                 $   1,886,000.76
#   PJM_WMAC:PJM_SMAC              $   1,664,978.94
#   PJM_Dom:PJM_SMAC               $   1,509,997.09
#   PJM_PENE:PJM_AP                $   1,408,064.07
#   PJM_Dom:PJM_West               $     293,154.27
#   PJM_West:PJM_Dom               $     284,377.03
#   PJM_AP:PJM_West                $     260,315.99
#   PJM_AP:PJM_ATSI                $     209,094.86
#   PJM_WMAC:PJM_EMAC              $     127,463.48
#   PJM_West:PJM_ATSI              $     109,499.69
#   PJM_West:PJM_COMD              $      38,114.92
#   PJM_EMAC:PJM_WMAC              $      33,940.56
#   PJM_Dom:PJM_AP                 $      20,054.58
#   PJM_West:PJM_AP                $      12,674.96
#   PJM_ATSI:PJM_West              $       6,070.83
#   TOTAL                          $  50,798,498.34
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $ 375,942,548.04
# Model Objective                $ 376,006,182.06
# Other Gap                      $      63,634.01
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# PJM_AP -> PJM_ATSI via line_104: 7.26 MWh
# PJM_AP -> PJM_Dom via line_105: 65.49 MWh
# PJM_AP -> PJM_SMAC via line_107: 57.70 MWh
# PJM_AP -> PJM_West via line_108: 9.04 MWh
# PJM_ATSI -> PJM_West via line_111: 0.21 MWh
# PJM_COMD -> PJM_West via line_116: 160.96 MWh
# PJM_Dom -> PJM_AP via line_117: 0.70 MWh
# PJM_Dom -> PJM_SMAC via line_118: 52.43 MWh
# PJM_Dom -> PJM_West via line_119: 10.18 MWh
# PJM_EMAC -> PJM_SMAC via line_124: 41.68 MWh
# PJM_EMAC -> PJM_WMAC via line_125: 1.18 MWh
# PJM_PENE -> PJM_AP via line_128: 48.89 MWh
# PJM_PENE -> PJM_WMAC via line_129: 77.30 MWh
# PJM_WMAC -> PJM_EMAC via line_134: 4.43 MWh
# PJM_WMAC -> PJM_SMAC via line_136: 42.25 MWh
# PJM_West -> PJM_AP via line_139: 0.44 MWh
# PJM_West -> PJM_ATSI via line_140: 3.80 MWh
# PJM_West -> PJM_COMD via line_141: 1.32 MWh
# PJM_West -> PJM_Dom via line_142: 9.87 MWh
#
# Total transmission across all lines: 595.13 MWh
#
# ====================================================================================================  Scenario   1 ✓
#
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle                5,562.75      60,677.44           0.00      60,677.44        19
# nuclear                                   5,105.80      31,376.60           0.00      31,376.60         9
# coal                                      2,405.53      37,892.10           0.00      37,892.10        15
# waste                                       247.91       1,548.25           0.00       1,548.25        25
# oil                                         216.73       3,718.22           0.00       3,718.22        17
# large_hydro                                 144.92       2,209.50           0.00       2,209.50         8
# steam                                        96.57       9,323.20           0.00       9,323.20        14
# small_hydro                                  76.56       1,133.90           0.00       1,133.90        19
# battery                                      42.09         400.00         472.12         872.12         9
# non-fossil                                   38.94         241.50           0.00         241.50         9
# natural gas turbine                          12.25      27,006.43           0.00      27,006.43        23
# biomass                                       3.37         293.40           0.00         293.40         6
# pump hydro                                    0.07           0.36           0.00           0.36         5
# solar                                    -1,228.96      34,946.77       4,070.94      39,017.71       220
# wind                                     -4,310.13      26,099.29      14,901.82      41,001.11       394
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      26,494.42
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 220
# Wind assets found : 394
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_PJM_AP:
#   Installed Capacity: 1,227.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_ATSI:
#   Installed Capacity: 1,666.47 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_COMD:
#   Installed Capacity: 2,126.40 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_Dom:
#   Installed Capacity: 2,777.43 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_EMAC:
#   Installed Capacity: 5,332.11 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_PENE:
#   Installed Capacity: 534.91 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_SMAC:
#   Installed Capacity: 2,688.53 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_WMAC:
#   Installed Capacity: 1,080.43 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_PJM_West:
#   Installed Capacity: 2,906.85 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_s01_slow_m0_d7/s01_s01_cost_components.csv
# Capex detail CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_s01_slow_m0_d7/s01_s01_capex_detail.csv
# Capex summary CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_s01_slow_m0_d7/s01_s01_capex_summary.csv
# EV summary CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_s01_slow_m0_d7/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7
# Solution JSON: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7_solution.json
# Solution CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7_solution.csv
# Summary CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7_summary.csv
# Total cost CSV: Output/PJM/scenario_results_2030_slow_PJM_midnight/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7/s01_Base_only_rps-10_v1g0_v2g0_bcapex315_slow_m0_d7_total_cost.csv
# Objective = 376,006,182.06
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.28, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.2, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.125, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_OH: ratio=0.085, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_PA: ratio=0.08, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.31, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_PJM_DE excluded   generator                       coal           DE         False            1   410.000000
# rps_PJM_DE excluded   generator natural gas combined cycle           DE         False            1  1511.000000
# rps_PJM_DE excluded   generator        natural gas turbine           DE         False            1   348.174346
# rps_PJM_DE excluded   generator                        oil           DE         False            1   114.100000
# rps_PJM_DE excluded   generator                      steam           DE         False            1   710.000000
# rps_PJM_DE included   generator                      waste           DE          True            1   151.896811
# rps_PJM_DE included       solar                      solar           DE          True            8   493.856581
# rps_PJM_DE included        wind                       wind           DE          True           13     2.000000
# rps_PJM_IL excluded   generator                       coal           IL         False            1  1578.400000
# rps_PJM_IL excluded   generator natural gas combined cycle           IL         False            1  4858.900000
# rps_PJM_IL excluded   generator        natural gas turbine           IL         False            1  7232.200000
# rps_PJM_IL excluded   generator                 non-fossil           IL         False            1     3.000000
# rps_PJM_IL excluded   generator                    nuclear           IL         False            1 10517.400000
# rps_PJM_IL excluded   generator                        oil           IL         False            1   351.100000
# rps_PJM_IL excluded   generator                      steam           IL         False            1  1378.000000
# rps_PJM_IL included   generator                      waste           IL          True            1    77.082203
# rps_PJM_IL included small_hydro                small_hydro           IL          True            1    29.700000
# rps_PJM_IL included       solar                      solar           IL          True            8  1237.873000
# rps_PJM_IL included        wind                       wind           IL          True           19  4583.900000
# rps_PJM_MD excluded   generator                       coal           MD         False            2  1758.000000
# rps_PJM_MD excluded   generator natural gas combined cycle           MD         False            2  2849.100000
# rps_PJM_MD excluded   generator        natural gas turbine           MD         False            2  1966.828626
# rps_PJM_MD excluded   generator                 non-fossil           MD         False            1     1.800000
# rps_PJM_MD excluded   generator                    nuclear           MD         False            1  1725.800000
# rps_PJM_MD excluded   generator                        oil           MD         False            2   364.400002
# rps_PJM_MD excluded   generator                      steam           MD         False            2  1922.000000
# rps_PJM_MD excluded large_hydro                large_hydro           MD         False            1   572.000000
# rps_PJM_MD included   generator                      waste           MD          True            3   159.673876
# rps_PJM_MD included small_hydro                small_hydro           MD          True            1    18.000000
# rps_PJM_MD included       solar                      solar           MD          True           24  5670.461318
# rps_PJM_MD included        wind                       wind           MD          True           50  1967.391403
# rps_PJM_MI excluded   generator natural gas combined cycle           MI         False            1  1084.000000
# rps_PJM_MI excluded   generator        natural gas turbine           MI         False            1     6.000000
# rps_PJM_MI excluded   generator                    nuclear           MI         False            1  2177.000000
# rps_PJM_MI included   generator                      waste           MI          True            1     9.231113
# rps_PJM_MI included small_hydro                small_hydro           MI          True            1     9.800000
# rps_PJM_MI included       solar                      solar           MI          True            8    54.615856
# rps_PJM_MI included        wind                       wind           MI          True           12     0.000000
# rps_PJM_NC excluded   generator natural gas combined cycle           NC         False            1   165.000000
# rps_PJM_NC excluded   generator                 non-fossil           NC         False            1    71.000000
# rps_PJM_NC excluded   generator                        oil           NC         False            1    17.400000
# rps_PJM_NC excluded large_hydro                large_hydro           NC         False            1   220.000000
# rps_PJM_NC included   generator                    biomass           NC          True            1    43.400000
# rps_PJM_NC included   generator                      waste           NC          True            1     0.419017
# rps_PJM_NC included small_hydro                small_hydro           NC          True            1    95.000000
# rps_PJM_NC included       solar                      solar           NC          True           15  1484.908165
# rps_PJM_NC included        wind                       wind           NC          True           13   208.000000
# rps_PJM_NJ excluded   generator                       coal           NJ         False            1    11.600000
# rps_PJM_NJ excluded   generator natural gas combined cycle           NJ         False            1  7286.200000
# rps_PJM_NJ excluded   generator        natural gas turbine           NJ         False            1  2334.393358
# rps_PJM_NJ excluded   generator                    nuclear           NJ         False            1  3500.200000
# rps_PJM_NJ excluded   generator                        oil           NJ         False            1   153.100000
# rps_PJM_NJ included   generator                      waste           NJ          True            1   252.021644
# rps_PJM_NJ included small_hydro                small_hydro           NJ          True            1    12.300000
# rps_PJM_NJ included       solar                      solar           NJ          True            8  2609.906518
# rps_PJM_NJ included        wind                       wind           NJ          True           19  3507.600000
# rps_PJM_OH excluded   generator                       coal           OH         False            2  7223.200000
# rps_PJM_OH excluded   generator natural gas combined cycle           OH         False            2 11794.116467
# rps_PJM_OH excluded   generator        natural gas turbine           OH         False            2  5242.328118
# rps_PJM_OH excluded   generator                 non-fossil           OH         False            2     6.400000
# rps_PJM_OH excluded   generator                    nuclear           OH         False            1   894.000000
# rps_PJM_OH excluded   generator                        oil           OH         False            2   895.121872
# rps_PJM_OH excluded   generator                      steam           OH         False            2    16.000000
# rps_PJM_OH included   generator                    biomass           OH          True            1     7.200000
# rps_PJM_OH included   generator                      waste           OH          True            2   216.247945
# rps_PJM_OH included small_hydro                small_hydro           OH          True            2   101.900000
# rps_PJM_OH included       solar                      solar           OH          True           16  3929.465319
# rps_PJM_OH included        wind                       wind           OH          True           38  1102.300000
# rps_PJM_PA excluded   generator                       coal           PA         False            2  6853.000000
# rps_PJM_PA excluded   generator natural gas combined cycle           PA         False            6 19257.363303
# rps_PJM_PA excluded   generator        natural gas turbine           PA         False            6  2172.756225
# rps_PJM_PA excluded   generator                 non-fossil           PA         False            2    24.000000
# rps_PJM_PA excluded   generator                    nuclear           PA         False            3  8994.200000
# rps_PJM_PA excluded   generator                        oil           PA         False            4   984.500000
# rps_PJM_PA excluded   generator                      steam           PA         False            4  4473.400000
# rps_PJM_PA excluded large_hydro                large_hydro           PA         False            2   542.700000
# rps_PJM_PA included   generator                    biomass           PA          True            1     2.500000
# rps_PJM_PA included   generator                      waste           PA          True            5   415.376248
# rps_PJM_PA included small_hydro                small_hydro           PA          True            5   356.900000
# rps_PJM_PA included       solar                      solar           PA          True           40  3721.212903
# rps_PJM_PA included        wind                       wind           PA          True          112 10618.699851
# rps_PJM_VA excluded   generator                       coal           VA         False            2  1501.700000
# rps_PJM_VA excluded   generator natural gas combined cycle           VA         False            2  8966.400000
# rps_PJM_VA excluded   generator        natural gas turbine           VA         False            4  4227.447443
# rps_PJM_VA excluded   generator                 non-fossil           VA         False            1   123.300000
# rps_PJM_VA excluded   generator                    nuclear           VA         False            1  3568.000000
# rps_PJM_VA excluded   generator                        oil           VA         False            4   827.500000
# rps_PJM_VA excluded   generator                      steam           VA         False            2   541.100000
# rps_PJM_VA excluded large_hydro                large_hydro           VA         False            2   628.800000
# rps_PJM_VA included   generator                    biomass           VA          True            2   237.000000
# rps_PJM_VA included   generator                      waste           VA          True            4   209.877278
# rps_PJM_VA included small_hydro                small_hydro           VA          True            3   236.800000
# rps_PJM_VA included       solar                      solar           VA          True           53 14050.845550
# rps_PJM_VA included        wind                       wind           VA          True           50  1349.000000
# ================================================================================
#
# Parameters Built: 1.0892937183380127
# Variables Built: 0.1673433780670166
# Constraints Built: 2.3860976696014404
# Objective Built: 0.10177898406982422
# Problem Solved: 6.1207475662231445
# Solution Graph Built: 2.328000068664551
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.13316679000854492
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 5,229,886 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                26,099.29      19,533.56      45,632.85          198,688.09             45.58       394
# solar                               34,946.77       8,856.85      43,803.62           79,766.00             14.73       220
# battery                                400.00         785.50       1,185.50          106,267.74              1.60         9
# biomass                                293.40           0.00         293.40                0.00              0.00         6
# coal                                37,892.10           0.00      37,892.10                0.00              0.00        15
# large_hydro                          2,209.50           0.00       2,209.50                0.00              0.00         8
# natural gas combined cycle          60,677.44           0.00      60,677.44                0.00              0.00        19
# natural gas turbine                 27,006.43           0.00      27,006.43                0.00              0.00        23
# non-fossil                             241.50           0.00         241.50                0.00              0.00         9
# nuclear                             31,376.60           0.00      31,376.60                0.00              0.00         9
# oil                                  3,718.22           0.00       3,718.22                0.00              0.00        17
# pump hydro                               0.36           0.00           0.36                0.00              0.00         5
# small_hydro                          1,133.90           0.00       1,133.90                0.00              0.00        19
# steam                                9,323.20           0.00       9,323.20                0.00              0.00        14
# unknown                           -173,867.18           0.00    -173,867.18                0.00              0.00        18
# waste                                1,548.25           0.00       1,548.25                0.00              0.00        25
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                 14,480.28
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $415,411,098.44
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $  45,581,185.70
#   solar                          $  14,734,223.78
#   battery                        $   1,600,852.38
#   TOTAL                          $  61,916,261.86
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   nuclear                        $ 106,513,644.88
#   natural gas combined cycle     $ 105,160,961.88
#   coal                           $  47,031,654.73
#   oil                            $   4,763,270.68
#   steam                          $   3,592,826.79
#   waste                          $   1,680,669.68
#   natural gas turbine            $     579,691.10
#   non-fossil                     $     254,911.19
#   biomass                        $      93,279.31
#   large_hydro                    $      22,706.81
#   small_hydro                    $       4,833.00
#   TOTAL                          $ 269,698,450.05
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   PJM_COMD:PJM_West              $  63,674,405.31
#   PJM_AP:PJM_SMAC                $   5,967,007.80
#   PJM_WMAC:PJM_SMAC              $   3,017,863.74
#   PJM_PENE:PJM_WMAC              $   2,324,414.14
#   PJM_WMAC:PJM_EMAC              $   1,883,117.88
#   PJM_PENE:PJM_AP                $   1,368,560.67
#   PJM_AP:PJM_Dom                 $   1,298,312.65
#   PJM_Dom:PJM_SMAC               $   1,246,050.01
#   PJM_West:PJM_Dom               $     736,236.57
#   PJM_West:PJM_ATSI              $     475,547.28
#   PJM_AP:PJM_West                $     398,544.40
#   PJM_Dom:PJM_West               $     352,316.83
#   PJM_EMAC:PJM_SMAC              $     344,692.51
#   PJM_AP:PJM_ATSI                $     295,149.56
#   PJM_EMAC:PJM_WMAC              $     143,861.88
#   PJM_West:PJM_AP                $     121,678.91
#   PJM_Dom:PJM_AP                 $      22,285.18
#   PJM_West:PJM_COMD              $      21,324.28
#   PJM_SMAC:PJM_WMAC              $       7,676.96
#   PJM_AP:PJM_PENE                $       4,244.11
#   PJM_ATSI:PJM_West              $       3,269.57
#   PJM_SMAC:PJM_EMAC              $       2,400.00
#   PJM_SMAC:PJM_Dom               $         945.23
#   TOTAL                          $  83,709,905.47
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $ 415,324,617.39
# Model Objective                $ 415,411,098.44
# Other Gap                      $      86,481.05
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# PJM_AP -> PJM_ATSI via line_104: 10.25 MWh
# PJM_AP -> PJM_Dom via line_105: 45.08 MWh
# PJM_AP -> PJM_PENE via line_106: 0.15 MWh
# PJM_AP -> PJM_SMAC via line_107: 86.87 MWh
# PJM_AP -> PJM_West via line_108: 13.84 MWh
# PJM_ATSI -> PJM_West via line_111: 0.11 MWh
# PJM_COMD -> PJM_West via line_116: 283.52 MWh
# PJM_Dom -> PJM_AP via line_117: 0.77 MWh
# PJM_Dom -> PJM_SMAC via line_118: 43.27 MWh
# PJM_Dom -> PJM_West via line_119: 12.23 MWh
# PJM_EMAC -> PJM_SMAC via line_124: 11.97 MWh
# PJM_EMAC -> PJM_WMAC via line_125: 5.00 MWh
# PJM_PENE -> PJM_AP via line_128: 47.52 MWh
# PJM_PENE -> PJM_WMAC via line_129: 80.71 MWh
# PJM_SMAC -> PJM_Dom via line_131: 0.03 MWh
# PJM_SMAC -> PJM_EMAC via line_132: 0.08 MWh
# PJM_SMAC -> PJM_WMAC via line_133: 0.27 MWh  Scenario   2 ✓
#
# PJM_WMAC -> PJM_EMAC via line_134: 65.39 MWh
# PJM_WMAC -> PJM_SMAC via line_136: 51.60 MWh
# PJM_West -> PJM_AP via line_139: 4.22 MWh
# PJM_West -> PJM_ATSI via line_140: 16.51 MWh
# PJM_West -> PJM_COMD via line_141: 0.74 MWh
# PJM_West -> PJM_Dom via line_142: 25.56 MWh
#
# Total transmission across all lines: 805.69 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# ...
#   rps_PJM_PA: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.41, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
# Added detail-equivalent aggregate V2G store to PJM_AP: max_power=1857.98 MW, max_energy=1857.98 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_ATSI: max_power=1971.06 MW, max_energy=1971.06 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_COMD: max_power=2444.09 MW, max_energy=2444.09 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_Dom: max_power=4267.80 MW, max_energy=4267.80 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_EMAC: max_power=8193.32 MW, max_energy=8193.32 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_PENE: max_power=821.95 MW, max_energy=821.95 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_SMAC: max_power=4131.19 MW, max_energy=4131.19 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_WMAC: max_power=1660.19 MW, max_energy=1660.19 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_West: max_power=3521.94 MW, max_energy=3521.94 MWh, window_hours=24
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.1, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.025, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.21, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.28, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.2, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.125, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_OH: ratio=0.085, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_PA: ratio=0.08, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.31, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.38, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.6, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']  Scenario  12 ✗ Error: could not convert string to float: 'PJM_AP:wind:7'
#   Scenario  13 ✗ Error: could not convert string to float: 'PJM_AP:wind:7'
#   Scenario  14 ✗ Error: could not convert string to float: 'PJM_AP:wind:7'
#
#   rps_PJM_NJ: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.225, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_OH: ratio=0.185, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_PA: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.41, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.1, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.025, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.21, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
# Added detail-equivalent aggregate V2G store to PJM_AP: max_power=3715.95 MW, max_energy=3715.95 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_ATSI: max_power=3942.13 MW, max_energy=3942.13 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_COMD: max_power=4888.18 MW, max_energy=4888.18 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_Dom: max_power=8535.60 MW, max_energy=8535.60 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_EMAC: max_power=16386.64 MW, max_energy=16386.64 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_PENE: max_power=1643.90 MW, max_energy=1643.90 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_SMAC: max_power=8262.38 MW, max_energy=8262.38 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_WMAC: max_power=3320.37 MW, max_energy=3320.37 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_West: max_power=7043.87 MW, max_energy=7043.87 MWh, window_hours=24
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.28, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.2, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.4, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.125, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_OH: ratio=0.085, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_PA: ratio=0.08, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.31, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#
# EV profile market key: PJM
# Added detail-equivalent aggregate V2G store to PJM_AP: max_power=3715.95 MW, max_energy=3715.95 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_ATSI: max_power=3942.13 MW, max_energy=3942.13 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_COMD: max_power=4888.18 MW, max_energy=4888.18 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_Dom: max_power=8535.60 MW, max_energy=8535.60 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_EMAC: max_power=16386.64 MW, max_energy=16386.64 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_PENE: max_power=1643.90 MW, max_energy=1643.90 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_SMAC: max_power=8262.38 MW, max_energy=8262.38 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_WMAC: max_power=3320.37 MW, max_energy=3320.37 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_West: max_power=7043.87 MW, max_energy=7043.87 MWh, window_hours=24
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
# EV state: PJM
# Model region: PJM
# STATE_TO_REGIONS key used: PJM
# GOOD regions used: ['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_PJM_DE: ratio=0.38, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_IL: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MD: ratio=0.6, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_MI: ratio=0.3, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NJ: ratio=0.5, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_NC: ratio=0.225, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_OH: ratio=0.185, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_PA: ratio=0.18, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
#   rps_PJM_VA: ratio=0.41, regions=['PJM_AP', 'PJM_ATSI', 'PJM_COMD', 'PJM_Dom', 'PJM_EMAC', 'PJM_PENE', 'PJM_SMAC', 'PJM_WMAC', 'PJM_West']
# Total battery assets removed: 12
# ================================================================================
#   Scenario  15 ✗ Error: could not convert string to float: 'PJM_AP:wind:7'
#
# EV profile market key: PJM
# Added detail-equivalent aggregate V2G store to PJM_AP: max_power=3715.95 MW, max_energy=3715.95 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_ATSI: max_power=3942.13 MW, max_energy=3942.13 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_COMD: max_power=4888.18 MW, max_energy=4888.18 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_Dom: max_power=8535.60 MW, max_energy=8535.60 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_EMAC: max_power=16386.64 MW, max_energy=16386.64 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_PENE: max_power=1643.90 MW, max_energy=1643.90 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_SMAC: max_power=8262.38 MW, max_energy=8262.38 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_WMAC: max_power=3320.37 MW, max_energy=3320.37 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to PJM_West: max_power=7043.87 MW, max_energy=7043.87 MWh, window_hours=24
#
# Processed 574 renewable plants with capex
# Skipped 40 renewable plants (no valid capex_cost)
# ================================================================================
#
#
#   Summary:
#     Successful: 3/15
#     Failed: 12/15
#     Saved to: Output/PJM/scenario_results_2030_slow_PJM_midnight/all_scenarios_summary.csv
#     ⚠ Failed scenarios logged to: Output/PJM/scenario_results_2030_slow_PJM_midnight/failed_scenarios.csv
