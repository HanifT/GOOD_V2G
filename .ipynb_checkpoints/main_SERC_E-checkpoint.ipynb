# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 10
IPM_REGION = "MAPP"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

MAPP_REGIONS = [
    "MIS_MAPP",
]

STATE_TO_REGIONS = {
    "MAPP": MAPP_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EIA-860M operating battery capacity, June 2026
#
# MIS_MAPP      0.0 MW operating
#
# Batteries reported as under construction:
#
# Northern Divide Energy Storage    100 MW
# Emmons-Logan Energy Storage       140 MW
#
# Total under construction          240 MW
#
# Because MAPP contains only one GOOD region, all battery
# capacity assigned to MAPP must be placed in MIS_MAPP.
# Therefore, the distribution weight is 1.0 even though
# the current operating battery capacity is zero.
#
# Pumped storage is excluded.

BATTERY_WEIGHTS = {
    "MIS_MAPP": 1.0000,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# EPA NEEDS active capacity in MIS_MAPP:
#
# Coal steam               1,657.0 MW
# Combustion turbines        418.6 MW
# O/G steam                    0.0 MW
# Combined cycle               0.0 MW
# Nuclear                      0.0 MW
#
# EPA NEEDS does not identify any active MAPP units with
# explicit retirement years of 2029 or 2030.
#
# The June 2026 EIA-860M inventory also does not report
# planned 2029–2030 retirements in the MIS_MAPP boundary.

RETIREMENT_POLICIES = {
    "MAPP": {
        # No explicit 2029–2030 retirement
        # from 1,657 MW of active coal capacity.
        "coal": 0.00,

        # No active O/G steam capacity.
        "oil": 0.00,

        # No explicit 2029–2030 retirement
        # from 418.6 MW of combustion-turbine capacity.
        "natural gas turbine": 0.00,

        # No active combined-cycle capacity.
        "natural gas combined cycle": 0.00,

        # No active nuclear capacity.
        "nuclear": 0.00,
    }
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "MAPP": {
        # MAPP 2030 central logic:
        #
        # The existing MAPP fleet is dominated by wind and coal.
        # EPA NEEDS reports approximately 4,722.7 MW of wind
        # and 1,657 MW of coal.
        #
        # Most coal capacity is lignite-fired. These units generally
        # operate as relatively stable baseload resources. However,
        # a high minimum-output floor would interfere with the large
        # amount of wind generation in the region.
        #
        # A 20% aggregated coal floor represents continued operation
        # of part of the coal fleet without forcing every coal unit
        # to remain online.
        #
        # Combustion turbines provide peaking and reliability support
        # and therefore do not receive a must-run requirement.

        "coal": {
            "must_run_fraction": 0.20,
            "ramp_rate": 0.05,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 240,
        },
    },
    "MAPP": {
        "battery": {
            "total_power_mw": 240,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "MAPP": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "MAPP": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 3 (slow, mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 12
# # Total runs: 180 (= 15 scenarios × 12 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/MAPP/scenario_results_2030_slow_MAPP_midnight
# ================================================================================
#
# EV state: MAPP
# Model region: MAPP
# STATE_TO_REGIONS key used: MAPP
# GOOD regions used: ['MIS_MAPP']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 0
# ================================================================================
#
# EV profile market key: MAPP
#
# Processed 81 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 64
# Exact duplicate groups: 2
# Assets contained in duplicate groups: 5
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# MIS_MAPP     | MT  | solar  | assets=  3 | profile=MIS_MAPP:solar:2
# MIS_MAPP     | ND  | solar  | assets=  2 | profile=MIS_MAPP:solar:2
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.08583927154541
# Variables Built: 0.7367522716522217
# Constraints Built: 6.782207727432251
# Objective Built: 0.2964329719543457
# EV state: MAPP
# Model region: MAPP
# STATE_TO_REGIONS key used: MAPP
# GOOD regions used: ['MIS_MAPP']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 0
# ================================================================================
#
# EV profile market key: MAPP
#
# Processed 81 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 64
# Exact duplicate groups: 2
# Assets contained in duplicate groups: 5
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# MIS_MAPP     | MT  | solar  | assets=  3 | profile=MIS_MAPP:solar:2
# MIS_MAPP     | ND  | solar  | assets=  2 | profile=MIS_MAPP:solar:2
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.0852816104888916
# Variables Built: 0.7536220550537109
# Constraints Built: 6.800567388534546
# Objective Built: 0.303847074508667
# EV state: MAPP
# Model region: MAPP
# STATE_TO_REGIONS key used: MAPP
# GOOD regions used: ['MIS_MAPP']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 0
# ================================================================================
#
# EV profile market key: MAPP
#
# Processed 81 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 64
# Exact duplicate groups: 2
# Assets contained in duplicate groups: 5
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# MIS_MAPP     | MT  | solar  | assets=  3 | profile=MIS_MAPP:solar:2
# MIS_MAPP     | ND  | solar  | assets=  2 | profile=MIS_MAPP:solar:2
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.0943984985351562
# Variables Built: 0.7677717208862305
# Constraints Built: 6.842481374740601
# Objective Built: 0.3018016815185547
# EV state: MAPP
# Model region: MAPP
# STATE_TO_REGIONS key used: MAPP
# GOOD regions used: ['MIS_MAPP']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 0
# ================================================================================
#
# EV profile market key: MAPP
#
# Processed 81 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 64
# Exact duplicate groups: 2
# Assets contained in duplicate groups: 5
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# MIS_MAPP     | MT  | solar  | assets=  3 | profile=MIS_MAPP:solar:2
# MIS_MAPP     | ND  | solar  | assets=  2 | profile=MIS_MAPP:solar:2
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.1093904972076416
# Variables Built: 0.7897944450378418
# Constraints Built: 7.240326881408691
# Objective Built: 0.7540926933288574
# EV state: MAPP
# Model region: MAPP
# STATE_TO_REGIONS key used: MAPP
# GOOD regions used: ['MIS_MAPP']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 0
# ================================================================================
#
# EV profile market key: MAPP
#
# Processed 81 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 64
# Exact duplicate groups: 2
# Assets contained in duplicate groups: 5
# Assets potentially removable: 3
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# MIS_MAPP     | MT  | solar  | assets=  3 | profile=MIS_MAPP:solar:2
# MIS_MAPP     | ND  | solar  | assets=  2 | profile=MIS_MAPP:solar:2
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.1319286823272705
# Variables Built: 0.7886912822723389
# Constraints Built: 7.16121244430542
# Objective Built: 0.7741777896881104
# Problem Solved: 10.55544400215149
# Solution Graph Built: 1.4350416660308838
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.4388244152069092
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 16,801 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                240.00           0.00         240.00          106,267.74              0.00         1
# coal                                 1,679.00           0.00       1,679.00                0.00              0.00         2
# natural gas turbine                    289.10           0.00         289.10                0.00              0.00         3
# non-fossil                               5.30           0.00           5.30                0.00              0.00         1
# oil                                     82.90           0.00          82.90                0.00              0.00         3
# small_hydro                              0.80           0.00           0.80                0.00              0.00         1
# solar                                1,732.06           0.00       1,732.06           81,956.32              0.00        23
# unknown                             -1,535.80           0.00      -1,535.80                0.00              0.00         2
# waste                                    0.16           0.00           0.16                0.00              0.00         3
# wind                                 3,747.00           0.00       3,747.00          101,256.28              0.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             11,679,688.20
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $75,869,918.20
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $  73,329,575.72
#   oil                            $     877,614.54
#   natural gas turbine            $     717,402.49
#   non-fossil                     $      51,990.96
#   waste                          $       1,590.17
#   small_hydro                    $           4.00
#   TOTAL                          $  74,978,177.90
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $  74,978,177.90
# Model Objective                $  75,869,918.20
# Other Gap                      $     891,740.30
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                      3,392.39       1,679.00           0.00       1,679.00         2
# battery                                     187.62         240.00           0.00         240.00         1
# oil                                          25.91          82.90           0.00          82.90         3
# natural gas turbine                          16.80         289.10           0.00         289.10         3
# non-fossil                                    7.49           5.30           0.00           5.30         1
# small_hydro                                   0.55           0.80           0.00           0.80         1
# waste                                         0.23           0.16           0.00           0.16         3
# solar                                    -3,998.85       1,732.06           0.00       1,732.06        23
# wind                                    -13,080.42       3,747.00           0.00       3,747.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  11,679,688.20
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.Problem Solved: 11.860694885253906
# Solution Graph Built: 1.5297009944915771
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.45090818405151367
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 16,023 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                240.00           0.00         240.00          106,267.74              0.00         1
# coal                                 1,679.00           0.00       1,679.00                0.00              0.00         2
# natural gas turbine                    289.10           0.00         289.10                0.00              0.00         3
# non-fossil                               5.30           0.00           5.30                0.00              0.00         1
# oil                                     82.90           0.00          82.90                0.00              0.00         3
# small_hydro                              0.80           0.00           0.80                0.00              0.00         1
# solar                                1,732.06           0.00       1,732.06           81,956.32              0.00        23
# unknown                             -1,535.80           0.00      -1,535.80                0.00              0.00         3
# waste                                    0.16           0.00           0.16                0.00              0.00         3
# wind                                 3,747.00           0.00       3,747.00          101,256.28              0.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             11,673,963.90
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
# Total Objective: $75,730,491.28
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $  73,214,353.31
#   oil                            $     886,759.56
#   natural gas turbine            $     684,069.56
#   non-fossil                     $      51,983.95
#   waste                          $       1,592.43
#   small_hydro                    $           3.88
#   TOTAL                          $  74,838,762.70
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $  74,838,762.70
# Model Objective                $  75,730,491.28
# Other Gap                      $     891,728.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                      3,387.12       1,679.00           0.00       1,679.00         2
# battery                                     187.08         240.00           0.00         240.00         1
# oil                                          26.17          82.90           0.00          82.90         3
# natural gas turbine                          16.02         289.10           0.00         289.10         3
# non-fossil                                    7.49           5.30           0.00           5.30         1
# small_hydro                                   0.53           0.80           0.00           0.80         1
# waste                                         0.23           0.16           0.00           0.16         3
# solar                                    -3,998.85       1,732.06           0.00       1,732.06        23
# wind                                    -13,080.42       3,747.00           0.00       3,747.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  11,673,963.90
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.Problem Solved: 12.047691345214844
# Solution Graph Built: 1.563636302947998
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.4261162281036377
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 4 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 16,023 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                240.00           0.00         240.00          106,267.74              0.00         1
# coal                                 1,679.00           0.00       1,679.00                0.00              0.00         2
# natural gas turbine                    289.10           0.00         289.10                0.00              0.00         3
# non-fossil                               5.30           0.00           5.30                0.00              0.00         1
# oil                                     82.90           0.00          82.90                0.00              0.00         3
# small_hydro                              0.80           0.00           0.80                0.00              0.00         1
# solar                                1,732.06           0.00       1,732.06           81,956.32              0.00        23
# unknown                             -1,535.80           0.00      -1,535.80                0.00              0.00         3
# waste                                    0.16           0.00           0.16                0.00              0.00         3
# wind                                 3,747.00           0.00       3,747.00          101,256.28              0.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             11,673,963.90
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 4
# ====================================================================================================
#
# Total Objective: $75,730,491.28
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $  73,214,353.31
#   oil                            $     886,759.56
#   natural gas turbine            $     684,069.56
#   non-fossil                     $      51,983.95
#   waste                          $       1,592.43
#   small_hydro                    $           3.88
#   TOTAL                          $  74,838,762.70
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $  74,838,762.70
# Model Objective                $  75,730,491.28
# Other Gap                      $     891,728.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                      3,387.12       1,679.00           0.00       1,679.00         2
# battery                                     187.08         240.00           0.00         240.00         1
# oil                                          26.17          82.90           0.00          82.90         3
# natural gas turbine                          16.02         289.10           0.00         289.10         3
# non-fossil                                    7.49           5.30           0.00           5.30         1
# small_hydro                                   0.53           0.80           0.00           0.80         1
# waste                                         0.23           0.16           0.00           0.16         3
# solar                                    -3,998.85       1,732.06           0.00       1,732.06        23
# wind                                    -13,080.42       3,747.00           0.00       3,747.00        64
# ...
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                      3,344.36       1,679.00           0.00       1,679.00         2
# battery                                     186.60         240.00           0.00         240.00         1
# ev_v2g                                       57.85          85.80           0.00          85.80         1
# oil                                          14.41          82.90           0.00          82.90         3
# non-fossil                                    7.73           5.30           0.00           5.30         1
# natural gas turbine                           4.83         289.10           0.00         289.10         3
# small_hydro                                   0.56           0.80           0.00           0.80         1
# waste                                         0.24           0.16           0.00           0.16         3
# solar                                    -3,998.85       1,732.06           0.00       1,732.06        23
# wind                                    -13,080.42       3,747.00           0.00       3,747.00        64
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  11,515,051.65
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================  Scenario  13 ✓
#   Scenario  14 ✓
#   Scenario  15 ✓
#
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 23
# Wind assets found : 64
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 22.07 MW
#   Max Shift Down: -11.03 MW
#   Total Shifting: 37,680.89 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_s12_fast_m0_d360/s12_s12_cost_components.csv
# Capex detail CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_s12_fast_m0_d360/s12_s12_capex_detail.csv
# Capex summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_s12_fast_m0_d360/s12_s12_capex_summary.csv
# EV summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_s12_fast_m0_d360/s12_s12_ev_summary.csv
# Finished scenario 12: s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360/s12_V1G_rps10_v1g50_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 75,840,041.44
#
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 23
# Wind assets found : 64
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_s13_fast_m0_d360/s13_s13_cost_components.csv
# Capex detail CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_s13_fast_m0_d360/s13_s13_capex_detail.csv
# Capex summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_s13_fast_m0_d360/s13_s13_capex_summary.csv
# EV summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_s13_fast_m0_d360/s13_s13_ev_summary.csv
# Finished scenario 13: s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 74,466,192.17
#
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 23
# Wind assets found : 64
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_s14_fast_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_s14_fast_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_s14_fast_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_s14_fast_m0_d360/s14_s14_ev_summary.csv
# Finished scenario 14: s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 74,466,192.17
#
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 23
# Wind assets found : 64
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 22.07 MW
#   Max Shift Down: -11.03 MW
#   Total Shifting: 37,680.89 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_s11_fast_m0_d360/s11_s11_cost_components.csv
# Capex detail CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_s11_fast_m0_d360/s11_s11_capex_detail.csv
# Capex summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_s11_fast_m0_d360/s11_s11_capex_summary.csv
# EV summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_s11_fast_m0_d360/s11_s11_ev_summary.csv
# Finished scenario 11: s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360
# Solution JSON: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360/s11_V1G_rps0_v1g50_v2g0_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 75,840,041.44
#
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 23
# Wind assets found : 64
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_MIS_MAPP:
#   Installed Capacity: 22.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_s15_fast_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_s15_fast_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_s15_fast_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_s15_fast_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 15: s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/MAPP/scenario_results_2030_fast_MAPP_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 74,466,192.17
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/MAPP/scenario_results_2030_fast_MAPP_flex/all_scenarios_summary.csv
