# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 10
IPM_REGION = "RMRG"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

RMRG_REGIONS = [
    "WECC_CO",
    "WECC_WY",
]

STATE_TO_REGIONS = {
    "RMRG": RMRG_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EPA NEEDS active battery capacity
#
# WECC_CO     9.2 MW
# WECC_WY     0.0 MW
#
# Total       9.2 MW
#
# WECC_CO includes:
# Panasonic Carport Solar Hybrid          1.0 MW
# I25 Battery Storage                     4.0 MW
# Fort Carson Battery Energy Storage      4.2 MW
#
# Pumped storage is excluded because these weights are
# specifically for battery storage.

BATTERY_WEIGHTS = {
    "WECC_CO": 1.0000,
    "WECC_WY": 0.0000,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# Fractions are calculated from explicit 2029–2030
# retirement years in the EPA NEEDS active-resource sheet.
#
# Units already placed in the NEEDS "retire by 2028" sheet
# are not part of the active fleet and are therefore not
# retired again here.

RETIREMENT_POLICIES = {
    "RMRG": {
        # 2,053 MW scheduled retirement
        # from 8,526 MW of active coal capacity.
        #
        # WECC_CO: 1,525 MW
        # WECC_WY:   528 MW
        "coal": 0.2408,

        # No explicit 2029–2030 retirement
        # from 95 MW of active O/G steam capacity.
        "oil": 0.00,

        # No explicit 2029–2030 retirement
        # from 3,028.4 MW of combustion-turbine capacity.
        "natural gas turbine": 0.00,

        # No explicit 2029–2030 retirement
        # from 3,270.6 MW of combined-cycle capacity.
        "natural gas combined cycle": 0.00,

        # No active nuclear capacity exists in these regions.
        "nuclear": 0.00,
    }
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "RMRG": {
        # RMRG 2030 central logic:
        #
        # RMRG includes the EPA IPM Colorado and Wyoming regions.
        # The region has substantial coal and wind capacity but
        # does not have active nuclear capacity in EPA NEEDS.
        #
        # Coal retains a limited minimum-output floor. The floor
        # remains low enough to accommodate wind generation and
        # scheduled coal retirements.
        #
        # Combined-cycle gas provides reliability and flexibility.
        #
        # Combustion turbines are treated as peaking resources.
        #
        # O/G steam is mostly gas-fired steam capacity in this
        # dataset. Its 10% floor represents a small online component.
        # The 8% hourly ramp limit is a planning-model approximation
        # that reduces unrealistic hourly shutdown and restart.

        "coal": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 670,
        },
    },
    "MISO": {
        "battery": {
            "total_power_mw": 670,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "MISO": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "MISO": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 3 (slow, mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 12
# # Total runs: 180 (= 15 scenarios × 12 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/RMRG/scenario_results_2030_slow_RMRG_midnight
# ================================================================================
#
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.138804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.238804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.338804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.138804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.238804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# Parameters Built: 2.7059082984924316
# Parameters Built: 2.6754536628723145
# Parameters Built: 2.7081148624420166
# Parameters Built: 2.7792155742645264
# Parameters Built: 2.7898519039154053
# Variables Built: 1.4494757652282715
# Variables Built: 1.4908387660980225
# Variables Built: 1.4911317825317383
# Variables Built: 1.647047758102417
# Variables Built: 1.639955759048462
# Constraints Built: 12.129936218261719
# Constraints Built: 12.207598209381104
# Constraints Built: 12.397352695465088
# Objective Built: 1.4230055809020996
# Constraints Built: 13.257337093353271
# Constraints Built: 13.2489492893219
# Objective Built: 1.4301044940948486
# Objective Built: 1.4389560222625732
# Objective Built: 0.6899185180664062
# Objective Built: 0.6863775253295898
# Problem Solved: 59.562010049819946
# Problem Solved: 59.28281092643738
# Problem Solved: 60.16227388381958
# Solution Graph Built: 4.475080251693726
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Problem Solved: 63.42444658279419
# Solution Graph Built: 4.837008476257324
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.6060798168182373
# Solution Graph Built: 4.456073760986328
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Solution DataFrame Built: 0.5911867618560791
# Solution DataFrame Built: 0.6084327697753906
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 18,133,047 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                670.00           0.00         670.00          106,267.74              0.00         2
# biomass                                 12.60           0.00          12.60                0.00              0.00         1
# coal                                 5,705.22           0.00       5,705.22                0.00              0.00         2
# large_hydro                            485.60           0.00         485.60                0.00              0.00         2
# natural gas combined cycle           3,343.60           0.00       3,343.60                0.00              0.00         2
# natural gas turbine                  5,109.35           0.00       5,109.35                0.00              0.00         3
# non-fossil                              19.80           0.00          19.80                0.00              0.00         2
# oil                                    153.00           0.00         153.00                0.00              0.00         3
# pump hydro                               0.04           0.00           0.04                0.00              0.00         1
# small_hydro                            513.70           0.00         513.70                0.00              0.00         3
# solar                                5,378.16           0.00       5,378.16           89,111.23              0.00        66
# steam                                   95.00           0.00          95.00                0.00              0.00         1
# unknown                            -17,871.61           0.00     -17,871.61                0.00              0.00         4
# waste                                   10.00           0.00          10.00                0.00              0.00         4
# wind                                12,223.10           0.00      12,223.10          102,341.13              0.00        39
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              6,772,719.71
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 10.0%
# ============================================================================================================================================
#
# Gas Generation: 18,132,909 MWh
# Total Objective: $1,044,168,472.97
#
# Problem Solved: 66.1140193939209
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                670.00           0.00         670.00          106,267.74              0.00         2
# biomass                                 12.60           0.00          12.60                0.00              0.00         1
# coal                                 5,705.22           0.00       5,705.22                0.00              0.00         2
# large_hydro                            485.60           0.00         485.60                0.00              0.00         2
# natural gas combined cycle           3,343.60           0.00       3,343.60                0.00              0.00         2
# natural gas turbine                  5,109.35           0.00       5,109.35                0.00              0.00         3
# non-fossil                              19.80           0.00          19.80                0.00              0.00         2
# oil                                    153.00           0.00         153.00                0.00              0.00         3
# pump hydro                               0.04           0.00           0.04                0.00              0.00         1
# small_hydro                            513.70           0.00         513.70                0.00              0.00         3
# solar                                5,378.16           0.00       5,378.16           89,111.23              0.00        66
# steam                                   95.00           0.00          95.00                0.00              0.00         1
# unknown                            -17,871.61           0.00     -17,871.61                0.00              0.00         4
# waste                                   10.00           0.00          10.00                0.00              0.00         4
# wind                                12,223.10           0.00      12,223.10          102,341.13              0.00        39
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              6,772,896.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 18,134,418 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                670.00           0.00         670.00          106,267.74              0.00         2
# biomass                                 12.60           0.00          12.60                0.00              0.00         1
# coal                                 5,705.22           0.00       5,705.22                0.00              0.00         2
# large_hydro                            485.60           0.00         485.60                0.00              0.00         2
# natural gas combined cycle           3,343.60           0.00       3,343.60                0.00              0.00         2
# natural gas turbine                  5,109.35           0.00       5,109.35                0.00              0.00         3
# non-fossil                              19.80           0.00          19.80                0.00              0.00         2
# oil                                    153.00           0.00         153.00                0.00              0.00         3
# pump hydro                               0.04           0.00           0.04                0.00              0.00         1
# small_hydro                            513.70           0.00         513.70                0.00              0.00         3
# solar                                5,378.16           0.00       5,378.16           89,111.23              0.00        66
# steam                                   95.00           0.00          95.00                0.00              0.00         1
# unknown                            -17,871.61           0.00     -17,871.61                0.00              0.00         4
# waste                                   10.00           0.00          10.00                0.00              0.00         4
# wind                                12,223.10           0.00      12,223.10          102,341.13              0.00        39
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              6,772,327.22
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 486,223,437.28
#   natural gas combined cycle     $ 381,669,296.86
#   natural gas turbine            $  98,924,203.72
#   oil                            $  15,029,229.13
#   non-fossil                     $   1,084,995.97
#   waste                          $     542,684.88
#   large_hydro                    $     193,096.47
#   small_hydro                    $      43,399.58
#   steam                          $      10,879.28
#   TOTAL                          $ 983,721,223.16
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WECC_WY:WECC_CO                $  55,273,373.77
#   WECC_CO:WECC_WY                $   2,669,128.76
#   TOTAL                          $  57,942,502.53
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $1,041,663,725.70
# Model Objective                $1,044,168,472.97
# Other Gap                      $   2,504,747.27
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WECC_CO -> WECC_WY via line_205: 92.68 MWh
# WECC_WY -> WECC_CO via line_250: 1,919.21 MWh
#
# Total transmission across all lines: 2,011.89 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# Total Objective: $1,044,169,919.64
#
# Total Objective: $1,044,169,367.51
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 486,233,483.26
#   natural gas combined cycle     $ 381,683,134.54
#   natural gas turbine            $  98,899,896.59
#   oil                            $  15,024,754.59
#   non-fossil                     $   1,085,244.19
#   waste                          $     542,870.32
#   large_hydro                    $     193,085.47
#   small_hydro                    $      43,390.66
#   steam                          $      10,879.28
#   TOTAL                          $ 983,716,738.90
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WECC_WY:WECC_CO                $  55,280,127.50
#   WECC_CO:WECC_WY                $   2,668,295.82
#   TOTAL                          $  57,948,423.32
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $1,041,665,162.22
# Model Objective                $1,044,169,919.64
# Other Gap                      $   2,504,757.43
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WECC_CO -> WECC_WY via line_205: 92.65 MWh
# WECC_WY -> WECC_CO via line_250: 1,919.45 MWh
#
# Total transmission across all lines: 2,012.10 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 486,192,908.77
#   natural gas combined cycle     $ 381,686,351.68
#   natural gas turbine            $  98,948,535.01
#   oil                            $  15,027,551.49
#   non-fossil                     $   1,085,237.18
#   waste                          $     542,897.88
#   large_hydro                    $     193,113.03
#   small_hydro                    $      43,398.04
#   steam                          $      10,879.28
#   TOTAL                          $ 983,730,872.35
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   WECC_WY:WECC_CO                $  55,267,112.90
#   WECC_CO:WECC_WY                $   2,666,646.21
#   TOTAL                          $  57,933,759.11
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $1,041,664,631.47
# Model Objective                $1,044,169,367.51
# Other Gap                      $   2,504,736.05
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# WECC_CO -> WECC_WY via line_205: 92.59 MWh
# WECC_WY -> WECC_CO via line_250: 1,919.00 MWh
#
# Total transmission across all lines: 2,011.59 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     30,480.24       5,705.22           0.00       5,705.22         2
# natural gas combined cycle               15,233.40       3,343.60           0.00       3,343.60         2
# natural gas turbine                       2,899.64       5,109.35           0.00       5,109.35         3
# battery                                   1,229.50         670.00           0.00         670.00         2
# large_hydro                                 995.90         485.60           0.00         485.60         2
# small_hydro                                 943.85         513.70           0.00         513.70         3
# oil                                         598.55         153.00           0.00         153.00         3
# non-fossil                                  156.41          19.80           0.00          19.80         2
# waste                                        78.23          10.00           0.00          10.00         4
# pump hydro                                    0.41           0.04           0.00           0.04         1
# steam                                         0.28          95.00           0.00          95.00         1
# biomass                                       0.00          12.60           0.00          12.60         1
# solar                                   -15,504.07       5,378.16           0.00       5,378.16        66
# wind                                    -38,887.90      12,223.10           0.00      12,223.10        39
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   6,772,719.71
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 66
# Wind assets found : 39
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WECC_CO:
#   Installed Capacity: 637.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WECC_WY:
#   Installed Capacity: 68.04 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s01_s01_slow_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s01_s01_slow_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s01_s01_slow_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s01_s01_slow_m0_d360/s01_s01_ev_summary.csv
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     30,480.93       5,705.22           0.00       5,705.22         2
# natural gas combined cycle               15,233.96       3,343.60           0.00       3,343.60         2
# natural gas turbine                       2,898.95       5,109.35           0.00       5,109.35         3
# battery                                   1,229.97         670.00           0.00         670.00         2
# large_hydro                                 995.84         485.60           0.00         485.60         2
# small_hydro                                 943.72         513.70           0.00         513.70         3
# oil                                         598.38         153.00           0.00         153.00         3
# non-fossil                                  156.44          19.80           0.00          19.80         2
# waste                                        78.26          10.00           0.00          10.00         4
# pump hydro                                    0.41           0.04           0.00           0.04         1
# steam                                         0.28          95.00           0.00          95.00         1
# biomass                                       0.00          12.60           0.00          12.60         1
# solar                                   -15,504.07       5,378.16           0.00       5,378.16        66
# wind                                    -38,887.90      12,223.10           0.00      12,223.10        39
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   6,772,896.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 66
# Wind assets found : 39
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_WECC_CO:
#   Installed Capacity: 637.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_WECC_WY:
#   Installed Capacity: 68.04 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/RMRG/scenario_results_2030_slow_RMRG_midnight/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# ...
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.238804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000     policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
#
# ================================================================================
# ================================================================================
#
#
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.238804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
# EV state: RMRG
# Model region: RMRG
# STATE_TO_REGIONS key used: RMRG
# GOOD regions used: ['WECC_CO', 'WECC_WY']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_RMRG_CO: ratio=0.138804, regions=['WECC_CO', 'WECC_WY']
# Total battery assets removed: 3
# ================================================================================
#
# EV profile market key: RMRG
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#
# Processed 99 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 24.08%
# Capacity before  : 7,514.77 MW
# Capacity after   : 5,705.22 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 79
# Exact duplicate groups: 5
# Assets contained in duplicate groups: 11
# Assets potentially removable: 6
# CAPEX variables after exact aggregation: 73
# ================================================================================
#
# Largest exact groups:
# WECC_WY      | WY  | solar  | assets=  3 | profile=WECC_WY:solar:3
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:4
# WECC_CO      | CO  | solar  | assets=  2 | profile=WECC_CO:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
# WECC_WY      | NE  | solar  | assets=  2 | profile=WECC_WY:solar:3
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
#      policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_RMRG_CO excluded   generator                       coal           CO         False            1  2110.576000
# rps_RMRG_CO excluded   generator natural gas combined cycle           CO         False            1  3249.600000
# rps_RMRG_CO excluded   generator        natural gas turbine           CO         False            1  4836.753063
# rps_RMRG_CO excluded   generator                 non-fossil           CO         False            1    18.900000
# rps_RMRG_CO excluded   generator                        oil           CO         False            1   140.700001
# rps_RMRG_CO excluded   generator                      steam           CO         False            1    95.000000
# rps_RMRG_CO excluded large_hydro                large_hydro           CO         False            1   418.799998
# rps_RMRG_CO included   generator                    biomass           CO          True            1    12.600000
# rps_RMRG_CO included   generator                      waste           CO          True            1     9.300000
# rps_RMRG_CO included small_hydro                small_hydro           CO          True            1   271.000002
# rps_RMRG_CO included       solar                      solar           CO          True           29  4650.278663
# rps_RMRG_CO included        wind                       wind           CO          True           19  5351.600000
# ================================================================================
#
# Parameters Built: 2.7179296016693115
# Parameters Built: 2.723804473876953
# Parameters Built: 2.732173442840576
# Parameters Built: 2.819948434829712
# Parameters Built: 2.876589059829712
# Variables Built: 1.4848670959472656
# Variables Built: 1.4798226356506348
# Variables Built: 1.5070960521697998
# Variables Built: 1.6368441581726074
# Variables Built: 1.6742675304412842
# Constraints Built: 12.315828561782837
# Constraints Built: 12.297246217727661
# Constraints Built: 12.362452745437622
# Objective Built: 1.4759883880615234
# Objective Built: 1.4787025451660156
# Objective Built: 1.4790222644805908
# Constraints Built: 13.553249835968018
# Constraints Built: 13.688517093658447
# Objective Built: 0.703038215637207
# Objective Built: 0.6820037364959717
