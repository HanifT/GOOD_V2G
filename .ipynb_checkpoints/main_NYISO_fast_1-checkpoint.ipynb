# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 90

IPM_REGION = "NYISO"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"
with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)

YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "NY"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/New_York_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 40  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    # "slow",
    "mid", 
    # "fast"
]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "NY_Z_J": 0.40,      # NYC - highest demand, most valuable storage
    "NY_Z_K": 0.20,      # Long Island - high demand, constrained transmission
    "NY_Z_F": 0.10,      # Capital region
    "NY_Z_C&E": 0.10,    # Central
    "NY_Z_G-I": 0.10,    # Hudson Valley - transmission relief
    "NY_Z_A": 0.05,      # Western NY
    "NY_Z_B": 0.025,     # Genesee
    "NY_Z_D": 0.025,     # North
}

STATE_TO_REGIONS = {
    "NY": [
        "NY_Z_A",
        "NY_Z_B",
        "NY_Z_C&E",
        "NY_Z_D",
        "NY_Z_F",
        "NY_Z_G-I",
        "NY_Z_J",
        "NY_Z_K"
    ],
}

RETIREMENT_POLICIES = {
    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },
}

ASSET_CONSTRAINT_POLICIES = {

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 690,
        },
    },
    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "CA": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (slow)
# # Charging scenarios: 1 (flex)
# # Total combinations: 1
# # Total runs: 15 (= 15 scenarios × 1 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Flexible load leveling
# Results Directory: Output/NYISO/scenario_results_2030_slow_NYISO_flex
# ================================================================================
#
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.062816143035889
# Variables Built: 4.044363498687744
# Constraints Built: 35.581355571746826
# Objective Built: 2.361069917678833
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.046478748321533
# Variables Built: 4.0521745681762695
# Constraints Built: 35.60602951049805
# Objective Built: 2.36460018157959
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.0395941734313965
# Variables Built: 4.1001012325286865
# Constraints Built: 35.76046895980835
# Objective Built: 2.3485846519470215
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.6, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.412122488021851
# Variables Built: 4.534746170043945
# Constraints Built: 37.53517532348633
# Objective Built: 4.912444353103638
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.7, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 6.373103857040405
# Variables Built: 4.517894744873047
# Constraints Built: 37.64671230316162
# Objective Built: 4.918050050735474
# Problem Solved: 1766.5079851150513
# Solution Graph Built: 71.53156471252441
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 3.3450186252593994
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 31,091,595 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39       9,293.62      15,042.02          336,540.11          1,281.39       155
# solar                                8,460.55       6,052.13      14,512.68           80,759.09            567.76        64
# battery                                690.00           0.00         690.00          106,267.74              0.00         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,597.08           0.00     -33,597.08                0.00              0.00        16
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              4,249,929.48
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $4,355,093,884.61
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,281,387,656.02
#   solar                          $ 567,757,648.52
#   TOTAL                          $1,849,145,304.54
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $ 656,889,731.22
#   nuclear                        $ 612,305,498.51
#   import                         $ 238,930,627.46
#   steam                          $ 122,533,006.10
#   natural gas turbine            $ 108,501,644.49
#   oil                            $  78,569,534.26
#   waste                          $  25,148,237.89
#   biomass                        $  14,676,987.53
#   large_hydro                    $   7,329,086.19
#   non-fossil                     $     798,290.52
#   small_hydro                    $     241,009.13
#   TOTAL                          $1,865,923,653.30
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 195,902,884.50
#   NY_Z_F:NY_Z_G-I                $ 123,689,009.73
#   NY_Z_C&E:NY_Z_G-I              $ 113,167,863.59
#   NY_Z_C&E:NY_Z_F                $  92,941,162.48
#   NY_Z_G-I:NY_Z_K                $  52,007,838.26
#   NY_Z_D:NY_Z_C&E                $  22,922,297.61
#   NY_Z_K:NY_Z_J                  $   7,526,746.85
#   NY_Z_C&E:NY_Z_B                $   6,224,455.62
#   NY_Z_B:NY_Z_A                  $   5,838,505.76
#   NY_Z_B:NY_Z_C&E                $   5,177,079.97
#   NY_Z_A:NY_Z_B                  $   5,150,098.89
#   NY_Z_J:NY_Z_K                  $   3,730,547.05
#   NY_Z_K:NY_Z_G-I                $   2,531,886.33
#   NY_Z_C&E:NY_Z_D                $     634,311.74
#   TOTAL                          $ 637,444,688.40
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $4,352,513,646.25
# Model Objective                $4,355,093,884.61
# Other Gap                      $   2,580,238.37
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 178.82 MWh
# NY_Z_B -> NY_Z_A via line_81: 202.73 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 179.76 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 216.13 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 22.02 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 3,227.12 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,929.44 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 795.91 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 4,294.76 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 6,802.18 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 1,805.83 MWh
# NY_Z_J -> NY_Z_K via line_99: 129.53 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 87.91 MWh
# NY_Z_K -> NY_Z_J via line_102: 261.35 MWh
#
# Total transmission across all lines: 22,133.50 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================  Scenario   1 ✓
#
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle               27,637.00      10,907.10           0.00      10,907.10         9
# nuclear                                  27,474.27       3,346.70           0.00       3,346.70         2
# large_hydro                               5,708.28       3,374.40           0.00       3,374.40         3
# small_hydro                               4,472.52       1,186.40           0.00       1,186.40         6
# steam                                     4,354.87      10,910.56           0.00      10,910.56         6
# import                                    3,792.55       5,850.00           0.00       5,850.00         3
# waste                                     3,625.89         473.20           0.00         473.20         8
# natural gas turbine                       3,454.59       2,545.92           0.00       2,545.92         8
# oil                                       2,508.08       1,699.11           0.00       1,699.11         5
# battery                                   1,299.52         690.00           0.00         690.00         8
# biomass                                     276.79          54.90           0.00          54.90         1
# non-fossil                                  115.08          20.20           0.00          20.20         2
# pump hydro                                    0.63           0.10           0.00           0.10         2
# solar                                   -28,036.91       8,460.55       6,052.13      14,512.68        64
# wind                                    -58,225.00       5,748.39       9,293.62      15,042.02       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                   4,249,929.48
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 74.51 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 56.67 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 111.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 12.42 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 71.07 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 112.26 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 136.65 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 126.53 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_s01_slow_m0_d360/s01_s01_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_s01_slow_m0_d360/s01_s01_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_s01_slow_m0_d360/s01_s01_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_s01_slow_m0_d360/s01_s01_ev_summary.csv
# Finished scenario 1: s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s01_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 4,355,093,884.61
# EV state: NY
# Model region: NYISO
# STATE_TO_REGIONS key used: NY
# GOOD regions used: ['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_NYISO: ratio=0.8, regions=['NY_Z_A', 'NY_Z_B', 'NY_Z_C&E', 'NY_Z_D', 'NY_Z_F', 'NY_Z_G-I', 'NY_Z_J', 'NY_Z_K']
# Total battery assets removed: 8
# ================================================================================
#
# EV profile market key: NY
#
# Processed 206 renewable plants with capex
# Skipped 13 renewable plants (no valid capex_cost)
# ================================================================================
#
# oil retirement summary
# Retired fraction : 10.00%
# Capacity before  : 1,887.90 MW
# Capacity after   : 1,699.11 MW
# natural gas turbine retirement summary
# Retired fraction : 15.00%
# Capacity before  : 2,995.20 MW
# Capacity after   : 2,545.92 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 133
# Exact duplicate groups: 7
# Assets contained in duplicate groups: 18
# Assets potentially removable: 11
# CAPEX variables after exact aggregation: 122
# ================================================================================
#
# Largest exact groups:
# NY_Z_D       | NY  | solar  | assets=  4 | profile=NY_Z_D:solar:1
# NY_Z_F       | NY  | solar  | assets=  4 | profile=NY_Z_F:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_A       | NY  | solar  | assets=  2 | profile=NY_Z_A:solar:1
# NY_Z_B       | NY  | solar  | assets=  2 | profile=NY_Z_B:solar:1
# NY_Z_C&E     | NY  | solar  | assets=  2 | profile=NY_Z_C&E:solar:1
# NY_Z_G-I     | NY  | solar  | assets=  2 | profile=NY_Z_G-I:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_NYISO excluded   generator natural gas combined cycle           NY         False            8  9954.800000
# rps_NYISO excluded   generator        natural gas turbine           NY         False            7  2050.678178
# rps_NYISO excluded   generator                 non-fossil           NY         False            2    20.200000
# rps_NYISO excluded   generator                    nuclear           NY         False            2  3346.700000
# rps_NYISO excluded   generator                        oil           NY         False            5  1699.110000
# rps_NYISO excluded   generator                      steam           NY         False            6 10910.560000
# rps_NYISO excluded large_hydro                large_hydro           NY         False            3  3374.400000
# rps_NYISO included   generator                    biomass           NY          True            1    54.900000
# rps_NYISO included   generator                      waste           NY          True            8   473.200000
# rps_NYISO included small_hydro                small_hydro           NY          True            6  1186.400000
# rps_NYISO included       solar                      solar           NY          True           64  8460.547085
# rps_NYISO included        wind                       wind           NY          True          155  5748.393721
# ================================================================================
#
# Parameters Built: 10.992489099502563
# Variables Built: 3.2510879039764404
# Constraints Built: 67.63488459587097
# Objective Built: 2.7622880935668945
# Problem Solved: 1960.1040995121002
# Solution Graph Built: 52.21539378166199
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 1.587585687637329
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 70.0%
# ============================================================================================================================================
#
# Gas Generation: 22,336,637 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                 5,748.39      12,145.00      17,893.39          336,540.11          1,826.89       155
# solar                                8,460.55       8,267.96      16,728.50           80,759.09            779.21        64
# battery                                690.00         881.47       1,571.47          106,267.74             92.39         8
# biomass                                 54.90           0.00          54.90                0.00              0.00         1
# import                               5,850.00           0.00       5,850.00                0.00              0.00         3
# large_hydro                          3,374.40           0.00       3,374.40                0.00              0.00         3
# natural gas combined cycle          10,907.10           0.00      10,907.10                0.00              0.00         9
# natural gas turbine                  2,545.92           0.00       2,545.92                0.00              0.00         8
# non-fossil                              20.20           0.00          20.20                0.00              0.00         2
# nuclear                              3,346.70           0.00       3,346.70                0.00              0.00         2
# oil                                  1,699.11           0.00       1,699.11                0.00              0.00         5
# pump hydro                               0.10           0.00           0.10                0.00              0.00         2
# small_hydro                          1,186.40           0.00       1,186.40                0.00              0.00         6
# steam                               10,910.56           0.00      10,910.56                0.00              0.00         6
# unknown                            -33,597.08           0.00     -33,597.08                0.00              0.00        16
# waste                                  473.20           0.00         473.20                0.00              0.00         8
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)              8,950,903.46
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $5,611,872,992.39
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $1,826,890,889.63
#   solar                          $ 779,210,222.79
#   battery                        $  92,388,824.38
#   TOTAL                          $2,698,489,936.81
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   import                         $ 820,357,620.51
#   nuclear                        $ 612,206,756.54
#   natural gas combined cycle     $ 460,763,660.67
#   natural gas turbine            $ 102,502,330.86
#   oil                            $  56,934,507.79
#   steam                          $  46,962,279.99
#   waste                          $  22,675,836.19
#   biomass                        $  11,970,870.74
#   non-fossil                     $     411,021.80
#   small_hydro                    $     212,466.24
#   large_hydro                    $      32,444.17
#   TOTAL                          $2,135,029,795.51
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   NY_Z_G-I:NY_Z_J                $ 245,493,003.73
#   NY_Z_F:NY_Z_G-I                $ 181,329,524.63
#   NY_Z_C&E:NY_Z_G-I              $ 107,598,600.80
#   NY_Z_C&E:NY_Z_F                $  79,382,768.56
#   NY_Z_G-I:NY_Z_K                $  63,233,545.94
#   NY_Z_D:NY_Z_C&E                $  39,034,039.58
#   NY_Z_J:NY_Z_K                  $  15,286,454.18
#   NY_Z_B:NY_Z_A                  $   8,642,256.76
#   NY_Z_K:NY_Z_J                  $   8,218,485.37
#   NY_Z_C&E:NY_Z_B                $   7,347,652.20
#   NY_Z_A:NY_Z_B                  $   7,115,541.14
#   NY_Z_B:NY_Z_C&E                $   5,706,924.95
#   NY_Z_K:NY_Z_G-I                $   2,851,699.64
#   NY_Z_C&E:NY_Z_D                $   1,215,766.28
#   NY_Z_F:NY_Z_C&E                $       3,847.60
#   TOTAL                          $ 772,460,111.35
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,605,979,843.67
# Model Objective                $5,611,872,992.39
# Other Gap                      $   5,893,148.72
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# NY_Z_A -> NY_Z_B via line_79: 247.07 MWh
# NY_Z_B -> NY_Z_A via line_81: 300.08 MWh
# NY_Z_B -> NY_Z_C&E via line_82: 198.16 MWh
# NY_Z_C&E -> NY_Z_B via line_83: 255.13 MWh
# NY_Z_C&E -> NY_Z_D via line_84: 42.21 MWh
# NY_Z_C&E -> NY_Z_F via line_85: 2,756.35 MWh
# NY_Z_C&E -> NY_Z_G-I via line_86: 3,736.06 MWh
# NY_Z_D -> NY_Z_C&E via line_88: 1,355.35 MWh
# NY_Z_F -> NY_Z_C&E via line_90: 0.13 MWh
# NY_Z_F -> NY_Z_G-I via line_91: 6,296.16 MWh
# NY_Z_G-I -> NY_Z_J via line_95: 8,524.06 MWh
# NY_Z_G-I -> NY_Z_K via line_96: 2,195.61 MWh
# NY_Z_J -> NY_Z_K via line_99: 338.61 MWh
# NY_Z_K -> NY_Z_G-I via line_101: 99.02 MWh
# NY_Z_K -> NY_Z_J via line_102: 285.36 MWh
#
# Total transmission across all lines: 26,629.36 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================  Scenario   2 ✓
#
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               19,073.09      10,907.10           0.00      10,907.10         9
# import                                   13,021.55       5,850.00           0.00       5,850.00         3
# small_hydro                               3,906.10       1,186.40           0.00       1,186.40         6
# battery                                   3,728.21         690.00         881.47       1,571.47         8
# waste                                     3,269.38         473.20           0.00         473.20         8
# natural gas turbine                       3,263.55       2,545.92           0.00       2,545.92         8
# oil                                       1,707.00       1,699.11           0.00       1,699.11         5
# steam                                     1,698.56      10,910.56           0.00      10,910.56         6
# biomass                                     225.76          54.90           0.00          54.90         1
# large_hydro                                 114.45       3,374.40           0.00       3,374.40         3
# ...
# Finished scenario 14: s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps70_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 5,491,324,783.35
#
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                 126,298.60         690.00      25,588.34      26,278.34         8
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               10,161.84      10,907.10           0.00      10,907.10         9
# small_hydro                               3,883.04       1,186.40           0.00       1,186.40         6
# waste                                     3,060.63         473.20           0.00         473.20         8
# import                                    1,942.58       5,850.00           0.00       5,850.00         3
# oil                                       1,470.70       1,699.11           0.00       1,699.11         5
# natural gas turbine                         878.33       2,545.92           0.00       2,545.92         8
# biomass                                     199.12          54.90           0.00          54.90         1
# steam                                        27.83      10,910.56           0.00      10,910.56         6
# non-fossil                                    3.08          20.20           0.00          20.20         2
# pump hydro                                    0.37           0.10           0.00           0.10         2
# large_hydro                                   0.00       3,374.40           0.00       3,374.40         3
# solar                                   -64,679.45       8,460.55      24,186.96      32,647.51        64
# wind                                    -86,651.36       5,748.39      16,888.00      22,636.39       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  13,612,564.03
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 37.25 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_A:
#   Installed Capacity: 37.25 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 37.25 MW
#   Max Shift Down: -18.62 MW
#   Total Shifting: 80,684.50 MWh
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 28.33 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_B:
#   Installed Capacity: 28.33 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 28.33 MW
#   Max Shift Down: -14.16 MW
#   Total Shifting: 72,120.54 MWh
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 55.64 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_C&E:
#   Installed Capacity: 55.64 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 55.64 MW
#   Max Shift Down: -27.81 MW
#   Total Shifting: 147,548.44 MWh
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_D:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 6.21 MW
#   Max Shift Down: -3.11 MW
#   Total Shifting: 13,943.43 MWh
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 35.54 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_F:
#   Installed Capacity: 35.54 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 35.54 MW
#   Max Shift Down: -17.76 MW
#   Total Shifting: 108,790.31 MWh
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 56.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_G-I:
#   Installed Capacity: 56.13 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 56.13 MW
#   Max Shift Down: -28.06 MW
#   Total Shifting: 180,561.94 MWh
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 68.32 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_J:
#   Installed Capacity: 68.32 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 68.32 MW
#   Max Shift Down: -34.16 MW
#   Total Shifting: 225,841.58 MWh
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 63.27 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_NY_Z_K:
#   Installed Capacity: 63.27 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 63.27 MW
#   Max Shift Down: -31.63 MW
#   Total Shifting: 167,764.66 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_s12_slow_m0_d360/s12_s12_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_s12_slow_m0_d360/s12_s12_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_s12_slow_m0_d360/s12_s12_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_s12_slow_m0_d360/s12_s12_ev_summary.csv
# Finished scenario 12: s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360/s12_V1G_rps80_v1g50_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 10,154,416,419.65
#
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                 125,734.50         690.00      25,248.17      25,938.17         8
# nuclear                                  27,469.71       3,346.70           0.00       3,346.70         2
# natural gas combined cycle               10,146.74      10,907.10           0.00      10,907.10         9
# small_hydro                               3,889.46       1,186.40           0.00       1,186.40         6
# waste                                     3,066.02         473.20           0.00         473.20         8
# import                                    1,917.16       5,850.00           0.00       5,850.00         3
# oil                                       1,469.96       1,699.11           0.00       1,699.11         5
# natural gas turbine                         874.65       2,545.92           0.00       2,545.92         8
# ev_v2g                                      806.78       1,185.09           0.00       1,185.09         8
# biomass                                     197.40          54.90           0.00          54.90         1
# steam                                        25.66      10,910.56           0.00      10,910.56         6
# non-fossil                                    3.07          20.20           0.00          20.20         2
# pump hydro                                    0.40           0.10           0.00           0.10         2
# large_hydro                                   0.00       3,374.40           0.00       3,374.40         3
# solar                                   -64,507.97       8,460.55      24,094.68      32,555.22        64
# wind                                    -86,607.03       5,748.39      16,876.57      22,624.96       155
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  13,446,182.82
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 64
# Wind assets found : 155
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_NY_Z_A:
#   Installed Capacity: 37.25 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_A:
#   Installed Capacity: 37.25 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_B:
#   Installed Capacity: 28.33 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_B:
#   Installed Capacity: 28.33 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_C&E:
#   Installed Capacity: 55.64 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_C&E:
#   Installed Capacity: 55.64 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_D:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_D:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_F:
#   Installed Capacity: 35.54 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_F:
#   Installed Capacity: 35.54 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_G-I:
#   Installed Capacity: 56.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_G-I:
#   Installed Capacity: 56.13 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_J:
#   Installed Capacity: 68.32 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_J:
#   Installed Capacity: 68.32 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_NY_Z_K:
#   Installed Capacity: 63.27 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_NY_Z_K:
#   Installed Capacity: 63.27 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_s15_slow_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_s15_slow_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_s15_slow_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_s15_slow_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 15: s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/NYISO/scenario_results_2030_slow_NYISO_flex/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps80_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 10,107,538,680.08
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/NYISO/scenario_results_2030_slow_NYISO_flex/all_scenarios_summary.csv
