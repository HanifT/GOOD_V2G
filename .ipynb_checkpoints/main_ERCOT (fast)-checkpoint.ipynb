# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 10
CPLEX_THREADS_PER_SCENARIO = 12

IPM_REGION = "ERCOT"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)
YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "TX"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/Texas_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 138  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    "slow",
                      # "mid", "fast"
                     ]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    # "midnight": {
    #     "profile": "timed_charging",
    #     "description": "Midnight timed charging",
    # },
    # "delay": {
    #     "profile": "max_delay",
    #     "description": "Maximum delay charging",
    # },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    # "flex": {
    #     "profile": "load_leveling",
    #     "description": "Flexible load leveling",
    # },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "ERC_REST": 0.60,
    "ERC_WEST": 0.40,
    "ERC_GWAY": 0.5,
    "ERC_FRNT": 0.15,
    "ERC_PHDL": 0.10,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

ERCOT_REGIONS = [
    "ERC_FRNT",
    "ERC_PHDL",
    "ERC_GWAY",
    "ERC_REST",
    "ERC_WEST",
]

STATE_TO_REGIONS = {
    "TX": ERCOT_REGIONS,
    "ERCOT": ERCOT_REGIONS,
}
RETIREMENT_POLICIES = {
    "TX": {
        "coal": 1 / 3,
    },

    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },

    "CA": {
        "oil": 0.70,
        "nuclear": 1.00,
        "natural gas turbine": 0.20,
        "natural gas combined cycle": 0.04,
        "coal": 1.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "TX": {
        # ERCOT 2030 central logic:
        # Nuclear is small in capacity but high in energy output, so keep it highly must-run.
        # Coal is still meaningful, but do NOT force it at 45% in a 2030 renewable-heavy case.
        # Combined-cycle gas should provide reliability, but not behave as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },
    },

    "CA": {
        # CAISO / California 2030 central logic:
        # Do not add a nuclear constraint unless your GOOD input data explicitly includes CA nuclear.
        # California policy still treats Diablo Canyon as a transition/reliability resource, not a long-run
        # 2030+ baseload expansion resource.
        # Gas must stay flexible because CA has solar-heavy duck-curve conditions.

        # If your GOOD data has a CA "nuclear" category and you are modeling a 2030 week
        # before Diablo Canyon Unit 2 retirement, you may add this sensitivity:
        #
        # "nuclear": {
        #     "must_run_fraction": 0.60,
        #     "ramp_rate": 0.03,
        # },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.08,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "FL": {
        # Florida / FRCC 2030 central logic:
        # Nuclear is baseload.
        # Florida relies heavily on natural gas, especially combined-cycle gas.
        # Coal still exists but should have a low floor because coal retirements and solar growth continue.
        # Oil should not be must-run.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.04,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.18,
            "ramp_rate": 0.18,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.60,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "PJM": {
        # PJM 2030 central logic:
        # Nuclear is large and should remain highly must-run.
        # Coal is still important, but a 45% hourly floor is too high for a 2030 policy/RPS case.
        # Combined-cycle gas is important for reliability and load growth, but it should not be forced
        # as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 17500,
        },
    },

    "CA": {
        "battery": {
            "total_power_mw": 16900,
        },
    },

    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },

    "TX": {
        "battery": {
            "total_power_mw": 17500,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": True,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 3 (slow, mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 12
# # Total runs: 180 (= 15 scenarios × 12 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            3  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False           17 36749.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False           19  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            7  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 10.007684230804443
# Variables Built: 3.4886507987976074
# Constraints Built: 30.355958223342896
# Objective Built: 1.5712974071502686
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.6, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            3  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False           17 36749.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False           19  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            7  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 10.016055345535278
# Variables Built: 3.58111310005188
# Constraints Built: 30.5129177570343
# Objective Built: 1.5853164196014404
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            3  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False           17 36749.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False           19  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            7  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 10.006652116775513
# Variables Built: 3.682339906692505
# Constraints Built: 30.63642644882202
# Objective Built: 1.5807256698608398
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            3  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False           17 36749.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False           19  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            7  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 10.181832790374756
# Variables Built: 3.611147165298462
# Constraints Built: 31.68427085876465
# Objective Built: 1.675483226776123
# Problem Solved: 739.8997852802277
# Solution Graph Built: 40.17741084098816
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.9041483402252197
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 138,337,325 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      68,464.98     105,607.48           98,282.12          6,853.40        81
# solar                               36,639.68      39,741.66      76,381.35           87,465.64          3,260.10        59
# battery                             17,500.00       9,391.14      26,891.14          106,267.74            984.30         5
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         3
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          36,749.70           0.00      36,749.70                0.00              0.00        17
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00        19
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         7
# unknown                           -142,961.87           0.00    -142,961.87                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             46,590,070.03
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $16,701,974,812.71
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,853,403,521.57
#   solar                          $3,260,104,288.73
#   battery                        $ 984,304,529.95
#   TOTAL                          $11,097,812,340.25
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,919,069,386.03
#   coal                           $ 860,323,885.36
#   nuclear                        $ 825,721,466.77
#   steam                          $  61,915,841.18
#   natural gas turbine            $  55,826,591.70
#   waste                          $  11,473,987.78
#   non-fossil                     $   3,742,892.43
#   biomass                        $     180,681.90
#   oil                            $     150,485.33
#   large_hydro                    $      12,600.59
#   small_hydro                    $       8,620.32
#   TOTAL                          $4,738,426,439.40
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 622,409,694.02
#   ERC_PHDL:ERC_WEST              $ 124,565,372.14
#   ERC_FRNT:ERC_REST              $   8,107,644.04
#   ERC_GWAY:ERC_REST              $   7,755,646.65
#   ERC_REST:ERC_WEST              $   2,889,393.12
#   ERC_WEST:ERC_PHDL              $       1,217.18
#   TOTAL                          $ 765,728,967.15
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,601,967,746.79
# Model Objective                $16,701,974,812.71
# Other Gap                      $ 100,007,065.92
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_FRNT -> ERC_REST via line_0: 281.52 MWh
# ERC_PHDL -> ERC_WEST via line_4: 4,325.19 MWh
# ERC_GWAY -> ERC_REST via line_2: 269.29 MWh
# ERC_REST -> ERC_WEST via line_5: 100.33 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.04 MWh
# ERC_WEST -> ERC_REST via line_8: 21,611.45 MWh
#
# Total transmission across all lines: 26,587.81 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets  Scenario   3 ✓
# Problem Solved: 783.8344650268555
# Solution Graph Built: 39.56145000457764
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.8835787773132324
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 138,337,046 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      68,465.61     105,608.11           98,282.12          6,853.47        81
# solar                               36,639.68      39,741.28      76,380.97           87,465.64          3,260.07        59
# battery                             17,500.00       9,391.19      26,891.19          106,267.74            984.31         5
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         3
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          36,749.70           0.00      36,749.70                0.00              0.00        17
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00        19
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         7
# unknown                           -142,961.87           0.00    -142,961.87                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             46,591,248.28
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $16,701,974,222.44
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,853,467,882.87
#   solar                          $3,260,071,896.87
#   battery                        $ 984,309,594.78
#   TOTAL                          $11,097,849,374.52
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,919,068,996.15
#   coal                           $ 860,338,188.72
#   nuclear                        $ 825,707,872.55
#   steam                          $  61,899,514.32
#   natural gas turbine            $  55,822,095.17
#   waste                          $  11,473,993.48
#   non-fossil                     $   3,742,918.00
#   biomass                        $     180,681.90
#   oil                            $     150,372.38
#   large_hydro                    $      12,600.59
#   small_hydro                    $       8,618.47
#   TOTAL                          $4,738,405,851.73
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 622,404,483.28
#   ERC_PHDL:ERC_WEST              $ 124,554,654.10
#   ERC_FRNT:ERC_REST              $   8,107,350.81
#   ERC_GWAY:ERC_REST              $   7,755,195.74
#   ERC_REST:ERC_WEST              $   2,888,914.96
#   ERC_WEST:ERC_PHDL              $       1,217.18
#   TOTAL                          $ 765,711,816.07
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,601,967,042.32
# Model Objective                $16,701,974,222.44
# Other Gap                      $ 100,007,180.12
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_FRNT -> ERC_REST via line_0: 281.51 MWh
# ERC_PHDL -> ERC_WEST via line_4: 4,324.81 MWh
# ERC_GWAY -> ERC_REST via line_2: 269.28 MWh
# ERC_REST -> ERC_WEST via line_5: 100.31 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.04 MWh
# ERC_WEST -> ERC_REST via line_8: 21,611.27 MWh
#
# Total transmission across all lines: 26,587.22 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets  Scenario   2 ✓
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              136,733.34      36,749.70           0.00      36,749.70        17
# nuclear                                  41,216.24       4,960.00           0.00       4,960.00         1
# coal                                     38,380.46       8,603.07           0.00       8,603.07         3
# battery                                  25,206.89      17,500.00       9,391.14      26,891.14         5
# steam                                     1,778.82       9,055.70           0.00       9,055.70         7
# waste                                     1,646.76         210.40           0.00         210.40         2
# natural gas turbine                       1,603.98       8,608.50           0.00       8,608.50        19
# non-fossil                                  539.70          68.80           0.00          68.80         1
# small_hydro                                 305.85         341.10           0.00         341.10         1
# large_hydro                                 185.07         208.00           0.00         208.00         1
# oil                                           7.65           1.40           0.00           1.40         1
# biomass                                       3.41         117.50           0.00         117.50         1
# solar                                  -200,350.63      36,639.68      39,741.66      76,381.35        59
# wind                                   -410,173.75      37,142.50      68,464.98     105,607.48        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  46,590,070.03
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 46.09 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 4,699.24 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 216.54 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
# Finished scenario 3: s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,701,974,812.71
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            3  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False           17 36749.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False           19  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            7  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 11.395085334777832
# Variables Built: 10.666899681091309
# Constraints Built: 31.559231519699097
# Objective Built: 3.7088053226470947
# Problem Solved: 849.4529983997345
# Solution Graph Built: 32.50306534767151
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.9000663757324219
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 138,274,672 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      68,464.98     105,607.48           98,282.12          6,853.40        81
# solar                               36,639.68      39,741.66      76,381.35           87,465.64          3,260.10        59
# battery                             17,500.00       9,391.14      26,891.14          106,267.74            984.30         5
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         3
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          36,749.70           0.00      36,749.70                0.00              0.00        17
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00        19
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         7
# unknown                           -142,961.87           0.00    -142,961.87                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             46,587,752.82
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $16,701,892,280.72
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,853,403,521.57
#   solar                          $3,260,104,288.73
#   battery                        $ 984,304,529.95
#   TOTAL                          $11,097,812,340.25
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,917,751,533.45
#   coal                           $ 861,716,459.45
#   nuclear                        $ 825,596,492.06
#   steam                          $  61,775,414.78
#   natural gas turbine            $  55,899,362.63
#   waste                          $  11,473,980.52
#   non-fossil                     $   3,742,523.84
#   biomass                        $     182,799.58
#   oil                            $     150,218.10
#   large_hydro                    $      12,600.59
#   small_hydro                    $       8,555.48
#   TOTAL                          $4,738,309,940.47
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 622,443,565.74
#   ERC_PHDL:ERC_WEST              $ 124,576,627.04
#   ERC_FRNT:ERC_REST              $   8,096,244.05
#   ERC_GWAY:ERC_REST              $   7,754,536.51
#   ERC_REST:ERC_WEST              $   2,891,718.53
#   ERC_WEST:ERC_PHDL              $       1,591.85
#   TOTAL                          $ 765,764,283.72
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,601,886,564.44
# Model Objective                $16,701,892,280.72
# Other Gap                      $ 100,005,716.28
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_FRNT -> ERC_REST via line_0: 281.12 MWh
# ERC_PHDL -> ERC_WEST via line_4: 4,325.58 MWh
# ERC_GWAY -> ERC_REST via line_2: 269.25 MWh
# ERC_REST -> ERC_WEST via line_5: 100.41 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.06 MWh
# ERC_WEST -> ERC_REST via line_8: 21,612.62 MWh
#
# Total transmission across all lines: 26,589.04 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets  Scenario   1 ✓
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              136,733.19      36,749.70           0.00      36,749.70        17
# nuclear                                  41,215.56       4,960.00           0.00       4,960.00         1
# coal                                     38,381.36       8,603.07           0.00       8,603.07         3
# battery                                  25,203.91      17,500.00       9,391.19      26,891.19         5
# steam                                     1,778.33       9,055.70           0.00       9,055.70         7
# waste                                     1,646.76         210.40           0.00         210.40         2
# natural gas turbine                       1,603.86       8,608.50           0.00       8,608.50        19
# non-fossil                                  539.70          68.80           0.00          68.80         1
# small_hydro                                 305.78         341.10           0.00         341.10         1
# large_hydro                                 185.07         208.00           0.00         208.00         1
# oil                                           7.64           1.40           0.00           1.40         1
# biomass                                       3.41         117.50           0.00         117.50         1
# solar                                  -200,349.66      36,639.68      39,741.28      76,380.97        59
# wind                                   -410,175.99      37,142.50      68,465.61     105,608.11        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  46,591,248.28
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 46.09 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 4,699.24 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 216.54 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# ...
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/packages/anaconda3-2024.10-1/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/packages/anaconda3-2024.10-1/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              128,854.79      36,749.70           0.00      36,749.70        17
# nuclear                                  41,003.81       4,960.00           0.00       4,960.00         1
# coal                                     36,008.03       8,603.07           0.00       8,603.07         3
# battery                                  20,185.76      17,500.00       1,905.50      19,405.50         5
# ev_v2g                                    2,769.87       3,866.71           0.00       3,866.71         3
# steam                                     1,860.23       9,055.70           0.00       9,055.70         7
# waste                                     1,588.95         210.40           0.00         210.40         2
# natural gas turbine                       1,256.75       8,608.50           0.00       8,608.50        19
# non-fossil                                  520.76          68.80           0.00          68.80         1
# small_hydro                                 299.79         341.10           0.00         341.10         1
# large_hydro                                 184.18         208.00           0.00         208.00         1
# oil                                           7.03           1.40           0.00           1.40         1
# biomass                                       3.73         117.50           0.00         117.50         1
# solar                                  -207,962.41      36,639.68      43,107.25      79,746.93        59
# wind                                   -416,869.77      37,142.50      70,356.76     107,499.26        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  50,774,786.14
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_s13_slow_m0_d360/s13_s13_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_s13_slow_m0_d360/s13_s13_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_s13_slow_m0_d360/s13_s13_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_s13_slow_m0_d360/s13_s13_ev_summary.csv
# Finished scenario 13: s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360/s13_V2G_rps0_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,090,675,185.79
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              128,527.45      36,749.70           0.00      36,749.70        17
# nuclear                                  41,004.86       4,960.00           0.00       4,960.00         1
# coal                                     36,224.21       8,603.07           0.00       8,603.07         3
# battery                                  20,043.53      17,500.00       1,905.50      19,405.50         5
# ev_v2g                                    2,756.23       3,866.71           0.00       3,866.71         3
# steam                                     1,623.28       9,055.70           0.00       9,055.70         7
# waste                                     1,585.87         210.40           0.00         210.40         2
# natural gas turbine                       1,471.73       8,608.50           0.00       8,608.50        19
# non-fossil                                  519.99          68.80           0.00          68.80         1
# small_hydro                                 295.72         341.10           0.00         341.10         1
# large_hydro                                 178.61         208.00           0.00         208.00         1
# oil                                           7.02           1.40           0.00           1.40         1
# biomass                                       3.55         117.50           0.00         117.50         1
# solar                                  -207,962.41      36,639.68      43,107.25      79,746.93        59
# wind                                   -416,869.77      37,142.50      70,356.76     107,499.26        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  50,653,245.82
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_s15_slow_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_s15_slow_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_s15_slow_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_s15_slow_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 15: s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,089,921,743.28
#
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              128,526.47      36,749.70           0.00      36,749.70        17
# nuclear                                  41,004.59       4,960.00           0.00       4,960.00         1
# coal                                     36,227.31       8,603.07           0.00       8,603.07         3
# battery                                  20,040.46      17,500.00       1,905.50      19,405.50         5
# ev_v2g                                    2,758.24       3,866.71           0.00       3,866.71         3
# steam                                     1,625.28       9,055.70           0.00       9,055.70         7
# waste                                     1,585.87         210.40           0.00         210.40         2
# natural gas turbine                       1,469.67       8,608.50           0.00       8,608.50        19
# non-fossil                                  519.99          68.80           0.00          68.80         1
# small_hydro                                 295.72         341.10           0.00         341.10         1
# large_hydro                                 178.61         208.00           0.00         208.00         1
# oil                                           7.02           1.40           0.00           1.40         1
# biomass                                       3.55         117.50           0.00         117.50         1
# solar                                  -207,962.41      36,639.68      43,107.25      79,746.93        59
# wind                                   -416,869.77      37,142.50      70,356.76     107,499.26        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  50,655,545.77
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 10.87 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 1,108.14 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 51.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_s14_slow_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_s14_slow_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_s14_slow_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_s14_slow_m0_d360/s14_s14_ev_summary.csv
# Finished scenario 14: s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_arrive/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,089,923,226.05
