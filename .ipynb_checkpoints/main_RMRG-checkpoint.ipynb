# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 50
IPM_REGION = "SPP"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    # "mid",
    # "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

SPP_REGIONS = [
    "SPP_KIAM",
    "SPP_N",
    "SPP_NEBR",
    "SPP_SPS",
    "SPP_WAUE",
    "SPP_WEST",
]

STATE_TO_REGIONS = {
    "SPP": SPP_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EPA NEEDS active battery capacity
#
# SPP_KIAM     0.0 MW
# SPP_N        2.2 MW
# SPP_NEBR     2.9 MW
# SPP_SPS    256.0 MW
# SPP_WAUE     0.8 MW
# SPP_WEST   222.0 MW
#
# Total      483.9 MW
#
# Pumped storage is excluded because these weights are
# specifically for battery storage.

BATTERY_WEIGHTS = {
    "SPP_KIAM": 0.0000,
    "SPP_N": 0.0045,
    "SPP_NEBR": 0.0060,
    "SPP_SPS": 0.5290,
    "SPP_WAUE": 0.0017,
    "SPP_WEST": 0.4588,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# Fractions are calculated from explicit 2029–2030
# retirement years in the EPA NEEDS active-resource sheet.
#
# Units already placed in the NEEDS "retire by 2028" sheet
# are not part of the active fleet and are therefore not
# retired again here.

RETIREMENT_POLICIES = {
    "SPP": {
        # 1,736 MW scheduled retirement
        # from 17,968.5 MW of active coal capacity.
        "coal": 0.0966,

        # 219 MW scheduled retirement
        # from 9,546.9 MW of active O/G steam capacity.
        "oil": 0.0229,

        # 20.3 MW scheduled retirement
        # from 13,472.5 MW of combustion-turbine capacity.
        "natural gas turbine": 0.0015,

        # No explicit retirement through 2030.
        "natural gas combined cycle": 0.00,

        # No explicit retirement through 2030.
        "nuclear": 0.00,
    }
}

# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "SPP": {
        # SPP 2030 central logic:
        #
        # SPP has a large wind fleet together with substantial
        # coal and natural-gas capacity.
        #
        # Nuclear remains highly must-run.
        #
        # Coal retains a limited minimum-output requirement,
        # but the floor is kept low to accommodate high wind output.
        #
        # Combined-cycle gas provides reliability while retaining
        # enough flexibility to respond to changing wind generation.
        #
        # Combustion turbines and O/G steam units are not forced
        # online because they mainly provide peaking and reliability
        # support.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 488,
        },
    },
    "MISO": {
        "battery": {
            "total_power_mw": 488,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "MISO": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "MISO": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (slow)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 4
# # Total runs: 60 (= 15 scenarios × 4 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/SPP/scenario_results_2030_slow_SPP_midnight
# ================================================================================
#
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.15, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.5, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 11.9663565158844
# Variables Built: 5.417037010192871
# Constraints Built: 45.179824352264404
# Objective Built: 2.4596245288848877
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.05, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.4, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.251502513885498
# Variables Built: 5.322647571563721
# Constraints Built: 45.245890378952026
# Objective Built: 2.4918484687805176
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.25, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.6, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.172229528427124
# Variables Built: 5.335594654083252
# Constraints Built: 45.26450729370117
# Objective Built: 2.4508538246154785
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.15, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.5, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.4861741065979
# Variables Built: 5.507270812988281
# Constraints Built: 46.78049039840698
# Objective Built: 5.240130662918091
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.05, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.4, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.233045816421509
# Variables Built: 5.805367708206177
# Constraints Built: 47.47589111328125
# Objective Built: 5.300915241241455
# Problem Solved: 662.7148168087006
# Solution Graph Built: 40.325719594955444
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.7215499877929688
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 10.0%
# ============================================================================================================================================
#
# Gas Generation: 32,645,759 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,635.30      36,179.90          102,983.77            182.47       299
# solar                               14,821.17       1,584.39      16,405.56           85,776.13            130.98       203
# battery                                488.00         796.97       1,284.97          106,267.74             83.53         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,035.53           0.00     -55,035.53                0.00              0.00        10
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,149,116.69
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $2,711,023,059.33
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 182,473,229.55
#   solar                          $ 130,983,825.43
#   battery                        $  83,532,457.01
#   TOTAL                          $ 396,989,511.99
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 997,593,924.45
#   natural gas combined cycle     $ 700,570,124.49
#   nuclear                        $ 291,077,878.98
#   steam                          $  47,337,214.41
#   natural gas turbine            $  32,266,366.47
#   oil                            $  30,130,630.18
#   waste                          $   3,499,916.11
#   large_hydro                    $   2,733,528.70
#   non-fossil                     $   1,245,637.86
#   small_hydro                    $      93,423.50
#   biomass                        $         502.01
#   TOTAL                          $2,106,549,147.16
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   SPP_N:SPP_WEST                 $  57,628,137.07
#   SPP_SPS:SPP_WEST               $  27,463,820.17
#   SPP_NEBR:SPP_N                 $  23,436,728.11
#   SPP_NEBR:SPP_WAUE              $  21,250,854.13
#   SPP_WEST:SPP_SPS               $  15,423,446.95
#   SPP_WEST:SPP_N                 $  13,937,891.02
#   SPP_N:SPP_NEBR                 $  13,759,488.07
#   SPP_WAUE:SPP_NEBR              $  12,863,799.52
#   SPP_N:SPP_SPS                  $   8,923,995.14
#   SPP_SPS:SPP_N                  $   7,947,930.31
#   TOTAL                          $ 202,636,090.50
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $2,706,174,749.64
# Model Objective                $2,711,023,059.33
# Other Gap                      $   4,848,309.69
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# SPP_NEBR -> SPP_N via line_154: 813.78 MWh
# SPP_NEBR -> SPP_WAUE via line_155: 737.88 MWh
# SPP_N -> SPP_NEBR via line_149: 477.76 MWh
# SPP_N -> SPP_WEST via line_151: 2,000.98 MWh
# SPP_N -> SPP_SPS via line_150: 309.86 MWh
# SPP_WEST -> SPP_N via line_168: 483.95 MWh
# SPP_WEST -> SPP_SPS via line_169: 535.54 MWh
# SPP_SPS -> SPP_N via line_156: 275.97 MWh
# SPP_SPS -> SPP_WEST via line_157: 953.60 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 446.66 MWh
#
# Total transmission across all lines: 7,035.98 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================Problem Solved: 686.4929180145264
# Solution Graph Built: 40.620516538619995
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.7685508728027344
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# Gas Generation: 32,686,714 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,689.72      36,234.32          102,983.77            188.23       299
# solar                               14,821.17       1,608.82      16,430.00           85,776.13            133.00       203
# battery                                488.00         634.26       1,122.26          106,267.74             66.48         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,035.53           0.00     -55,035.53                0.00              0.00        10
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,401,686.32
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $2,703,437,178.12
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $ 188,233,929.65
#   solar                          $ 133,003,849.51
#   battery                        $  66,478,109.88
#   TOTAL                          $ 387,715,889.04
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   coal                           $ 994,138,216.22
#   natural gas combined cycle     $ 700,342,498.09
#   nuclear                        $ 291,082,233.50
#   steam                          $  50,193,849.09
#   natural gas turbine            $  34,347,780.24
#   oil                            $  30,168,090.33
#   waste                          $   3,485,592.17
#   large_hydro                    $   2,724,552.07
#   non-fossil                     $   1,246,231.86
#   small_hydro                    $      93,009.80
#   biomass                        $         788.35
#   TOTAL                          $2,107,822,841.73
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   SPP_N:SPP_WEST                 $  58,153,122.88
#   SPP_SPS:SPP_WEST               $  27,450,010.88
#   SPP_NEBR:SPP_N                 $  23,242,061.07
#   SPP_NEBR:SPP_WAUE              $  21,358,092.36
#   SPP_WEST:SPP_SPS               $  15,678,945.71
#   SPP_WEST:SPP_N                 $  14,110,113.88
#   SPP_N:SPP_NEBR                 $  13,956,217.60
#   SPP_WAUE:SPP_NEBR              $  12,811,440.71
#   SPP_N:SPP_SPS                  $   8,987,711.02
#   SPP_SPS:SPP_N                  $   7,915,964.86
#   TOTAL                          $ 203,663,680.97
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $2,699,202,411.74
# Model Objective                $2,703,437,178.12
# Other Gap                      $   4,234,766.38
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# SPP_NEBR -> SPP_N via line_154: 807.02 MWh
# SPP_NEBR -> SPP_WAUE via line_155: 741.60 MWh
# SPP_N -> SPP_NEBR via line_149: 484.59 MWh
# SPP_N -> SPP_WEST via line_151: 2,019.21 MWh
# SPP_N -> SPP_SPS via line_150: 312.07 MWh
# SPP_WEST -> SPP_N via line_168: 489.93 MWh
# SPP_WEST -> SPP_SPS via line_169: 544.41 MWh
# SPP_SPS -> SPP_N via line_156: 274.86 MWh
# SPP_SPS -> SPP_WEST via line_157: 953.13 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 444.84 MWh
#
# Total transmission across all lines: 7,071.66 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================  Scenario   3 ✓
#
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     50,451.27      17,860.24           0.00      17,860.24         9
# natural gas combined cycle               31,709.63       9,888.90           0.00       9,888.90        10
# nuclear                                  16,062.00       1,995.00           0.00       1,995.00         2
# large_hydro                               9,117.33       4,148.60           0.00       4,148.60         9
# battery                                   4,411.08         488.00         796.97       1,284.97         5
# steam                                     1,381.08       4,989.40           0.00       4,989.40         9
# small_hydro                               1,360.19         678.00           0.00         678.00         5
# oil                                       1,161.21         780.90           0.00         780.90        11
# natural gas turbine                         936.13      10,264.08           0.00      10,264.08        17
# waste                                       504.84          97.42           0.00          97.42        15
# non-fossil                                  179.56          40.80           0.00          40.80         2
# pump hydro                                    0.25           0.03           0.00           0.03         3
# biomass                                       0.01          10.40           0.00          10.40         2
# solar                                   -42,392.29      14,821.17       1,584.39      16,405.56       203
# wind                                   -136,757.07      34,544.60       1,635.30      36,179.90       299
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  10,149,116.69
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 203
# Wind assets found : 299
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_SPP_NEBR:
#   Installed Capacity: 186.56 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_SPP_N:
#   Installed Capacity: 462.74 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_SPP_WEST:
#   Installed Capacity: 417.02 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_SPP_SPS:
#   Installed Capacity: 78.62 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_SPP_WAUE:
#   Installed Capacity: 67.27 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
# Finished scenario 3: s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps10_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 2,711,023,059.33
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.25, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.6, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000Problem Solved: 705.4896018505096
# Solution Graph Built: 41.58116888999939
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 2.726046085357666
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 32,723,197 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                34,544.60       1,732.53      36,277.13          102,983.77            192.76       299
# solar                               14,821.17       1,615.20      16,436.38           85,776.13            133.53       203
# battery                                488.00         527.80       1,015.80          106,267.74             55.32         5
# biomass                                 10.40           0.00          10.40                0.00              0.00         2
# coal                                17,860.24           0.00      17,860.24                0.00              0.00         9
# large_hydro                          4,148.60           0.00       4,148.60                0.00              0.00         9
# natural gas combined cycle           9,888.90           0.00       9,888.90                0.00              0.00        10
# natural gas turbine                 10,264.08           0.00      10,264.08                0.00              0.00        17
# non-fossil                              40.80           0.00          40.80                0.00              0.00         2
# nuclear                              1,995.00           0.00       1,995.00                0.00              0.00         2
# oil                                    780.90           0.00         780.90                0.00              0.00        11
# pump hydro                               0.03           0.00           0.03                0.00              0.00         3
# small_hydro                            678.00           0.00         678.00                0.00              0.00         5
# steam                                4,989.40           0.00       4,989.40                0.00              0.00         9
# unknown                            -55,035.53           0.00     -55,035.53                0.00              0.00        10
# waste                                   97.42           0.00          97.42                0.00              0.00        15
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             10,569,063.03
# Total Shortfall (MWh)                    0.00
#
# ...
# SPP_SPS -> SPP_WEST via line_157: 959.39 MWh
# SPP_WAUE -> SPP_NEBR via line_163: 441.00 MWh
#
# Total transmission across all lines: 7,099.26 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================  Scenario  10 ✓
#
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# coal                                     50,056.36      17,860.24           0.00      17,860.24         9
# natural gas combined cycle               31,710.59       9,888.90           0.00       9,888.90        10
# nuclear                                  16,058.51       1,995.00           0.00       1,995.00         2
# large_hydro                               9,077.62       4,148.60           0.00       4,148.60         9
# battery                                   2,893.33         488.00         347.98         835.98         5
# steam                                     1,483.26       4,989.40           0.00       4,989.40         9
# small_hydro                               1,355.86         678.00           0.00         678.00         5
# oil                                       1,156.54         780.90           0.00         780.90        11
# natural gas turbine                       1,027.64      10,264.08           0.00      10,264.08        17
# waste                                       501.39          97.42           0.00          97.42        15
# non-fossil                                  179.35          40.80           0.00          40.80         2
# pump hydro                                    0.26           0.03           0.00           0.03         3
# biomass                                       0.01          10.40           0.00          10.40         2
# solar                                   -42,383.90      14,821.17       1,580.95      16,402.12       203
# wind                                   -137,184.72      34,544.60       1,755.87      36,300.47       299
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  10,568,369.99
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 203
# Wind assets found : 299
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_SPP_NEBR:
#   Installed Capacity: 93.28 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_NEBR:
#   Installed Capacity: 93.28 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 93.28 MW
#   Max Shift Down: -46.25 MW
#   Total Shifting: 211,085.48 MWh
#
# ev_load_fixed_SPP_N:
#   Installed Capacity: 231.37 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_N:
#   Installed Capacity: 231.37 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 231.37 MW
#   Max Shift Down: -115.52 MW
#   Total Shifting: 501,381.19 MWh
#
# ev_load_fixed_SPP_WEST:
#   Installed Capacity: 208.51 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WEST:
#   Installed Capacity: 208.51 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 208.51 MW
#   Max Shift Down: -104.15 MW
#   Total Shifting: 430,119.68 MWh
#
# ev_load_fixed_SPP_SPS:
#   Installed Capacity: 39.31 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_SPS:
#   Installed Capacity: 39.31 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 39.31 MW
#   Max Shift Down: -19.43 MW
#   Total Shifting: 80,522.21 MWh
#
# ev_load_fixed_SPP_WAUE:
#   Installed Capacity: 33.64 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v1g_SPP_WAUE:
#   Installed Capacity: 33.64 MW
#   Shift Capacity: 0.00 MW
#   Shift Window: 24
#   Max Shift Up: 33.64 MW
#   Max Shift Down: -16.81 MW
#   Total Shifting: 79,166.88 MWh
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_s10_slow_m0_d360/s10_s10_cost_components.csv
# Capex detail CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_s10_slow_m0_d360/s10_s10_capex_detail.csv
# Capex summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_s10_slow_m0_d360/s10_s10_capex_summary.csv
# EV summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_s10_slow_m0_d360/s10_s10_ev_summary.csv
# Finished scenario 10: s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/SPP/scenario_results_2030_slow_SPP_midnight/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360/s10_V1G_rps-10_v1g50_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 2,675,225,920.01
# EV state: SPP
# Model region: SPP
# STATE_TO_REGIONS key used: SPP
# GOOD regions used: ['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
#   rps_SPP_MO: ratio=0.25, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
#   rps_SPP_NM: ratio=0.6, regions=['SPP_KIAM', 'SPP_N', 'SPP_NEBR', 'SPP_SPS', 'SPP_WAUE', 'SPP_WEST']
# Total battery assets removed: 7
# ================================================================================
#
# EV profile market key: SPP
# Missing EV profiles for these regions:
# ['SPP_KIAM']
# Added detail-equivalent aggregate V2G store to SPP_NEBR: max_power=981.12 MW, max_energy=981.12 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to SPP_N: max_power=2337.72 MW, max_energy=2337.72 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to SPP_WEST: max_power=1953.00 MW, max_energy=1953.00 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to SPP_SPS: max_power=386.68 MW, max_energy=386.68 MWh, window_hours=24
# Added detail-equivalent aggregate V2G store to SPP_WAUE: max_power=352.46 MW, max_energy=352.46 MWh, window_hours=24
#
# Processed 477 renewable plants with capex
# Skipped 25 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 9.66%
# Capacity before  : 19,770.02 MW
# Capacity after   : 17,860.24 MW
# oil retirement summary
# Retired fraction : 2.29%
# Capacity before  : 799.20 MW
# Capacity after   : 780.90 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,279.50 MW
# Capacity after   : 10,264.08 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.662728071212769
# Variables Built: 15.473287343978882
# Constraints Built: 52.336308002471924
# Objective Built: 2.9092609882354736
#  340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.861562490463257
# Variables Built: 4.170977830886841
# Constraints Built: 60.6603045463562
# Objective Built: 6.020026922225952
#
# ================================================================================
# Expandable solar/wind assets: 349
# Exact duplicate groups: 9
# Assets contained in duplicate groups: 18
# Assets potentially removable: 9
# CAPEX variables after exact aggregation: 340
# ================================================================================
#
# Largest exact groups:
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:3
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_NEBR     | NE  | solar  | assets=  2 | profile=SPP_NEBR:solar:2
# SPP_N        | KS  | solar  | assets=  2 | profile=SPP_N:solar:3
# SPP_SPS      | NM  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_SPS      | OK  | solar  | assets=  2 | profile=SPP_SPS:solar:4
# SPP_SPS      | TX  | solar  | assets=  2 | profile=SPP_SPS:solar:5
# SPP_WAUE     | SD  | solar  | assets=  2 | profile=SPP_WAUE:solar:2
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#     policy   status      type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_SPP_MO included     solar                      solar           MO          True           28     0.000000
# rps_SPP_MO included      wind                       wind           MO          True           30     0.000000
# rps_SPP_NM excluded generator natural gas combined cycle           NM         False            1   585.000000
# rps_SPP_NM excluded generator        natural gas turbine           NM         False            1   252.121250
# rps_SPP_NM excluded generator                      steam           NM         False            1   112.000000
# rps_SPP_NM included generator                      waste           NM          True            1     0.105595
# rps_SPP_NM included     solar                      solar           NM          True           15  1815.266930
# rps_SPP_NM included      wind                       wind           NM          True           19  1638.600000
# ================================================================================
#
# Parameters Built: 12.973547220230103
# Variables Built: 4.251596689224243
# Constraints Built: 65.69799137115479
# Objective Built: 6.99345064163208
