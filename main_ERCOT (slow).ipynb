# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================
N_SCENARIO_WORKERS = 4
CPLEX_THREADS_PER_SCENARIO = 40

IPM_REGION = "ERCOT"
GOOD_ROOT = Path.home() / "GOOD_MODEL"
EV_DATA_PATH = GOOD_ROOT / "Examples" / "EVDATA" / f"{IPM_REGION}_EVDATA.json"

with open(EV_DATA_PATH, "r") as f:
    ev_data = json.load(f)
YEAR = 2030

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR)

YEAR_INPUT=2030
MONTH_INPUT=0
DAY_INPUT=360

STATE = "TX"
BASE_GRAPH = good.graph.graph_from_json("Examples/Nodes/Texas_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")
TARGET_PEAK_GW = 138  # choose 135, 150, 180, etc.
Discount_rate = 0.07
Lifetime = 25
# Define all adoption scenarios
ADOPTION_SCENARIOS = [
    "slow",
                      # "mid", "fast"
                     ]
# =============================================================================
# Configuration
# =============================================================================
# Define all charging scenarios
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}

# Battery storage distribution weights
BATTERY_WEIGHTS = {
    "ERC_REST": 0.60,
    "ERC_WEST": 0.40,
    "ERC_GWAY": 0.0,
    "ERC_FRNT": 0.0,
    "ERC_PHDL": 0.0,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6

ERCOT_REGIONS = [
    "ERC_FRNT",
    "ERC_PHDL",
    "ERC_GWAY",
    "ERC_REST",
    "ERC_WEST",
]

STATE_TO_REGIONS = {
    "TX": ERCOT_REGIONS,
    "ERCOT": ERCOT_REGIONS,
}
RETIREMENT_POLICIES = {
    "TX": {
        "coal": 1 / 3,
    },

    "NY": {
        "oil": 0.10,
        "natural gas turbine": 0.15,
    },

    "CA": {
        "oil": 0.70,
        "nuclear": 1.00,
        "natural gas turbine": 0.20,
        "natural gas combined cycle": 0.04,
        "coal": 1.00,
    },
}

ASSET_CONSTRAINT_POLICIES = {
    "TX": {
        # ERCOT 2030 central logic:
        # Nuclear is small in capacity but high in energy output, so keep it highly must-run.
        # Coal is still meaningful, but do NOT force it at 45% in a 2030 renewable-heavy case.
        # Combined-cycle gas should provide reliability, but not behave as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.90,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.12,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },

    "NY": {
        # NYISO 2030 central logic:
        # Existing nuclear should be almost always online.
        # Coal should not have a must-run floor. NY has effectively moved away from coal.
        # Gas/oil and dual-fuel units are important for reliability, especially downstate and winter,
        # but they should not be forced as baseload in a clean-transition scenario.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.20,
        },
    },

    "CA": {
        # CAISO / California 2030 central logic:
        # Do not add a nuclear constraint unless your GOOD input data explicitly includes CA nuclear.
        # California policy still treats Diablo Canyon as a transition/reliability resource, not a long-run
        # 2030+ baseload expansion resource.
        # Gas must stay flexible because CA has solar-heavy duck-curve conditions.

        # If your GOOD data has a CA "nuclear" category and you are modeling a 2030 week
        # before Diablo Canyon Unit 2 retirement, you may add this sensitivity:
        #
        # "nuclear": {
        #     "must_run_fraction": 0.60,
        #     "ramp_rate": 0.03,
        # },

        "coal": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.08,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "FL": {
        # Florida / FRCC 2030 central logic:
        # Nuclear is baseload.
        # Florida relies heavily on natural gas, especially combined-cycle gas.
        # Coal still exists but should have a low floor because coal retirements and solar growth continue.
        # Oil should not be must-run.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.08,
            "ramp_rate": 0.04,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.18,
            "ramp_rate": 0.18,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.60,
        },

        "oil": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.30,
        },
    },

    "PJM": {
        # PJM 2030 central logic:
        # Nuclear is large and should remain highly must-run.
        # Coal is still important, but a 45% hourly floor is too high for a 2030 policy/RPS case.
        # Combined-cycle gas is important for reliability and load growth, but it should not be forced
        # as baseload in every hour.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.25,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.05,
            "ramp_rate": 0.25,
        },
    },
}


FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,

            # Default total stationary battery power
            # You can override by state below.
            "total_power_mw": 17500,
        },
    },

    "CA": {
        "battery": {
            "total_power_mw": 16900,
        },
    },

    "NY": {
        "battery": {
            "total_power_mw": 690,
        },
    },

    "TX": {
        "battery": {
            "total_power_mw": 17500,
        },
    },
}

ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        # If False, only fill missing or zero line operating costs.
        # If True, overwrite all line operating costs.
        "overwrite_existing_operating_cost": False,
        # If False, only fill missing efficiencies.
        # If True, overwrite all line efficiencies.
        "overwrite_existing_efficiency": False,
    },
    "NY": {},
    "CA": {},
    "TX": {},
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": True,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })

        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 1 (slow)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 4
# # Total runs: 60 (= 15 scenarios × 4 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.6, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.0, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.3257172107696533
# Parameters Built: 3.339979887008667
# Parameters Built: 3.372767925262451
# Parameters Built: 3.472172975540161
# Variables Built: 1.2345390319824219
# Variables Built: 1.2388713359832764
# Variables Built: 1.306542158126831
# Variables Built: 1.354945421218872
# Constraints Built: 15.554160833358765
# Constraints Built: 15.579810380935669
# Constraints Built: 15.522085666656494
# Objective Built: 1.597623348236084
# Objective Built: 1.593557357788086
# Objective Built: 1.5374255180358887
# Constraints Built: 17.390190839767456
# Objective Built: 0.6911180019378662
# Problem Solved: 59.69307899475098
# Solution Graph Built: 5.453141927719116
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Problem Solved: 65.43881249427795
# Solution DataFrame Built: 0.709627628326416
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 60.0%
# ============================================================================================================================================
#
# Gas Generation: 135,397,957 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,798.31     106,940.81           98,282.12          6,988.81        81
# solar                               36,639.68      41,520.81      78,160.49           87,465.64          3,410.57        59
# battery                             17,500.00       4,765.35      22,265.35          106,267.74            499.47         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -140,130.85           0.00    -140,130.85                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,847,738.69
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Total Objective: $16,338,368,756.36
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,988,809,763.95
#   solar                          $3,410,566,642.01
#   battery                        $ 499,466,392.66
#   TOTAL                          $10,898,842,798.62
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,974,146,676.41
#   nuclear                        $ 829,827,541.76
#   coal                           $ 686,754,427.29
#   steam                          $  89,607,115.35
#   natural gas turbine            $  31,529,560.24
#   waste                          $  11,252,950.98
#   non-fossil                     $   3,672,482.10
#   biomass                        $     186,912.31
#   oil                            $     161,360.35
#   large_hydro                    $      12,336.82
#   small_hydro                    $       8,493.14
#   TOTAL                          $4,627,159,856.75
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 612,530,878.50
#   ERC_PHDL:ERC_WEST              $ 113,968,891.77
#   ERC_REST:ERC_WEST              $   3,019,890.16
#   ERC_WEST:ERC_PHDL              $       4,265.24
#   TOTAL                          $ 729,523,925.67
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,255,526,581.05
# Model Objective                $16,338,368,756.36
# Other Gap                      $  82,842,175.31
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,957.25 MWh
# ERC_REST -> ERC_WEST via line_5: 104.86 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.15 MWh
# ERC_WEST -> ERC_REST via line_8: 21,268.43 MWh
#
# Total transmission across all lines: 25,330.69 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,591.16      35,044.70           0.00      35,044.70         2
# nuclear                                  41,421.19       4,960.00           0.00       4,960.00         1
# coal                                     30,543.98       8,603.07           0.00       8,603.07         1
# battery                                  22,633.37      17,500.00       4,765.35      22,265.35         3
# steam                                     2,508.29       9,055.70           0.00       9,055.70         2
# waste                                     1,615.04         210.40           0.00         210.40         2
# natural gas turbine                         806.79       8,608.50           0.00       8,608.50         2
# non-fossil                                  529.55          68.80           0.00          68.80         1
# small_hydro                                 301.34         341.10           0.00         341.10         1
# large_hydro                                 181.20         208.00           0.00         208.00         1
# oil                                           8.20           1.40           0.00           1.40         1
# biomass                                       3.52         117.50           0.00         117.50         1
# solar                                  -205,017.76      36,639.68      41,520.81      78,160.49        59
# wind                                   -414,893.14      37,142.50      69,798.31     106,940.81        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  51,847,738.69
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 19.79 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 2,018.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 92.99 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
# Solution Graph Built: 5.7291460037231445
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.6967535018920898
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 135,418,961 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,798.41     106,940.91           98,282.12          6,988.82        81
# solar                               36,639.68      41,520.72      78,160.40           87,465.64          3,410.56        59
# battery                             17,500.00       4,765.35      22,265.35          106,267.74            499.47         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -140,130.85           0.00    -140,130.85                0.00              0.00         5
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             51,846,860.62
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
# Total Objective: $16,338,364,962.25
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,988,819,739.97
#   solar                          $3,410,559,388.88
#   battery                        $ 499,466,135.62
#   TOTAL                          $10,898,845,264.47
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,974,612,125.15
#   nuclear                        $ 829,835,585.90
#   coal                           $ 686,247,146.59
#   steam                          $  89,616,302.90
#   natural gas turbine            $  31,524,293.87
#   waste                          $  11,252,951.23
#   non-fossil                     $   3,672,478.15
#   biomass                        $     193,142.73
#   oil                            $     161,358.14
#   large_hydro                    $      12,336.82
#   small_hydro                    $       8,493.14
#   TOTAL                          $4,627,136,214.61
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 612,540,429.28
#   ERC_PHDL:ERC_WEST              $ 113,976,692.08
#   ERC_REST:ERC_WEST              $   3,019,902.57
#   ERC_WEST:ERC_PHDL              $       4,265.24
#   TOTAL                          $ 729,541,289.18
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $16,255,522,768.26
# Model Objective                $16,338,364,962.25
# Other Gap                      $  82,842,193.99
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 3,957.52 MWh
# ERC_REST -> ERC_WEST via line_5: 104.86 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.15 MWh
# ERC_WEST -> ERC_REST via line_8: 21,268.76 MWh
#
# Total transmission across all lines: 25,331.29 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              134,612.29      35,044.70           0.00      35,044.70         2
# nuclear                                  41,421.59       4,960.00           0.00       4,960.00         1
# coal                                     30,521.42       8,603.07           0.00       8,603.07         1
# battery                                  22,634.65      17,500.00       4,765.35      22,265.35         3
# steam                                     2,508.55       9,055.70           0.00       9,055.70         2
# waste                                     1,615.04         210.40           0.00         210.40         2
# natural gas turbine                         806.67       8,608.50           0.00       8,608.50         2
# non-fossil                                  529.55          68.80           0.00          68.80         1
# small_hydro                                 301.34         341.10           0.00         341.10         1
# large_hydro                                 181.20         208.00           0.00         208.00         1
# oil                                           8.20           1.40           0.00           1.40         1
# biomass                                       3.64         117.50           0.00         117.50         1
# solar                                  -205,017.53      36,639.68      41,520.72      78,160.40        59
# wind                                   -414,893.49      37,142.50      69,798.41     106,940.91        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  51,846,860.62
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 19.79 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 2,018.06 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 92.99 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_s02_slow_m0_d360/s02_s02_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_s02_slow_m0_d360/s02_s02_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_s02_slow_m0_d360/s02_s02_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_s02_slow_m0_d360/s02_s02_ev_summary.csv
# Problem Solved: 76.82116198539734
# Finished scenario 3: s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360/s03_Base_only_rps60_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,338,368,756.36
#   Scenario   3 ✓
# EV state: TX
# Model region: ERCOT
# STATE_TO_REGIONS key used: ERCOT
# GOOD regions used: ['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
#
# Texas load scaling summary
# Current TX base peak : 74.52 GW
# Target TX base peak  : 138.00 GW
# Applied scale factor : 1.8518
# Created RPS policies:
#   rps_ERCOT: ratio=0.5, regions=['ERC_FRNT', 'ERC_PHDL', 'ERC_GWAY', 'ERC_REST', 'ERC_WEST']
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: TX
# Missing EV profiles for these regions:
# ['ERC_FRNT', 'ERC_GWAY']
#
# Processed 134 renewable plants with capex
# Skipped 6 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 33.33%
# Capacity before  : 12,904.60 MW
# Capacity after   : 8,603.07 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 122
# Exact duplicate groups: 13
# Assets contained in duplicate groups: 29
# Assets potentially removable: 16
# CAPEX variables after exact aggregation: 106
# ================================================================================
#
# Largest exact groups:
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:7
# ERC_PHDL     | TX  | wind   | assets=  3 | profile=ERC_PHDL:wind:6
# ERC_WEST     | TX  | solar  | assets=  3 | profile=ERC_WEST:solar:4
# ERC_PHDL     | TX  | wind   | assets=  2 | profile=ERC_PHDL:wind:8
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_PHDL     | TX  | solar  | assets=  2 | profile=ERC_PHDL:solar:4
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_REST     | TX  | solar  | assets=  2 | profile=ERC_REST:solar:3
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:7
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | wind   | assets=  2 | profile=ERC_WEST:wind:6
# ERC_WEST     | TX  | solar  | assets=  2 | profile=ERC_WEST:solar:5
#
# ================================================================================
# RPS ASSET MEMBERSHIP CHECK
# ================================================================================
#    policy   status        type                       fuel jurisdiction  rps_eligible  asset_count  capacity_mw
# rps_ERCOT excluded   generator                       coal           TX         False            1  8603.066667
# rps_ERCOT excluded   generator natural gas combined cycle           TX         False            2 35044.700000
# rps_ERCOT excluded   generator        natural gas turbine           TX         False            2  8608.500001
# rps_ERCOT excluded   generator                 non-fossil           TX         False            1    68.800000
# rps_ERCOT excluded   generator                    nuclear           TX         False            1  4960.000000
# rps_ERCOT excluded   generator                        oil           TX         False            1     1.399999
# rps_ERCOT excluded   generator                      steam           TX         False            2  9055.700000
# rps_ERCOT excluded large_hydro                large_hydro           TX         False            1   208.000000
# rps_ERCOT included   generator                    biomass           TX          True            1   117.500000
# rps_ERCOT included   generator                      waste           TX          True            2   210.400000
# rps_ERCOT included small_hydro                small_hydro           TX          True            1   341.100000
# rps_ERCOT included       solar                      solar           TX          True           59 36639.683001
# rps_ERCOT included        wind                       wind           TX          True           81 37142.500002
# ================================================================================
#
# Parameters Built: 3.4610602855682373
# Solution Graph Built: 5.34395694732666
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Variables Built: 0.9525594711303711
# Solution DataFrame Built: 0.714200496673584
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Finished scenario 2: s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_midnight/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360/s02_Base_only_rps50_v1g0_v2g0_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,338,364,962.25
# ...
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 632.89 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 632.89 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 29.16 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 29.16 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_s15_slow_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_s15_slow_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_s15_slow_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_s15_slow_m0_d360/s15_s15_ev_summary.csv
# Solution Graph Built: 7.464067459106445
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.7671430110931396
# Finished scenario 15: s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360/s15_V2G_rps60_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,002,554,996.46
#   Scenario  15 ✓
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 14 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 50.0%
# ============================================================================================================================================
#
# Gas Generation: 132,431,851 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# wind                                37,142.50      69,233.94     106,376.44           98,282.12          6,929.98        81
# solar                               36,639.68      44,285.94      80,925.62           87,465.64          3,632.91        59
# battery                             17,500.00         908.04      18,408.04          106,267.74             95.17         3
# biomass                                117.50           0.00         117.50                0.00              0.00         1
# coal                                 8,603.07           0.00       8,603.07                0.00              0.00         1
# ev_v2g                               9,309.91           0.00       9,309.91                0.00              0.00         3
# large_hydro                            208.00           0.00         208.00                0.00              0.00         1
# natural gas combined cycle          35,044.70           0.00      35,044.70                0.00              0.00         2
# natural gas turbine                  8,608.50           0.00       8,608.50                0.00              0.00         2
# non-fossil                              68.80           0.00          68.80                0.00              0.00         1
# nuclear                              4,960.00           0.00       4,960.00                0.00              0.00         1
# oil                                      1.40           0.00           1.40                0.00              0.00         1
# small_hydro                            341.10           0.00         341.10                0.00              0.00         1
# steam                                9,055.70           0.00       9,055.70                0.00              0.00         2
# unknown                           -139,336.53           0.00    -139,336.53                0.00              0.00         8
# waste                                  210.40           0.00         210.40                0.00              0.00         2
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)             53,318,761.14
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 14
# ====================================================================================================
#
# Total Objective: $16,002,556,162.19
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   wind                           $6,929,975,961.34
#   solar                          $3,632,910,951.44
#   battery                        $  95,173,299.63
#   TOTAL                          $10,658,060,212.41
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,909,840,131.55
#   nuclear                        $ 828,539,039.49
#   coal                           $ 680,020,837.66
#   steam                          $  85,366,451.44
#   natural gas turbine            $  29,598,947.19
#   waste                          $  11,135,363.25
#   non-fossil                     $   3,635,249.43
#   biomass                        $     220,180.69
#   oil                            $     156,246.00
#   large_hydro                    $      12,232.29
#   small_hydro                    $       8,360.75
#   TOTAL                          $4,548,533,039.74
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   ERC_WEST:ERC_REST              $ 595,336,350.97
#   ERC_PHDL:ERC_WEST              $ 116,630,603.04
#   ERC_REST:ERC_WEST              $   2,405,566.61
#   ERC_WEST:ERC_PHDL              $         315.81
#   TOTAL                          $ 714,372,836.43
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $15,920,966,088.58
# Model Objective                $16,002,556,162.19
# Other Gap                      $  81,590,073.61
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
# ERC_PHDL -> ERC_WEST via line_4: 4,049.67 MWh
# ERC_REST -> ERC_WEST via line_5: 83.53 MWh
# ERC_WEST -> ERC_PHDL via line_7: 0.01 MWh
# ERC_WEST -> ERC_REST via line_8: 20,671.40 MWh
#
# Total transmission across all lines: 24,804.61 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              131,675.52      35,044.70           0.00      35,044.70         2
# nuclear                                  41,356.88       4,960.00           0.00       4,960.00         1
# coal                                     30,244.50       8,603.07           0.00       8,603.07         1
# battery                                  20,367.54      17,500.00         908.04      18,408.04         3
# steam                                     2,389.00       9,055.70           0.00       9,055.70         2
# waste                                     1,598.16         210.40           0.00         210.40         2
# ev_v2g                                    1,306.38       2,327.48           0.00       2,327.48         3
# natural gas turbine                         756.33       8,608.50           0.00       8,608.50         2
# non-fossil                                  524.18          68.80           0.00          68.80         1
# small_hydro                                 296.64         341.10           0.00         341.10         1
# large_hydro                                 179.66         208.00           0.00         208.00         1
# oil                                           7.94           1.40           0.00           1.40         1
# biomass                                       4.15         117.50           0.00         117.50         1
# solar                                  -211,600.23      36,639.68      44,285.94      80,925.62        59
# wind                                   -412,896.79      37,142.50      69,233.94     106,376.44        81
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                  53,318,761.14
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 59
# Wind assets found : 81
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_ERC_PHDL:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_PHDL:
#   Installed Capacity: 6.21 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_REST:
#   Installed Capacity: 632.89 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_REST:
#   Installed Capacity: 632.89 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ev_load_fixed_ERC_WEST:
#   Installed Capacity: 29.16 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_ERC_WEST:
#   Installed Capacity: 29.16 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_s14_slow_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_s14_slow_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_s14_slow_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_s14_slow_m0_d360/s14_s14_ev_summary.csv
# Finished scenario 14: s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360
# Solution JSON: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_solution.json
# Solution CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_solution.csv
# Summary CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_summary.csv
# Total cost CSV: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360/s14_V2G_rps50_v1g0_v2g50_bcapex315_slow_m0_d360_total_cost.csv
# Objective = 16,002,556,162.19
#   Scenario  14 ✓
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/ERCOT/scenario_results_2030_slow_ERCOT_flex/all_scenarios_summary.csv
