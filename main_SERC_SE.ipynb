# %%
import warnings
warnings.filterwarnings("ignore")
import good
import json
import os
import pandas as pd
import importlib
from good import s_runner
from good import helper
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing as mp
from pathlib import Path

# %%
# =============================================================================
# Input settings
# =============================================================================

import os
import json
import importlib
import pandas as pd

# ---------------------------------------------------------
# Model region
# ---------------------------------------------------------
# This is the model region key, not one IPM node.
# For PJM, this maps to several GOOD nodes.
N_SCENARIO_WORKERS = 5
CPLEX_THREADS_PER_SCENARIO = 10
IPM_REGION = "SERC-SE"
MODEL_REGION = IPM_REGION
STATE = IPM_REGION

YEAR_INPUT = 2030
MONTH_INPUT = 0
DAY_INPUT = 360

Discount_rate = 0.07
Lifetime = 25

# ---------------------------------------------------------
# Load EV data and scenarios
# ---------------------------------------------------------
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
def find_good_root():
    """
    Find the GOOD project root in a portable way.

    Priority:
    1. Use GOOD_ROOT environment variable if it exists.
    2. Search upward from the current working directory.
    """
    env_root = os.environ.get("GOOD_ROOT")
    if env_root:
        return Path(env_root).expanduser().resolve()

    current = Path.cwd().resolve()
    for folder in [current, *current.parents]:
        if (folder / "good").exists() and (folder / "Examples").exists():
            return folder

    raise FileNotFoundError(
        "Could not find GOOD project root. "
        "Set GOOD_ROOT to the path of your GOOD folder."
    )


GOOD_ROOT = find_good_root()
EV_DATA_DIR = GOOD_ROOT / "Examples" / "EVDATA"

ev_data_path = EV_DATA_DIR / f"{IPM_REGION}_EVDATA.json"

if not ev_data_path.exists():
    available_files = sorted(EV_DATA_DIR.glob("*.json"))
    available_names = [p.name for p in available_files]

    raise FileNotFoundError(
        f"Could not find EV data file:\n"
        f"  {ev_data_path}\n\n"
        f"Available files in {EV_DATA_DIR}:\n"
        f"  {available_names}"
    )

with ev_data_path.open("r") as f:
    ev_data = json.load(f)

SCENARIOS = helper.load_scenarios(IPM_REGION, YEAR_INPUT)

# ---------------------------------------------------------
# Load base graph and base policies
# ---------------------------------------------------------
BASE_GRAPH = good.graph.graph_from_json(f"Examples/Nodes/{IPM_REGION}_IPM.json")
BASE_POLICIES = good.utilities.read_json("Examples/policies.json")

# ---------------------------------------------------------
# Run settings
# ---------------------------------------------------------
TARGET_PEAK_GW = 150
ADOPTION_SCENARIOS = [
    "slow",
    "mid",
    "fast"
]
CHARGING_SCENARIOS = {
    "midnight": {
        "profile": "timed_charging",
        "description": "Midnight timed charging",
    },
    "delay": {
        "profile": "max_delay",
        "description": "Maximum delay charging",
    },
    "arrive": {
        "profile": "min_delay",
        "description": "Immediate arrival charging",
    },
    "flex": {
        "profile": "load_leveling",
        "description": "Flexible load leveling",
    },
}
# ---------------------------------------------------------
# GOOD regions used by this model region
# ---------------------------------------------------------

SERC_SE_REGIONS = [
    "S_SOU",
]

STATE_TO_REGIONS = {
    "SERC-SE": SERC_SE_REGIONS,
}

# ---------------------------------------------------------
# Battery storage distribution weights
# ---------------------------------------------------------
# EIA-860M operating battery capacity, June 2026:
#
# S_SOU: 786.2 MW
#
# This includes operating electrochemical battery generators
# located within the S_SOU IPM region.
#
# Pumped-storage hydro is excluded because these weights are
# specifically for battery storage.
#
# Because SERC-SE contains only one GOOD region, all new
# regional battery capacity is assigned to S_SOU.

BATTERY_WEIGHTS = {
    "S_SOU": 1.0000,
}

assert abs(sum(BATTERY_WEIGHTS.values()) - 1.0) < 1e-6


# =============================================================================
# Policies used by run_one_scenario
# =============================================================================

# ---------------------------------------------------------
# Region-level retirement policies
# ---------------------------------------------------------
# The denominator is the EPA NEEDS Winter 2024 active fleet.
#
# The numerator includes:
#
# 1. Retirement years recorded in the NEEDS active sheet.
# 2. Matching generators subsequently reported as retired in
#    EIA-860M.
#
# Generators absent from the NEEDS active fleet are not added
# to the retirement numerator because the model does not contain
# that capacity.

RETIREMENT_POLICIES = {
    "SERC-SE": {
        # Scherer Unit 3:
        # 860.0 MW scheduled retirement in 2029.
        #
        # 860.0 / 10,146.0 MW active coal capacity
        "coal": 0.0848,

        # E.C. Gaston steam Units 1-4:
        # 1,020.0 MW scheduled retirement in 2029.
        #
        # These are represented by the model's O/G Steam
        # category, even though they are primarily gas-fired.
        #
        # 1,020.0 / 3,691.2 MW active O/G steam capacity
        "oil": 0.2763,

        # E.C. Gaston GT4: 16.0 MW scheduled retirement.
        # Two small Hewlett Packard generators: 2.8 MW already
        # retired after the NEEDS baseline.
        #
        # 18.8 / 12,268.2 MW active combustion-turbine capacity
        "natural gas turbine": 0.0015,

        # No matched retirement through 2030 from
        # 20,323.7 MW of active combined-cycle capacity.
        "natural gas combined cycle": 0.0000,

        # No matched retirement through 2030 from
        # 8,080.0 MW of active nuclear capacity.
        "nuclear": 0.0000,
    }
}


# ---------------------------------------------------------
# Asset constraint policies
# ---------------------------------------------------------

ASSET_CONSTRAINT_POLICIES = {
    "SERC-SE": {
        # SERC-SE / S_SOU 2030 central logic:
        #
        # S_SOU has approximately:
        #
        # Nuclear:             8,080.0 MW
        # Coal steam:         10,146.0 MW
        # Combined cycle:     20,323.7 MW
        # Combustion turbine: 12,268.2 MW
        # O/G steam:           3,691.2 MW
        #
        # Nuclear remains highly must-run.
        #
        # Coal receives a moderate aggregated floor. This represents
        # a portion of the remaining coal fleet staying committed
        # without forcing every coal unit online during low-load or
        # high-renewable hours.
        #
        # Combined-cycle gas is the largest thermal category in this
        # region. A 15% floor represents the portion likely committed
        # for load following and reliability.
        #
        # Combustion turbines remain peaking resources and therefore
        # receive no must-run floor.
        #
        # The model's "oil" category represents O/G steam. Much of this
        # capacity is gas-fired steam generation. Its 10% floor and
        # slower 8% hourly transition limit serve as an aggregated
        # commitment approximation when startup variables are absent.

        "nuclear": {
            "must_run_fraction": 0.95,
            "ramp_rate": 0.03,
        },

        "coal": {
            "must_run_fraction": 0.20,
            "ramp_rate": 0.05,
        },

        "natural gas combined cycle": {
            "must_run_fraction": 0.15,
            "ramp_rate": 0.20,
        },

        "natural gas turbine": {
            "must_run_fraction": 0.00,
            "ramp_rate": 0.80,
        },

        "oil": {
            "must_run_fraction": 0.10,
            "ramp_rate": 0.08,
        },
    },
}

FLEXIBILITY_POLICIES = {
    "default": {
        # -----------------------------
        # V1G settings
        # -----------------------------
        "v1g": {
            "base_shift_cost": 0.0,
            "fixed_om_per_kw_year": 0.0,
            "shift_window_hours": 24,
        },

        # -----------------------------
        # V2G settings
        # -----------------------------
        "v2g": {
            "window_hours": 24,
            "energy_duration_hours": 1,
            "roundtrip_efficiency": 0.985,
            "base_shift_cost": 1.3784e-9,
            "fixed_om_per_kw_year": 0.0,
        },

        # -----------------------------
        # Stationary battery settings
        # -----------------------------
        "battery": {
            "duration_hours": 4,
            "charge_efficiency": 0.93,
            "discharge_efficiency": 0.92,
            "fixed_om_per_kw_year": 3.75,
            "cycling_cost_per_mwh": 0.01,
            "initial_soc_fraction": 0.50,
            "total_power_mw": 786,
        },
    },
    "SERC-SE": {
        "battery": {
            "total_power_mw": 786,
        },
    },
}

# ---------------------------------------------------------
# Economic policies
# ---------------------------------------------------------
ECONOMIC_POLICIES = {
    "default": {
        "discount_rate": 0.07,
        "lifetime_years": 25,
        "import_operating_cost": 1.75e-8,
        "apply_crf_to_renewables": True,
        "apply_crf_to_storage": True,
        "renewable_fuels_for_crf": {"solar", "wind"},
    },

    "SERC-SE": {},
}

# ---------------------------------------------------------
# Transmission policies
# ---------------------------------------------------------
TRANSMISSION_POLICIES = {
    "default": {
        "apply_distance_enhancement": True,
        "default_operating_cost": 2.222222222222222e-09,
        "default_efficiency": 0.90,
        "overwrite_existing_operating_cost": False,
        "overwrite_existing_efficiency": False,
    },
    "SERC-SE": {},
}

# ---------------------------------------------------------
# Policy inputs passed directly to run_one_scenario
# ---------------------------------------------------------
# Important:
# For PJM, state_rps_policies must be None.
# Each PJM scenario already has cfg["state_rps_policies"].
# This is how rps_minus10, rps_base, and rps_plus10 work.
POLICY_INPUTS = {
    "state_rps_policies": None,
}

# %%
"""
Professional Scenario Runner - Loops Through All Adoption × Charging Scenarios
Runs all combinations of adoption levels and charging patterns separately.
Each combination gets its own folder.
"""
# =============================================================================
# Main Loop - Process Each Adoption × Charging Scenario Combination
# =============================================================================

importlib.reload(s_runner)


total_combinations = len(ADOPTION_SCENARIOS) * len(CHARGING_SCENARIOS)
total_runs = len(SCENARIOS) * total_combinations
print(f"\n{'#'*80}")
print(f"# RUNNING ALL ADOPTION × CHARGING SCENARIOS")
print(f"# Adoption scenarios: {len(ADOPTION_SCENARIOS)} ({', '.join(ADOPTION_SCENARIOS)})")
print(f"# Charging scenarios: {len(CHARGING_SCENARIOS)} ({', '.join(CHARGING_SCENARIOS.keys())})")
print(f"# Total combinations: {total_combinations}")
print(f"# Total runs: {total_runs} (= {len(SCENARIOS)} scenarios × {total_combinations} combinations)")
print(f"{'#'*80}\n")
# Track overall progress
all_results_tracker = {}

for adoption_level in ADOPTION_SCENARIOS:

    print(f"\n{'█'*80}")
    print(f"█ ADOPTION LEVEL: {adoption_level.upper()}")
    print(f"{'█'*80}\n")

    for charging_name, charging_config in CHARGING_SCENARIOS.items():

        # Set up this combination
        RESULTS_DIR = f"Output/{IPM_REGION}/scenario_results_{YEAR_INPUT}_{adoption_level}_{IPM_REGION}_{charging_name}"
        CHARGING_PROFILE = charging_config["profile"]


        ctx = s_runner.ScenarioRunContext(
            scenarios=SCENARIOS,
            base_graph=BASE_GRAPH,
            base_policies=BASE_POLICIES,
            state_to_regions=STATE_TO_REGIONS,
            ev_data=ev_data,
            battery_weights=BATTERY_WEIGHTS,
            results_dir=RESULTS_DIR,
            discount_rate=Discount_rate,
            lifetime=Lifetime,
            retirement_policies=RETIREMENT_POLICIES,
            asset_constraint_policies=ASSET_CONSTRAINT_POLICIES,
            solver_threads=CPLEX_THREADS_PER_SCENARIO,
        )
        # Create unique key for tracking
        combo_key = f"{adoption_level}_{charging_name}"

        print(f"\n{'='*80}")
        print(f"COMBINATION: {adoption_level.upper()} adoption + {charging_config['description']}")
        print(f"Results Directory: {RESULTS_DIR}")
        print(f"{'='*80}\n")

        # Create results directory
        os.makedirs(RESULTS_DIR, exist_ok=True)

        # Run all scenarios for this combination
        all_results = []
        failed_scenarios = []

        tasks = []

        for scenario_id in sorted(SCENARIOS.keys()):
            tasks.append({
                "scenario_id": scenario_id,
                "ctx": ctx,
                "year": YEAR_INPUT,
                "adoption": adoption_level,
                "charging": CHARGING_PROFILE,
                "charging_name": charging_name,
                "charging_description": charging_config["description"],
                "month": MONTH_INPUT,
                "day_duration": DAY_INPUT,
                "model_region": IPM_REGION,
                "discount_rate": Discount_rate,
                "lifetime": Lifetime,
                "fix_peak": False,
                "target_peak_gw": TARGET_PEAK_GW,
                "peak_region_mode": "all",
                "peak_regions": None,
                "retirement_policy": None,
                "asset_constraint_policy": None,
                "use_state_default_retirement": True,
                "use_state_default_asset_constraints": True,
                "flexibility_policy": FLEXIBILITY_POLICIES,
                "use_state_default_flexibility": True,
                "economic_policy": ECONOMIC_POLICIES,
                "use_state_default_economic_policy": True,
                "transmission_policy": TRANSMISSION_POLICIES,
                "use_state_default_transmission_policy": True,
            })
       

        mp_context = mp.get_context("spawn")

        with ProcessPoolExecutor(
            max_workers=N_SCENARIO_WORKERS,
            mp_context=mp_context,
        ) as executor:

            futures = {
                executor.submit(s_runner.run_one_scenario_parallel_task, task): task["scenario_id"]
                for task in tasks
            }

            for future in as_completed(futures):
                scenario_id = futures[future]
                result = future.result()

                if result["ok"]:
                    all_results.append(result["row"])
                    print(f"  Scenario {scenario_id:>3} ✓")
                else:
                    print(f"  Scenario {scenario_id:>3} ✗ Error: {result['error']}")

                    failed_scenarios.append({
                        "scenario_id": scenario_id,
                        "error": result["error"],
                        "traceback": result["traceback"],
                    })
        
        
        # Save results for this combination
        all_results_df = pd.DataFrame(all_results)
        summary_path = os.path.join(RESULTS_DIR, "all_scenarios_summary.csv")
        all_results_df.to_csv(summary_path, index=False)

        # Save failed scenarios if any
        if failed_scenarios:
            failed_df = pd.DataFrame(failed_scenarios)
            failed_path = os.path.join(RESULTS_DIR, "failed_scenarios.csv")
            failed_df.to_csv(failed_path, index=False)

        # Store for later comparison
        all_results_tracker[combo_key] = all_results_df

        # Print summary for this combination
        print(f"\n  Summary:")
        print(f"    Successful: {len(all_results)}/{len(SCENARIOS)}")
        print(f"    Failed: {len(failed_scenarios)}/{len(SCENARIOS)}")
        print(f"    Saved to: {summary_path}")

        if failed_scenarios:
            print(f"    ⚠ Failed scenarios logged to: {failed_path}")
# Out:
# ################################################################################
# # RUNNING ALL ADOPTION × CHARGING SCENARIOS
# # Adoption scenarios: 3 (slow, mid, fast)
# # Charging scenarios: 4 (midnight, delay, arrive, flex)
# # Total combinations: 12
# # Total runs: 180 (= 15 scenarios × 12 combinations)
# ################################################################################
#
#
# ████████████████████████████████████████████████████████████████████████████████
# █ ADOPTION LEVEL: SLOW
# ████████████████████████████████████████████████████████████████████████████████
#
#
# ================================================================================
# COMBINATION: SLOW adoption + Midnight timed charging
# Results Directory: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight
# ================================================================================
#
# EV state: SERC-SE
# Model region: SERC-SE
# STATE_TO_REGIONS key used: SERC-SE
# GOOD regions used: ['S_SOU']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-SE
# EV state: SERC-SE
# Model region: SERC-SE
# STATE_TO_REGIONS key used: SERC-SE
# GOOD regions used: ['S_SOU']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-SE
#
# Processed 104 renewable plants with capex
# Skipped 4 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 8.48%
# Capacity before  : 14,203.00 MW
# Capacity after   : 12,998.59 MW
# oil retirement summary
# Retired fraction : 27.63%
# Capacity before  : 925.10 MW
# Capacity after   : 669.49 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,353.90 MW
# Capacity after   : 10,338.37 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 62
# Exact duplicate groups: 1
# Assets contained in duplicate groups: 2
# Assets potentially removable: 1
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# S_SOU        | GA  | solar  | assets=  2 | profile=S_SOU:solar:3
#
# RPS asset membership check: no matching assets found.
#
# Processed 104 renewable plants with capex
# Skipped 4 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 8.48%
# Capacity before  : 14,203.00 MW
# Capacity after   : 12,998.59 MW
# oil retirement summary
# Retired fraction : 27.63%
# Capacity before  : 925.10 MW
# Capacity after   : 669.49 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,353.90 MW
# Capacity after   : 10,338.37 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 62
# Exact duplicate groups: 1
# Assets contained in duplicate groups: 2
# Assets potentially removable: 1
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# S_SOU        | GA  | solar  | assets=  2 | profile=S_SOU:solar:3
#
# RPS asset membership check: no matching assets found.
# EV state: SERC-SE
# Model region: SERC-SE
# STATE_TO_REGIONS key used: SERC-SE
# GOOD regions used: ['S_SOU']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-SE
# EV state: SERC-SE
# Model region: SERC-SE
# STATE_TO_REGIONS key used: SERC-SE
# GOOD regions used: ['S_SOU']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-SE
# EV state: SERC-SE
# Model region: SERC-SE
# STATE_TO_REGIONS key used: SERC-SE
# GOOD regions used: ['S_SOU']
# Base load peak scaling is OFF. Using original graph load.
# Created RPS policies:
# Total battery assets removed: 2
# ================================================================================
#
# EV profile market key: SERC-SE
#
# Processed 104 renewable plants with capex
# Skipped 4 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 8.48%
# Capacity before  : 14,203.00 MW
# Capacity after   : 12,998.59 MW
# oil retirement summary
# Retired fraction : 27.63%
# Capacity before  : 925.10 MW
# Capacity after   : 669.49 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,353.90 MW
# Capacity after   : 10,338.37 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 62
# Exact duplicate groups: 1
# Assets contained in duplicate groups: 2
# Assets potentially removable: 1
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# S_SOU        | GA  | solar  | assets=  2 | profile=S_SOU:solar:3
#
# RPS asset membership check: no matching assets found.
#
# Processed 104 renewable plants with capex
# Skipped 4 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 8.48%
# Capacity before  : 14,203.00 MW
# Capacity after   : 12,998.59 MW
# oil retirement summary
# Retired fraction : 27.63%
# Capacity before  : 925.10 MW
# Capacity after   : 669.49 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,353.90 MW
# Capacity after   : 10,338.37 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 62
# Exact duplicate groups: 1
# Assets contained in duplicate groups: 2
# Assets potentially removable: 1
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# S_SOU        | GA  | solar  | assets=  2 | profile=S_SOU:solar:3
#
# RPS asset membership check: no matching assets found.
#
# Processed 104 renewable plants with capex
# Skipped 4 renewable plants (no valid capex_cost)
# ================================================================================
#
# coal retirement summary
# Retired fraction : 8.48%
# Capacity before  : 14,203.00 MW
# Capacity after   : 12,998.59 MW
# oil retirement summary
# Retired fraction : 27.63%
# Capacity before  : 925.10 MW
# Capacity after   : 669.49 MW
# natural gas turbine retirement summary
# Retired fraction : 0.15%
# Capacity before  : 10,353.90 MW
# Capacity after   : 10,338.37 MW
# ================================================================================
# EXACT RENEWABLE AGGREGATION DIAGNOSTIC
# ================================================================================
# Expandable solar/wind assets: 62
# Exact duplicate groups: 1
# Assets contained in duplicate groups: 2
# Assets potentially removable: 1
# CAPEX variables after exact aggregation: 61
# ================================================================================
#
# Largest exact groups:
# S_SOU        | GA  | solar  | assets=  2 | profile=S_SOU:solar:3
#
# RPS asset membership check: no matching assets found.
# Parameters Built: 2.921354055404663
# Parameters Built: 2.944499969482422
# Parameters Built: 2.915884017944336
# Parameters Built: 2.9233269691467285
# Parameters Built: 2.970752716064453
# Variables Built: 1.8041231632232666
# Variables Built: 1.8378427028656006
# Variables Built: 1.8968729972839355
# Variables Built: 1.832226276397705
# Variables Built: 1.945587158203125
# Constraints Built: 11.441152095794678
# Constraints Built: 11.489491939544678
# Constraints Built: 11.614167928695679
# Constraints Built: 11.790115594863892
# Constraints Built: 11.79335355758667
# Objective Built: 1.4174702167510986
# Objective Built: 1.4376411437988281
# Objective Built: 1.575636863708496
# Objective Built: 1.3727269172668457
# Objective Built: 1.4467558860778809
# Problem Solved: 36.39846348762512
# Problem Solved: 38.15578866004944
# Problem Solved: 39.04539704322815
# Problem Solved: 39.54243516921997
# Solution Graph Built: 3.280181646347046
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Problem Solved: 39.73702931404114
# Solution DataFrame Built: 0.6146464347839355
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Solution Graph Built: 3.535839796066284
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution Graph Built: 3.321478843688965
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Solution DataFrame Built: 0.6226913928985596
#
# ============================================================================================================================================
# SCENARIO 3 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 10.0%
# ============================================================================================================================================
#
# Gas Generation: 122,888,073 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# unknown                            -47,741.10           0.00     -47,741.10                0.00              0.00         2
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 3
# ====================================================================================================
#
# Solution DataFrame Built: 0.6260366439819336
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Solution Graph Built: 3.4783639907836914
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# Total Objective: $5,415,938,428.79
#
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Solution Graph Built: 3.5196359157562256
# ================================================================================
# SOLVER STATUS CHECK
# ================================================================================
# Solver status: ok
# Termination condition: optimal
# ================================================================================
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,922,000,885.15
#   nuclear                        $1,471,463,933.46
#   coal                           $ 963,401,560.75
#   oil                            $  21,893,019.37
#   non-fossil                     $  20,102,420.77
#   steam                          $   7,445,864.60
#   waste                          $   5,172,930.78
#   large_hydro                    $   1,283,526.01
#   small_hydro                    $     171,176.14
#   natural gas turbine            $      79,201.82
#   biomass                        $       9,629.35
#   TOTAL                          $5,413,024,148.21
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,413,024,148.21
# Model Objective                $5,415,938,428.79
# Other Gap                      $   2,914,280.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
# Solution DataFrame Built: 0.594975471496582
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
# Solution DataFrame Built: 0.6254971027374268
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              122,886.17      19,292.20           0.00      19,292.20         4
# nuclear                                  69,887.13       8,089.00           0.00       8,089.00         2
# coal                                     37,516.91      12,998.59           0.00      12,998.59         4
# large_hydro                               7,155.73       2,921.30           0.00       2,921.30         2
# non-fossil                                2,897.86         335.40           0.00         335.40         3
# small_hydro                               2,681.96       1,094.90           0.00       1,094.90         2
# waste                                       746.52          86.40           0.00          86.40         4
# oil                                         670.46         669.49           0.00         669.49         3
# battery                                     330.02         786.00           0.00         786.00         1
# steam                                       224.81       3,246.50           0.00       3,246.50         4
# natural gas turbine                           1.90      10,338.37           0.00      10,338.37         4
# pump hydro                                    1.25           0.13           0.00           0.13         1
# biomass                                       0.29         399.70           0.00         399.70         2
# wind                                          0.00           0.00           0.00           0.00        48
# solar                                   -14,791.82       5,941.71           0.00       5,941.71        60
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 60
# Wind assets found : 48
#
# ============================================================================================================================================
# SCENARIO 2 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_SOU:
#   Installed Capacity: 1,260.15 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s03_s03_slow_m0_d360/s03_s03_cost_components.csv
# Capex detail CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s03_s03_slow_m0_d360/s03_s03_capex_detail.csv
# Capex summary CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s03_s03_slow_m0_d360/s03_s03_capex_summary.csv
# EV summary CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s03_s03_slow_m0_d360/s03_s03_ev_summary.csv
#
# Gas Generation: 122,888,073 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# unknown                            -47,741.10           0.00     -47,741.10                0.00              0.00         2
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 2
# ====================================================================================================
#
#
# ====================================================================================================
# OBJECTIVE GAP CHECK
# ====================================================================================================
#
# ============================================================================================================================================
# SCENARIO 1 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 122,888,073 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# unknown                            -47,741.10           0.00     -47,741.10                0.00              0.00         2
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 1
# ====================================================================================================
#
# Total Objective: $5,415,938,428.79
#
# Total Objective: $5,415,938,428.79
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,922,000,885.15
#   nuclear                        $1,471,463,933.46
#   coal                           $ 963,401,560.75
#   oil                            $  21,893,019.37
#   non-fossil                     $  20,102,420.77
#   steam                          $   7,445,864.60
#   waste                          $   5,172,930.78
#   large_hydro                    $   1,283,526.01
#   small_hydro                    $     171,176.14
#   natural gas turbine            $      79,201.82
#   biomass                        $       9,629.35
#   TOTAL                          $5,413,024,148.21
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,413,024,148.21
# Model Objective                $5,415,938,428.79
# Other Gap                      $   2,914,280.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# SCENARIO 4 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: -10.0%
# ============================================================================================================================================
#
# Gas Generation: 123,092,185 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# unknown                            -47,741.10           0.00     -47,741.10                0.00              0.00         3
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 4
# ====================================================================================================
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,922,000,885.15
#   nuclear                        $1,471,463,933.46
#   coal                           $ 963,401,560.75
#   oil                            $  21,893,019.37
#   non-fossil                     $  20,102,420.77
#   steam                          $   7,445,864.60
#   waste                          $   5,172,930.78
#   large_hydro                    $   1,283,526.01
#   small_hydro                    $     171,176.14
#   natural gas turbine            $      79,201.82
#   biomass                        $       9,629.35
#   TOTAL                          $5,413,024,148.21
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,413,024,148.21
# Model Objective                $5,415,938,428.79
# Other Gap                      $   2,914,280.58
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# SCENARIO 5 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 0.0%
# ============================================================================================================================================
# Total Objective: $5,415,417,415.21
#
#
# Gas Generation: 123,092,185 MWh
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              122,886.17      19,292.20           0.00      19,292.20         4
# nuclear                                  69,887.13       8,089.00           0.00       8,089.00         2
# coal                                     37,516.91      12,998.59           0.00      12,998.59         4
# large_hydro                               7,155.73       2,921.30           0.00       2,921.30         2
# non-fossil                                2,897.86         335.40           0.00         335.40         3
# small_hydro                               2,681.96       1,094.90           0.00       1,094.90         2
# waste                                       746.52          86.40           0.00          86.40         4
# oil                                         670.46         669.49           0.00         669.49         3
# battery                                     330.02         786.00           0.00         786.00         1
# steam                                       224.81       3,246.50           0.00       3,246.50         4
# natural gas turbine                           1.90      10,338.37           0.00      10,338.37         4
# pump hydro                                    1.25           0.13           0.00           0.13         1
# biomass                                       0.29         399.70           0.00         399.70         2
# wind                                          0.00           0.00           0.00           0.00        48
# solar                                   -14,791.82       5,941.71           0.00       5,941.71        60
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 60
# Wind assets found : 48
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# unknown                            -47,741.10           0.00     -47,741.10                0.00              0.00         3
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 5
# ====================================================================================================
#
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_SOU:
#   Installed Capacity: 1,260.15 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s02_s02_slow_m0_d360/s02_s02_cost_components.csv
# Capex detail CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s02_s02_slow_m0_d360/s02_s02_capex_detail.csv
# Capex summary CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s02_s02_slow_m0_d360/s02_s02_capex_summary.csv
# EV summary CSV: Output/SERC-SE/scenario_results_2030_slow_SERC-SE_midnight/s02_s02_slow_m0_d360/s02_s02_ev_summary.csv
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              122,886.17      19,292.20           0.00      19,292.20         4
# nuclear                                  69,887.13       8,089.00           0.00       8,089.00         2
# coal                                     37,516.91      12,998.59           0.00      12,998.59         4
# large_hydro                               7,155.73       2,921.30           0.00       2,921.30         2
# non-fossil                                2,897.86         335.40           0.00         335.40         3
# small_hydro                               2,681.96       1,094.90           0.00       1,094.90         2
# waste                                       746.52          86.40           0.00          86.40         4
# oil                                         670.46         669.49           0.00         669.49         3
# battery                                     330.02         786.00           0.00         786.00         1
# ...
# solar                                   -14,791.82       5,941.71           0.00       5,941.71        60
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 60
# Wind assets found : 48
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_SOU:
#   Installed Capacity: 500.71 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_S_SOU:
#   Installed Capacity: 500.71 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_s14_fast_m0_d360/s14_s14_cost_components.csv
# Capex detail CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_s14_fast_m0_d360/s14_s14_capex_detail.csv
# Capex summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_s14_fast_m0_d360/s14_s14_capex_summary.csv
# EV summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_s14_fast_m0_d360/s14_s14_ev_summary.csv
#
# ============================================================================================================================================
# SCENARIO 15 CLEAN CAPACITY / CAPEX DEBUG
# RPS Target: 10.0%
# ============================================================================================================================================
#
# Gas Generation: 124,991,672 MWh
# Fuel                             Installed MW       Capex MW       Total MW      Avg Capex $/MW   Capex Cost ($M)   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# battery                                786.00           0.00         786.00          106,267.74              0.00         1
# oil                                    669.49           0.00         669.49                0.00              0.00         3
# waste                                   86.40           0.00          86.40                0.00              0.00         4
# unknown                            -47,482.37           0.00     -47,482.37                0.00              0.00         3
# steam                                3,246.50           0.00       3,246.50                0.00              0.00         4
# solar                                5,941.71           0.00       5,941.71           81,831.20              0.00        60
# small_hydro                          1,094.90           0.00       1,094.90                0.00              0.00         2
# pump hydro                               0.13           0.00           0.13                0.00              0.00         1
# nuclear                              8,089.00           0.00       8,089.00                0.00              0.00         2
# biomass                                399.70           0.00         399.70                0.00              0.00         2
# non-fossil                             335.40           0.00         335.40                0.00              0.00         3
# natural gas turbine                 10,338.37           0.00      10,338.37                0.00              0.00         4
# natural gas combined cycle          19,292.20           0.00      19,292.20                0.00              0.00         4
# large_hydro                          2,921.30           0.00       2,921.30                0.00              0.00         2
# ev_v2g                               8,511.69           0.00       8,511.69                0.00              0.00         1
# coal                                12,998.59           0.00      12,998.59                0.00              0.00         4
# wind                                     0.00           0.00           0.00          116,041.38              0.00        48
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                      0.00
# Total Shortfall (MWh)                    0.00
#
# ====================================================================================================
# DETAILED COST BREAKDOWN - SCENARIO 15
# ====================================================================================================
#
# Total Objective: $5,465,556,984.59
#
# ====================================================================================================
# COST SUMMARY
# ====================================================================================================
#
# CAPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ASSET OPEX
# ----------------------------------------------------------------------------------------------------
#   natural gas combined cycle     $2,971,990,493.73
#   nuclear                        $1,471,503,258.39
#   coal                           $ 965,763,604.56
#   oil                            $  21,920,240.02
#   non-fossil                     $  20,102,420.77
#   waste                          $   5,172,930.78
#   steam                          $   3,660,453.76
#   large_hydro                    $   1,283,526.01
#   small_hydro                    $     171,176.14
#   biomass                        $       4,126.86
#   TOTAL                          $5,461,572,231.04
#
# LINE OPEX
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# FIXED
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# PENALTIES
# ----------------------------------------------------------------------------------------------------
#   TOTAL                          $           0.00
#
# ====================================================================================================
# Reconstructed Total            $5,461,572,231.04
# Model Objective                $5,465,556,984.59
# Other Gap                      $   3,984,753.56
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION LINE MAPPING
# ====================================================================================================
#
# ====================================================================================================
# TRANSMISSION FLOW CHECK
# ====================================================================================================
#
# Total transmission across all lines: 0.00 MWh
#
# ====================================================================================================
# TRANSMISSION LINE PARAMETERS
# ====================================================================================================
#
# ====================================================================================================
# SHORTFALL BY REGION AND HOUR
# ====================================================================================================
# No shortfall found.
#
# ====================================================================================================
# WASTAGE BY REGION AND HOUR
# ====================================================================================================
# No wastage found.
#
# ====================================================================================================
# IMPORT CONGESTION AT SHORTFALL HOURS
# ====================================================================================================
# No shortfall hours found.
#
# ============================================================================================================================================
# GENERATION TABLE
# ============================================================================================================================================
# Fuel                              Generation (GWh)   Installed MW       Capex MW       Total MW   #Assets
# --------------------------------------------------------------------------------------------------------------------------------------------
# natural gas combined cycle              124,991.67      19,292.20           0.00      19,292.20         4
# nuclear                                  69,888.96       8,089.00           0.00       8,089.00         2
# coal                                     37,613.09      12,998.59           0.00      12,998.59         4
# large_hydro                               7,155.73       2,921.30           0.00       2,921.30         2
# non-fossil                                2,897.86         335.40           0.00         335.40         3
# small_hydro                               2,681.96       1,094.90           0.00       1,094.90         2
# waste                                       746.52          86.40           0.00          86.40         4
# oil                                         671.45         669.49           0.00         669.49         3
# battery                                     307.05         786.00           0.00         786.00         1
# steam                                       112.09       3,246.50           0.00       3,246.50         4
# ev_v2g                                      107.10       2,127.92           0.00       2,127.92         1
# pump hydro                                    1.25           0.13           0.00           0.13         1
# biomass                                       0.12         399.70           0.00         399.70         2
# natural gas turbine                           0.00      10,338.37           0.00      10,338.37         4
# wind                                          0.00           0.00           0.00           0.00        48
# solar                                   -14,791.82       5,941.71           0.00       5,941.71        60
# --------------------------------------------------------------------------------------------------------------------------------------------
# Total Wastage (MWh)                           0.00
# Total Shortfall (MWh)                         0.00
#
# ====================================================================================================
# SIMULTANEOUS CHARGE / DISCHARGE CHECK
# ====================================================================================================
# No simultaneous charge/discharge detected.
#
# ====================================================================================================
# ENERGY BALANCE DIAGNOSTIC
# ====================================================================================================
#
# Solar assets found: 60
# Wind assets found : 48
#
# ====================================================================================================
# EV ASSET DIAGNOSTIC
# ====================================================================================================
#
# ev_load_fixed_S_SOU:
#   Installed Capacity: 500.71 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: False
#
# ev_load_v2g_S_SOU:
#   Installed Capacity: 500.71 MW
#   Shift Capacity: 0.00 MW
#   Shiftable: True
#
# ====================================================================================================
# REGIONAL EV SUMMARY
# ====================================================================================================
#
# ====================================================================================================
# STATEWIDE EV TOTALS
# ====================================================================================================
# Cost components CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_s15_fast_m0_d360/s15_s15_cost_components.csv
# Capex detail CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_s15_fast_m0_d360/s15_s15_capex_detail.csv
# Capex summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_s15_fast_m0_d360/s15_s15_capex_summary.csv
# EV summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_s15_fast_m0_d360/s15_s15_ev_summary.csv
# Finished scenario 13: s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360/s13_V2G_rps-10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 5,465,556,984.59
#   Scenario  13 ✓
# Finished scenario 14: s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360/s14_V2G_rps0_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 5,465,556,984.59
#   Scenario  14 ✓
# Finished scenario 15: s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360
# Solution JSON: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.json
# Solution CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_solution.csv
# Summary CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_summary.csv
# Total cost CSV: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360/s15_V2G_rps10_v1g0_v2g50_bcapex315_fast_m0_d360_total_cost.csv
# Objective = 5,465,556,984.59
#   Scenario  15 ✓
#
#   Summary:
#     Successful: 15/15
#     Failed: 0/15
#     Saved to: Output/SERC-SE/scenario_results_2030_fast_SERC-SE_flex/all_scenarios_summary.csv
